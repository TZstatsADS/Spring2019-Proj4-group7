# %%
import re

def isClean(cur_token):
    
    # Words longer than 20 chars is garbage
    if len(cur_token) > 20:
        return False
    
    # Number of punctuation in string is greater 
    # than number of alpha numeric characters
    alphanum = re.findall("[A-Za-z0-9]", cur_token)
    punc = re.findall("[^A-Za-z0-9]", cur_token)
    if len(punc) > len(alphanum):
        return False
    
    # ignoring first and last, if there are two or more 
    # different punctuation
    uniquepunc = len(set(re.findall("[^A-Za-z0-9]", cur_token[1:-1] )))
    if uniquepunc > 1:
        return False

    # if 3 identical characters in a row
    tmp4 = re.findall("([a-z\\d])\\1\\1", cur_token)
    if tmp4:
        return False
    
    # if num upper case is greater than num lowercase
    # and word is not all uppercase
    upper = re.findall("[A-Z]", cur_token)
    lower = re.findall("[a-z]", cur_token)
    if (len(upper) > len(lower)) and (len(upper) != len(cur_token)):
        return False
    
    # if all characters are alphabetic
    # and num constants is greater than 8 times the vowels
    # or vice versa
    vowels = re.findall("[AEIOUaeiou]", cur_token)
    constants = re.findall("[^AEIOUaeiou]", cur_token)
    if cur_token.isalpha() and (len(vowels) > len(constants) * 8 or len(constants) > len(vowels) * 8):
        return False
    
    # four or more consecutive vowels or 5 or more consecutive constants
    tmpv = re.findall("[AEIOUaeiou]{4,}", cur_token)
    tmpc = re.findall("[^AEIOUaeiou]{5,}", cur_token)
    if tmpv or tmpc:
        return False
    
    # if first and last chars are both lower case an any character upper
    lower_ends = cur_token[0] + cur_token[-1]
    if lower_ends.islower() and not cur_token.islower():
        return False
    
    # if normal word
    return True

# %%
# read each file
import glob
arr = []
name = []
for file in list(glob.glob('../data/tesseract/*.txt')):                                       
    reader = open(file)    
    text = reader.read()
    arr.append(text)
    name.append(file)

# %%
# split words and select trash words
trash = []
for file in arr:
    garbage = []
    text = file.strip().split()
    garbage = [x for x in text if isClean(x) == False]
    #print(len(text))
#     for count, word in enumerate(text):
#         #print (count)
#         #if the word is garbage
#         if isClean(word) == False:
#             # if first word
#             if count == 0:
#                 # append current word and next
#                 garbage.append((word, "", text[count + 1]))
#             #if last word
#             elif count == len(text) - 1:
#                 garbage.append((word, text[count - 1], ""))
#             #other wise
#             else:
#                 garbage.append((word, text[count - 1], text[count + 1]))
    #garbage = [''.join(w) for w in garbage]        
    trash.append(garbage)

# %%
#trash
# Out:
# [['u',
#   'by',
#   'Willlam',
#   'J.',
#   'ACTION.',
#   '..',
#   '...1nvolv1ng',
#   't',
#   'V1972',
#   'a',
#   'AFL’CID',
#   'cmng',
#   "Admlnlstratlon's",
#   'd',
#   'mm',
#   'M1115',
#   'Banklng',
#   'Cy',
#   'Commlttee',
#   'jurlsdlctlon',
#   't',
#   'commlttee',
#   'hearlngs',
#   'a',
#   'antlclpated.',
#   'm',
#   'lngs,',
#   'mm',
#   'm',
#   'prohlblt:',
#   '1nvolv1ng',
#   'm',
#   'dE*',
#   'L7.',
#   'a',
#   'mg',
#   'contrlbute',
#   '.',
#   'reportlng',
#   'statlstlcs',
#   'worklng',
#   'condltlons',
#   'dlstrlbutlon.',
#   'advertlslng.',
#   'commlttee',
#   'by',
#   '.',
#   'cm',
#   '012524A',
#   'ENVIRONMENT...',
#   'pendlng',
#   'Subcommlttee',
#   'Worklng',
#   '1nv1ted',
#   'a',
#   'mm',
#   'by',
#   'submltted',
#   'Addltlonal',
#   'Actlng',
#   'Willlam',
#   'B.',
#   'm',
#   'testlng',
#   'STAFF...',
#   '1n515ted',
#   'pendlng',
#   '1396,',
#   'mm',
#   "Commlttee's",
#   'by',
#   'Commlttee',
#   'Senate*ﬂouse',
#   'A',
#   'HDUSE’SENATE',
#   'CONFERENCE.',
#   '..',
#   'Commlsslon',
#   'by',
#   'mg',
#   'EEDC‘S',
#   'm',
#   '1::',
#   'jurlsdlctlon.',
#   'A',
#   'CoNsUMER',
#   'BILL...',
#   '...wh1ch',
#   'Subcommlttee',
#   'b111,',
#   '1177,',
#   'establlsh',
#   'm',
#   'addltlon.',
#   'dE*',
#   'by',
#   'a',
#   'cm',
#   '035191',
#   'T',
#   'thls',
#   'suggestlng',
#   'Commlttee.',
#   'Subcommlttee',
#   'marklng',
#   'thls',
#   'ownsmm',
#   '.',
#   '.',
#   '.',
#   '...on',
#   '25729',
#   'by',
#   'G.',
#   'm.fFlaJ,',
#   'Commlttee',
#   '1519,',
#   '23725',
#   'by',
#   'F.',
#   '(D.*MD.7,',
#   'Commlttee',
#   'by',
#   'Perslstently',
#   "EPA'S",
#   '155mm;',
#   '"Requlrements',
#   'Submlttal',
#   "EPA'S",
#   'Admlnlstrator.',
#   '1mpllcatlons',
#   'posslble',
#   'envlronmentallsts',
#   'thls',
#   'polltlcal',
#   'ms',
#   'REPORT...',
#   '...wr1tten',
#   'by',
#   'Commlttee',
#   'Subcommlttee',
#   'Hlth',
#   'hearlngs',
#   '2754,',
#   '1971.',
#   'By',
#   "Commlttee's",
#   'K.',
#   'vsmg',
#   'flnanclng.',
#   'Endlng',
#   'Permlttlng',
#   'actlvltles',
#   'Endlng',
#   'Quallfylng',
#   'earnlngs',
#   'CMAD3619',
#   'speclflc',
#   'by',
#   'Subsldlze',
#   'dlrectly,',
#   '1nd1rectly,',
#   'a',
#   'endlng',
#   'a',
#   'cernlng',
#   'by',
#   'phthalatejolastlclzed',
#   'polyvlnyl',
#   '£11m,',
#   'blrth',
#   'mm',
#   'plastlclzers',
#   'plastlcs,',
#   'polyvlnyl',
#   'wlsh',
#   'a',
#   'technlcal',
#   'Plannlng',
#   'Hlth',
#   'understandlng',
#   '1nvolv1ng',
#   'admlnlstratlon',
#   'ASSOCIATION...',
#   '1::',
#   'mm',
#   'Unlverslty',
#   'a',
#   'reglstry',
#   'acroosteolysls',
#   '(flngertlp',
#   'lesmnsy',
#   'a',
#   '1ndustry.',
#   'by',
#   'contrlbutlons',
#   'polyvlnyl',
#   'a',
#   'whlch',
#   'Hlth',
#   'cllnlcal,',
#   'thls',
#   'syndrome',
#   'polyvlnyl',
#   '...as',
#   'a',
#   'concernlng',
#   'facllltles',
#   'm',
#   'modlflcatlon',
#   'Hlth',
#   'm',
#   'coMMIssIoN...',
#   'cm',
#   '035193',
#   '...scheduled',
#   'a',
#   'concernlng',
#   'by',
#   'requestlng',
#   'wrltten',
#   'by',
#   'dld',
#   'sufflclent',
#   'a',
#   'm',
#   'a',
#   'T',
#   '..',
#   'flrst',
#   'thls',
#   'CURRENTS/PILDT',
#   'whlch',
#   'monthly,',
#   'by',
#   'P.',
#   '9000',
#   'ACTIVITIES...',
#   '...by',
#   '1ncreaslng.',
#   '"An',
#   'W',
#   'a',
#   'descrlblng',
#   'dlstrlbutlon',
#   '20,000',
#   'upcomlng.',
#   'A',
#   '"A',
#   'Growth,"',
#   '"Careers',
#   'Industry."',
#   '"What',
#   'by',
#   'Exhlblt',
#   'ellclted',
#   'Admlnlstrators',
#   'Clty,',
#   '1215.',
#   'dlsplay',
#   'Supervlslon',
#   'Clty,',
#   'recognltlon',
#   'by',
#   'Dlvlslon',
#   'a',
#   'Dlvlslon',
#   'Chemlstry,',
#   'trlaliAcademlc',
#   'a',
#   'Actlvltles',
#   'Commlttee',
#   'meetlng,',
#   'partlclpate',
#   'mm',
#   'ECIS"',
#   'Instltute',
#   '“(Efficient',
#   'cMADBall',
#   "MCA'S",
#   'E.',
#   'mm',
#   '(NSF7',
#   'NSF',
#   'fundlng.',
#   'by',
#   'a',
#   '1nternsh1p',
#   'R',
#   'u',
#   '1ndustry.',
#   'A'],
#  ['nlsms',
#   'T',
#   'A',
#   'thls',
#   'by',
#   'scrlptl',
#   's',
#   'a',
#   'a',
#   'p',
#   'by',
#   'by',
#   'M.',
#   'F,',
#   'the.Mt.',
#   '1972.',
#   '$30,000',
#   'consultlng',
#   'regardlng',
#   '$3,000.',
#   'Supervlslon',
#   'm',
#   "MCA'S",
#   'by',
#   'a',
#   'Technlcal',
#   'technlcal',
#   'subscrlblng',
#   'MCA,',
#   'Comnlttee.',
#   'Fundlng',
#   'Consnltments',
#   'by',
#   'thlrteen',
#   'thls',
#   'u',
#   '$3,500',
#   'commltments.',
#   'd',
#   'sclentlflc',
#   'thls',
#   'm',
#   'trlctlon.',
#   'conslstency',
#   't',
#   'm',
#   'n',
#   'tlmlng.',
#   'pry',
#   'sclentlflc',
#   "non'competltlve",
#   'whlch',
#   'subscrlblng',
#   'm',
#   'a',
#   'by',
#   "MCA'S",
#   '"General',
#   'Prlnclples',
#   'Appllcable',
#   'Conmlttees"',
#   'ty',
#   'Commlttee.',
#   '035207'],
#  ['D',
#   'Atlvltles',
#   'Commlttee',
#   'm',
#   'g',
#   'Chemlsts',
#   'By',
#   'Commlttee',
#   'm',
#   'thls',
#   'affectlng',
#   'Commlttee',
#   'technlcal',
#   'a',
#   'technlcal',
#   'by',
#   '197D',
#   '1971;',
#   'thlrd',
#   'm',
#   'a',
#   'I',
#   'thls',
#   'tn',
#   "Commlttee's",
#   'actlvltles,',
#   'asslgnment',
#   'responslblllty',
#   'm',
#   'condltlons',
#   'Commltte',
#   'flrst',
#   'establlshed',
#   'mm',
#   'a',
#   'chemlsts.',
#   'a',
#   'chemlstry,',
#   'chemlsts',
#   'xpandlng',
#   '1ndustry.',
#   'm',
#   'd',
#   "50's,",
#   'Commlttee',
#   'a',
#   'recrultlng',
#   'technlcal',
#   'I',
#   'blrth',
#   'chemlsts',
#   "70's.",
#   'thls',
#   'mm',
#   'beglnnlng',
#   '1959,',
#   'chemlsts',
#   'w',
#   '1Ch',
#   'whlch',
#   'ch',
#   'growlng.',
#   'thls',
#   'chemlsts',
#   'mm',
#   'unsettllng',
#   'Commlttee',
#   'stresslng',
#   'chemlsts',
#   '1ndustry.',
#   '035213',
#   'SWPLY’DEMAND',
#   'mm',
#   'a',
#   'mghly',
#   'concernlng',
#   'relatlonshlp',
#   'sclentlflc',
#   'reachlng',
#   "1980's",
#   'by',
#   'prestlglous',
#   'Foundatlbn.',
#   'Sclentlflc',
#   'Commlsslon,',
#   '‘',
#   'Varylng',
#   'ranglng',
#   'predlctlon',
#   'm',
#   'Harnlngs',
#   'mm',
#   'changlng',
#   'shlftlng',
#   'actlvltles.',
#   'thls,',
#   'predlctlng',
#   'technlcal',
#   'by',
#   'm',
#   'Hlth',
#   'a',
#   '13.5.,',
#   '24.5.',
#   'chemlstry',
#   '.',
#   'd',
#   'thls',
#   'contlnueS,',
#   'a',
#   'sclentlflc',
#   'A5',
#   'responslbl-',
#   '1ndustry,',
#   'I',
#   'I',
#   'mm',
#   'a',
#   's-atlstlcal',
#   'analysls',
#   'thls',
#   'und-rgraduate',
#   'chemlstry',
#   '1970,',
#   'chemlstry',
#   'flrst',
#   'a',
#   'hlgh',
#   'chemlstry',
#   'flrst',
#   'chemlstry',
#   '1955.',
#   'Statlstlcs',
#   'w',
#   'o',
#   'a',
#   'chemlstry',
#   'a',
#   '"stepplng',
#   'Thlrd,',
#   'undrgraduate',
#   'decllnlng',
#   'Slgnlflcanly.',
#   '43,000',
#   '1971,',
#   '31,000.',
#   'th',
#   'rapldlyidecllnlng',
#   'sclentlflc',
#   'technlcal',
#   'changlng',
#   'R',
#   'L',
#   'n',
#   'thls',
#   'I',
#   'w',
#   '1dustry,',
#   'a',
#   'nt',
#   'posslble.',
#   '035214',
#   'chemlc.l',
#   '1ndustry,',
#   'complexlty,',
#   'requlrlng',
#   '1nd1v1duals',
#   'worklng',
#   'condltlons',
#   'mg',
#   'chemlsts',
#   'predlctlon',
#   'thls',
#   'a',
#   'rlsk',
#   'overslmpllflcatlon,',
#   'thls',
#   'by',
#   'R/D.',
#   '1A5:',
#   'actlvltles',
#   'a',
#   'technlcal',
#   'mm',
#   'thls',
#   'tendlng',
#   'R/D',
#   'chemlsts',
#   'a',
#   'd',
#   'thls',
#   'dlmlnlsh.',
#   'd',
#   '1nvolv1ng',
#   'newlyiemerglng',
#   '1mend1ng',
#   'crlsls,',
#   'whlch',
#   'Slgmsk',
#   'posslbly',
#   'dE*',
#   'st',
#   'supply,',
#   'offsettlng',
#   '1ndustry.',
#   'sequently,',
#   'chemlstry',
#   'technlcal',
#   'surroundlng',
#   'temptlng',
#   '"Walt',
#   'Commlttee',
#   'thls,',
#   '1Veness',
#   'chemlstry',
#   'a',
#   '.',
#   '1ntenslfy',
#   'n',
#   'technlcallyiorlented',
#   '1ndustry.',
#   'n',
#   'd',
#   'mlnd',
#   'chemlsts',
#   "'",
#   '0F',
#   'coupmmm',
#   'm',
#   'mm',
#   'a',
#   'by',
#   '1nustry,',
#   '1:.',
#   'thls',
#   'a',
#   'promptly',
#   'Hlth',
#   'posltlve',
#   'mm',
#   'Commlttee,',
#   'organlzlng',
#   'a',
#   'Meanwhlle,',
#   'I',
#   'mm',
#   's',
#   'thls',
#   'plannlng',
#   '.ommssmns.',
#   't',
#   'e',
#   'I',
#   '1971,',
#   'a',
#   'reallgnment',
#   'accordlng',
#   't',
#   'eondltl',
#   'ntlng',
#   '"To',
#   'unerstandlng',
#   '1ndustry;',
#   '35515:',
#   'chemlstry,',
#   '1nterd15c1pllnary',
#   'm',
#   'chemlstry;',
#   'teachlng',
#   'chemlstry',
#   'mlsslon',
#   'Hlth',
#   'actlvltles',
#   'attalnlng',
#   'I',
#   'unerstandlng',
#   'asslgned',
#   'm',
#   'a',
#   'mlbcommlttee.',
#   'Concernlng',
#   '60110',
#   'mg',
#   '61nd:',
#   'chemlstry',
#   'a',
#   'sclentlsts',
#   'mm',
#   'a',
#   'multlple',
#   'ms',
#   'chemlst.',
#   'prevalllng',
#   'a',
#   'a',
#   'a',
#   'a',
#   'speclflc',
#   'descrlbed',
#   'succlnctly',
#   'skllls.',
#   'a',
#   'legltlmate',
#   'openlngs.',
#   'thls',
#   'actlvlty',
#   'condltlons.',
#   'Subcommlttee',
#   '1ndustry.',
#   'a',
#   'mm',
#   'a',
#   'mlght',
#   'subcommlttee',
#   'chemlstry',
#   'a',
#   'R',
#   'L',
#   'D.',
#   'n',
#   '1ndustry,',
#   '35—m1n15tratlon,',
#   'marketlng,',
#   'mm',
#   '...where',
#   'Consequently,',
#   'm',
#   'b',
#   '1nd1v1dual',
#   'skllls',
#   '4,500',
#   'admlnlstrators',
#   'A',
#   'dlstrlbuted',
#   'a',
#   'g',
#   'studnts.',
#   '197171972',
#   '30,000',
#   '10,000',
#   'unwittlng',
#   '1:.',
#   'subommlttee',
#   '55515::',
#   'chmlstry',
#   'a',
#   'a',
#   'edlclne,',
#   'whlch',
#   'technlcallytralned',
#   'p',
#   'a',
#   'nd',
#   'chemlsts',
#   'partlclpants',
#   'by',
#   '1nv1tatlon',
#   'by',
#   '1nv1tatlon,',
#   'mm',
#   'prellmlnary',
#   'plannlng',
#   'a',
#   'whlch',
#   '111',
#   'jolntly',
#   'expedltlng',
#   'by',
#   'whlch',
#   'thls',
#   'subcommlttee',
#   "'",
#   '1957,',
#   'outstandlng',
#   'chemlstry',
#   'englneerlng.',
#   'by',
#   'r',
#   'r-clplents',
#   'teachlng',
#   '1972,',
#   'medallsts',
#   'a',
#   'a',
#   'flrst',
#   '1972,',
#   'a',
#   'thls',
#   "V'IT",
#   's',
#   'contrlbuted',
#   'm',
#   'thls',
#   'dlmensl-n',
#   'A5',
#   'a',
#   '1nst1tutlons',
#   '1n1tlate',
#   'tradltln',
#   '03517',
#   'a',
#   'actlvlt',
#   'ngh',
#   'SC',
#   '1964,',
#   'mm',
#   'admlnlstered',
#   'by',
#   'Councllq',
#   'restrlcted',
#   'Hlthln',
#   'councll.',
#   '1973,',
#   'ellglble',
#   'a',
#   '$1,000.',
#   '1nf-Imatlon',
#   'e',
#   'Subcommlttee',
#   'chemlstry',
#   'chemlstry',
#   'flrst',
#   '1ntenslfled',
#   'c',
#   'emlstry',
#   'Recently,',
#   'mm',
#   'mm',
#   'chemlstry',
#   'a',
#   'flrst',
#   'Mczvsponsored',
#   '"Chemlstry',
#   'publlsh-d',
#   'by',
#   '1ndustry.',
#   '100,000',
#   'I',
#   'm',
#   'enrlch',
#   'hlgh',
#   'chemlstry',
#   'slmllar',
#   'm',
#   'thls',
#   'publlshes',
#   'enlistlng',
#   'asslstlng',
#   'manuscrlpts',
#   '.',
#   'Wlnston',
#   'publlshed',
#   '155,000',
#   'thls',
#   'fundlng',
#   'Chemlstry',
#   'Commlttee',
#   'ACS.',
#   'submltted',
#   'months,',
#   'Chln’nan',
#   'commlttee',
#   'contrlbutlons',
#   'chemlstry',
#   'educat-rs.',
#   '1n1tlated',
#   'thls',
#   'subcommlttee',
#   'mm',
#   'slmllar',
#   '03.219',
#   'FUEL]:',
#   'vmgnsmmms',
#   'suscommmrm',
#   't',
#   'subcommlttee',
#   'Actlvltles',
#   'Commlttee',
#   'gr',
#   'understandlng',
#   'a',
#   'neg.t1ve',
#   ':echmcallymnented',
#   '1ndustry.',
#   'm',
#   'surE,',
#   'mm',
#   'a',
#   'r',
#   '"wrlte',
#   'thls',
#   'mm',
#   '1nd1cates',
#   'a',
#   'accompllshments',
#   'sbcommlttee',
#   'Hlth',
#   'dlstrlbute',
#   'exhlblts',
#   'c',
#   'sclnce',
#   'publlcs.',
#   'publlshed',
#   'a',
#   'slmple',
#   'manuscrlpt',
#   "MCA'S",
#   'exhlblt',
#   't',
#   'mm',
#   '2,500',
#   'Vlslted',
#   'exhlblts',
#   'slmllar',
#   'Hlth',
#   'subcommlttees',
#   'presentlng',
#   '"Cat.lyst',
#   'Necessary...?,',
#   'whlch',
#   'I',
#   'thls',
#   'mornlng.',
#   'thls',
#   '1nd1cates',
#   'prlnted',
#   'mm',
#   'whlch',
#   '1nd1cated',
#   'a',
#   'mm',
#   'Commlttee',
#   'Crltlclsm',
#   'whlch,',
#   'restrlctlve',
#   'endlng.',
#   'thlng',
#   'a',
#   'publlc.',
#   'Publlcs',
#   'a',
#   '5:111',
#   'n',
#   '035219',
#   'brlngs',
#   'my',
#   'I',
#   'Commlttee',
#   'MCA,',
#   'Commlttee',
#   'membershlp',
#   '1nd1v1duals',
#   'a',
#   'hlghly',
#   'dlsclpllnes',
#   'glvlng',
#   'a',
#   'I',
#   'a',
#   'a',
#   'prlvllege',
#   'mm',
#   't',
#   '-m.',
#   'I',
#   'thls',
#   'I',
#   'hlghllghts',
#   'accompllshments',
#   'I',
#   'I',
#   'w',
#   'thls',
#   'I',
#   'u',
#   'A',
#   '035220'],
#  ['A',
#   'thls',
#   'sclentlflc',
#   'carclnogenlclty.',
#   'by',
#   'Plannlng',
#   'mg',
#   'whlch',
#   'Hlth',
#   'testlng',
#   'Accordlng',
#   'Hlth',
#   'whlch',
#   'contlngencles,',
#   '$193,000.',
#   'Fundlng',
#   'Fundlng',
#   'commltments',
#   'sufflclent',
#   'publlcly',
#   'polyvlnyl',
#   'm',
#   "MCA'S",
#   'by',
#   'a',
#   'subscrlblng',
#   'Admlnlst',
#   'm',
#   'Commlttee.',
#   '03522',
#   's',
#   'thls',
#   'c',
#   'ly',
#   'dlsclosed,',
#   'restrlctlon.',
#   'conslste',
#   'y',
#   'MCA,',
#   'nt',
#   'sclentlflc',
#   'nonicompetltlve',
#   'u',
#   'ml',
#   'Hlthln',
#   'subscrlblng',
#   'a',
#   't',
#   'by',
#   "MCA'S",
#   '"General',
#   'p',
#   '1nc1ples',
#   'Appllcable',
#   'Commlttee.',
#   '035229'],
#  ['exhlblt',
#   'by',
#   'Wllllam',
#   'J',
#   'REFORM...hear1ngs',
#   'm',
#   "Commlttee's",
#   'M1115',
#   'Ark.7,',
#   '1nd1cated',
#   'orlty.',
#   'pry',
#   'cert.1n',
#   'hearlngs.',
#   'H111',
#   '..',
#   'oopholejolugglng"',
#   'bllls.',
#   'M1115',
#   'Admlnstratlon',
#   '1::',
#   'offlclals',
#   '1nd1cate',
#   'Admmsmr',
#   'H111',
#   '(AER)',
#   'mm',
#   'H111',
#   'offlclals',
#   'whlch',
#   'by',
#   'Commlttee.',
#   'M1115',
#   '1nd1cated',
#   'ls',
#   '1:.',
#   'a',
#   'm',
#   'by',
#   'Admlnlstratlon,',
#   '1:.',
#   'ICY...1n',
#   'Admlnlstratlon',
#   'H111',
#   'leadershlp.',
#   '1nd1cated',
#   'addltlon',
#   'm',
#   'hls',
#   'H111',
#   'pollcy.',
#   '1nd1cated',
#   'r',
#   'a',
#   'by',
#   'D3626',
#   'DVERSY...oVer',
#   'a',
#   'by',
#   'wlth',
#   'Commlsslon',
#   'classlflcatlon',
#   "(BCV'57",
#   ',',
#   'clalmlng',
#   'a',
#   'slngle',
#   'trendlng',
#   'Crltlclz-d',
#   '54n,nnn,',
#   'contendlng',
#   'a',
#   'm',
#   'prescrlbe',
#   'lengthy.',
#   'm',
#   'addltlonal',
#   'Instltu-e,',
#   '11mm;',
#   '1973.',
#   'NIosH..',
#   'Instltute',
#   'conductlng',
#   'a',
#   'a',
#   'statl-tlcal',
#   'g',
#   'physlcal',
#   'by',
#   's',
#   "Instltute's",
#   'speclflc',
#   'thls',
#   'a',
#   'a',
#   'snnn',
#   'mlght',
#   '1-31:',
#   'e',
#   'a',
#   't',
#   'e',
#   'M',
#   'A',
#   'H111',
#   'egardlng',
#   'cm',
#   'n3.24a',
#   'ASDCIATIDN...part1c1pated',
#   'Commlttee',
#   'mg',
#   'A.',
#   'Dlstrlbutlon',
#   'Toxlcclogy.',
#   '.',
#   'deflnltlons',
#   'thls',
#   'H111',
#   'a',
#   's',
#   'm',
#   '119707',
#   'al.55161catlon.',
#   'mater1.ls',
#   't',
#   'ASDCIATIDN...has',
#   'm',
#   'Envlr-nmental',
#   'membershlp',
#   'Stand.rds',
#   'Commlttee.',
#   '.',
#   'GROUPS...are',
#   'wlth',
#   'th',
#   '(:5.',
#   '1norgan1cs,',
#   'plastlcs',
#   'synthetlcs.',
#   'n',
#   '1::',
#   'Offlcs',
#   'draftlng',
#   'dlscharge',
#   'permlts',
#   'cs',
#   'synthetlcs',
#   'wlth',
#   'H111',
#   'a',
#   'establlshlng',
#   'dlscharge',
#   'antlclpated',
#   '1nd1v1dual',
#   'H111',
#   '35247',
#   'commrmg...nas',
#   'establlshed',
#   'wlth',
#   't',
#   'regardlng:',
#   'dlscharge',
#   'dlscharge',
#   'appllcatlons',
#   'a',
#   'm',
#   'dlscharges',
#   '1nt-mun1c1pal',
#   'A',
#   'CDMMITTEE...task',
#   'H111',
#   's',
#   '.',
#   'BLDCH...Assoclate',
#   'a',
#   'lDiyear',
#   'lvltles',
#   'Commlttee',
#   'm',
#   'u',
#   'catalysts',
#   'MCA/ACS',
#   '"Chemlstry',
#   '19591971.',
#   'A',
#   '03624:!'],
#  ['acqulsltlons',
#   '1973,',
#   'by',
#   'm',
#   '1973,',
#   'th',
#   'prlnted.',
#   'III.',
#   'ummmns.',
#   '1015:',
#   'Meetlng.',
#   'Reglstratlon.',
#   'by',
#   'mg',
#   '1::',
#   'brlng',
#   'Hlth',
#   'Commlttee',
#   'thls',
#   'reglstratlon',
#   'mm',
#   '1214,',
#   '10712,',
#   'by',
#   'a',
#   '1nvolv1ng',
#   'supplementlng',
#   'testlng',
#   '1973,',
#   'Exhlblt',
#   'A.',
#   'by',
#   'cm',
#   '012531',
#   'MOTION.',
#   'voTED:',
#   'A,',
#   '1C7',
#   'Subcommlttee',
#   'Studylng',
#   'm',
#   'by',
#   'subcommlttEE,',
#   'whlch',
#   'B.',
#   'MOTION.',
#   'voTED:',
#   'B.',
#   'Hlth',
#   '1::',
#   'meetlngs',
#   '1973774',
#   'meetlngs,',
#   'subcommlttee',
#   '1::',
#   'Commlttee',
#   'm',
#   'by',
#   'a',
#   'Commlttee',
#   'Exhlblt',
#   'by',
#   'Commlttee',
#   'MOTION.',
#   'voTED:',
#   'Commlttee',
#   'Exhlblt',
#   '(E7',
#   'Membershlp',
#   'Commlttee.',
#   'Membershlp',
#   'Commlttee',
#   'appllcatlons',
#   ',',
#   'Membershlp',
#   'Commlttee',
#   'appllcants',
#   'membershlp',
#   '0N',
#   'MOTION.',
#   'voTED:',
#   'appllcants',
#   'membershlp',
#   'cm',
#   '012532',
#   'A',
#   'Vlnyl',
#   'testlng',
#   'vmyl',
#   'admlnlstratlon.',
#   'a',
#   'mm',
#   'supportlng',
#   'testlng',
#   'scrlptlon',
#   'antlclpated',
#   'ranglng',
#   'a',
#   'mmmum',
#   '572,000',
#   'a',
#   '$92,000.',
#   '(13115..',
#   'A',
#   'testlng',
#   'cm',
#   '012533'],
#  ['B',
#   'mmmcmnms',
#   'AVENUE.',
#   'N.',
#   'WASHINGTON.',
#   '20009',
#   '12027',
#   '49375125',
#   'Commlttee:',
#   'R.',
#   'thls',
#   'commlttee,',
#   'Commlttee',
#   'meetlng,',
#   'Hlth',
#   'llmlted',
#   'Washlngton',
#   'A',
#   'prellmlnary',
#   'Commlttee',
#   'm',
#   'commlttee',
#   'thls',
#   'a',
#   'flrst',
#   'by',
#   'Commlttee',
#   'Hlth',
#   'a',
#   'servlng',
#   'commlttees',
#   'Washlngton',
#   'm',
#   'a',
#   'm',
#   'commlttee',
#   "MCA'S",
#   'by',
#   'ellmlnatlng',
#   'layerlng,',
#   'actlvltles',
#   "MCA'S",
#   'meetlngs',
#   'addltlonal',
#   'technlcal',
#   'commlttees,',
#   'a',
#   'actlvlty',
#   'by',
#   'A.',
#   'Commlttees',
#   'ellmlnated.',
#   '035303',
#   'regardlng,',
#   'crltlcal',
#   'meetlngs',
#   'Washlngton',
#   'facllltate',
#   'mm',
#   'A',
#   'lngs',
#   '1973774',
#   'B.',
#   'technlcal',
#   'commlttees',
#   'CommlttEE,',
#   'mm',
#   'addltlon',
#   '1::',
#   'actlvltles,',
#   'MCAl',
#   'a',
#   'commlttees.',
#   'whlch',
#   'a',
#   'beglns.',
#   'Commlttee',
#   'a',
#   'crltlcal',
#   '1nd1cate',
#   'whlch',
#   'A',
#   'outllnlng',
#   '1973774',
#   'sollcltlng',
#   'partlclpatlon.',
#   'Meetlngs',
#   'meetlngs',
#   'by',
#   'mm',
#   'meetlngs.',
#   'mm',
#   'whlch',
#   'meetlng.',
#   'a',
#   'regardlng',
#   'meetlngs,',
#   'meanlngful',
#   'llmlted',
#   'Provldlng',
#   'a',
#   'contrlbutlon',
#   'by',
#   'thls',
#   'partlclpatlon',
#   'by',
#   'permltted',
#   'dlmlnlsh',
#   'Commlttee.',
#   'flrst',
#   "MCA'S",
#   'provldlng',
#   'Hlth',
#   '035304',
#   'by',
#   'a',
#   'brlng',
#   'm',
#   'technlcal',
#   'pendlng',
#   'commlttees.',
#   'accompllshments',
#   'Commlttees',
#   'a',
#   'a',
#   'prevalllng',
#   'th',
#   'Onsithlrd',
#   'commlttees',
#   'whlch',
#   '1nv1ted',
#   'meetlng.',
#   'thls',
#   'plannlng',
#   'Washlngton',
#   'meetlngs',
#   '(January',
#   'meetlngs',
#   'crltlcal',
#   'th',
#   'B',
#   'mm',
#   'mm',
#   'meetlngs,',
#   'm',
#   'mg',
#   'tendlng',
#   'by',
#   'provldlng',
#   'a',
#   'whlch',
#   'contrlbu',
#   's',
#   '1n51ght',
#   'tlvltles.',
#   'Actlvlty',
#   'technlcal',
#   'commlttees,',
#   'stymled',
#   'by',
#   'commlttees',
#   'by',
#   'a',
#   'try',
#   'y',
#   'm',
#   'a',
#   'unanlmlty',
#   'mm',
#   'ty',
#   'Commlttee',
#   '035305',
#   'A',
#   'm',
#   'Meetlngs',
#   'Meetlng.',
#   '111.',
#   'ofReport',
#   'ecretaryiTreasurer.',
#   'meetlng;',
#   'actlvltles',
#   '1nd1cated,',
#   'mm',
#   'Dlr',
#   's',
#   '.',
#   'Technlcal',
#   'Commlttees.',
#   'A',
#   '035305'],
#  ['T',
#   'B',
#   '1::',
#   "Industry's",
#   'I',
#   '(Hart',
#   '3111',
#   '11577',
#   'r',
#   'a',
#   'blll',
#   '11577',
#   'm',
#   'mg',
#   '1ndustry.',
#   'Hearlngs',
#   'Subcommltt',
#   'e',
#   'Commlttee',
#   'thls',
#   'y',
#   'hearlngs',
#   '1::',
#   'b111,',
#   'y',
#   'A',
#   '1::',
#   'n',
#   'wml',
#   'llttle',
#   '1::',
#   'a',
#   'a',
#   'hearlngs',
#   'a',
#   'whlch',
#   'r',
#   'posslble',
#   'thls',
#   'hearlngs',
#   '1ndustry.',
#   't',
#   'a',
#   'mm',
#   '1ndustry,',
#   'stry',
#   's',
#   'appear...nor',
#   'commlttees',
#   'm',
#   'a',
#   'contlngencles.',
#   'Accordlngly,',
#   'a',
#   'tr',
#   '1:,',
#   'mgnly',
#   '1t1VE,',
#   'a',
#   'restralnlng',
#   'talnlng',
#   'Th',
#   'a',
#   '$17,537.',
#   'd',
#   's',
#   'T',
#   'e',
#   'p',
#   'a',
#   'm',
#   'A',
#   '039330'],
#  ['exhlblt',
#   'by',
#   'Wllllam',
#   'J',
#   '.',
#   'v',
#   'b',
#   'mmsmmr',
#   '...1n',
#   'hls',
#   'whlch',
#   'whlch',
#   'Speclflcally,',
#   'sharlng,',
#   'addltlon',
#   'm',
#   'stresslng',
#   'sendlng',
#   'm',
#   'a',
#   'admlnlstratlve',
#   '1nd1cated',
#   'concernlng:',
#   'A',
#   'wlth',
#   'm',
#   'a',
#   '1nvolv1ng',
#   'a',
#   'flnanclng',
#   'Admlnlstratlon',
#   'studylng',
#   'a',
#   'a',
#   'thls',
#   'cousngss...',
#   'H111',
#   'Slghts',
#   'by',
#   'H111',
#   'pestlcldes',
#   'b111,',
#   '2770,',
#   '1::',
#   'prlnclple',
#   'by',
#   'CommlttEE,',
#   'by',
#   'pestlclde',
#   'b111,',
#   '10729,',
#   'by',
#   'Commlttee',
#   'H111',
#   'posslble.',
#   'cm',
#   '036161',
#   'whlch',
#   'by',
#   'Subcommlttee',
#   'actlng',
#   'm',
#   'thls',
#   'a',
#   'by',
#   'commlttee',
#   'wlth',
#   'by',
#   'a',
#   'transmltted',
#   'concernlng',
#   'whlch',
#   'deflnltlon',
#   'a',
#   'certlflcatlon',
#   'a',
#   '1nc1dent',
#   'certlflcatlon.',
#   'H111',
#   'mlsslon',
#   '1971.',
#   'months.',
#   '1971,',
#   'whlch',
#   'posslbly',
#   'strlngent',
#   'a',
#   'Subcommlttee',
#   'conductlng',
#   'hearlngs',
#   'flrst',
#   'Commlsslon',
#   'by',
#   'A',
#   'concernlng',
#   'thls',
#   '9247,',
#   '"ceasemandideslst"',
#   'b111,',
#   'by',
#   'CommlttEE,',
#   '"ceasemandideslst"',
#   'm',
#   'thls',
#   '7130,',
#   'by',
#   'Commlttee',
#   'Subcommlttee',
#   'whlch',
#   '$2.25',
#   'cmnz~1~2',
#   'strlke',
#   'a',
#   'strlke.',
#   '.',
#   'submltted',
#   'a',
#   'm',
#   'requestlng',
#   '1:,',
#   'a',
#   'mm',
#   'by',
#   '(RrDreJ',
#   '(R.7N.Y.7',
#   'Commlttee',
#   'hearlngs',
#   'wlthln',
#   'a',
#   'a',
#   'Arbltratlon',
#   'strlke',
#   'permltted',
#   'Arbltratlon',
#   'wlthln',
#   'months.',
#   '35967,',
#   'thch',
#   'strlkes',
#   '1ndustry.',
#   's',
#   'llmlted',
#   'strlke',
#   'H111',
#   'dlfflcult',
#   'antlistrlke',
#   'Admlnlstratlon',
#   'm',
#   'provldlng',
#   'a',
#   'mm',
#   'restrlctlve',
#   '(5.',
#   '2592mm.',
#   '109147,',
#   'recelvlng',
#   'Pollcy,',
#   'commlttee',
#   'a',
#   'mg',
#   'm',
#   'whlch',
#   'mlght',
#   'by',
#   'thls',
#   'hearlngs.',
#   'Commlttee',
#   '1971,',
#   '2754,',
#   'whlch',
#   'Admlnlsi',
#   'a',
#   'hearlngs',
#   'by',
#   "Commlttee's",
#   'Subcommlttee',
#   'Commlttee',
#   'wrltten\\test1mony',
#   'submltted.',
#   'A',
#   'H111',
#   'wlth',
#   'expandlng',
#   'comrrmg...',
#   '...wh1ch',
#   'establlshed,',
#   '1::',
#   'flrst',
#   'm',
#   'by',
#   'hls',
#   'commlttee',
#   'ls',
#   'by',
#   'Wllllam',
#   'Wllllams',
#   'ls',
#   'servlng',
#   '..',
#   '.',
#   '...w111',
#   'hearlngs',
#   'emlsslon',
#   'concernlng',
#   'berylllum',
#   'Clty,',
#   'wlth',
#   '197m,',
#   "EPA'S",
#   'Admlnlstrator:',
#   'emlsslon',
#   'exlstlng',
#   'whlch',
#   '61nd:',
#   'm',
#   'a',
#   'emlsslons',
#   'flrst',
#   'H111',
#   'hls',
#   'partlclpatlng',
#   'hearlngs.',
#   'whlch',
#   'by',
#   'Instltute.',
#   '*emlsslons',
#   'nltrlc',
#   'by',
#   'EPA,',
#   'wlth',
#   'munlclpaltype',
#   '1nc1nerators.',
#   'submltted',
#   'llttle',
#   'a',
#   'representlng',
#   "1ndustry's",
#   'capaclty,',
#   '1::',
#   'emlsslons',
#   '1nv1ted',
#   'm',
#   'm',
#   'technlcal',
#   'llmlted',
#   'publlsh',
#   'mg',
#   'whlch',
#   'technlcal',
#   'speclallsts',
#   'cm',
#   'n35154',
#   'r',
#   'cmmmc...',
#   '...the',
#   '2nnn',
#   '1::',
#   '1971.',
#   '1nc1dents',
#   '1nvolv1ng',
#   'translt.',
#   '51mply',
#   'm',
#   'conflrm',
#   "cammm's",
#   'A',
#   'Slgnk',
#   'dwlndllng',
#   'asslgned',
#   'Asslstance',
#   'ranglng',
#   'm',
#   'twoithlrds',
#   '1nc1dents',
#   '1nvolv1ng',
#   'cmmmc',
#   'plannlng,',
#   'antlclpated',
#   'thls',
#   'H111',
#   'conflrms',
#   'Valldlty',
#   'W',
#   'provldlng',
#   'shlppers.',
#   's',
#   'm',
#   'cammm',
#   'thls',
#   'by',
#   'cmmmc',
#   'H111',
#   'by',
#   '1::',
#   ':7.',
#   'Franclscm',
#   'asslstance',
#   'by',
#   'Counclls',
#   'PHTHALATES...',
#   'plastlclzers',
#   'plastlcs,',
#   'polyvlnyl',
#   'Calllng',
#   '...m',
#   'by',
#   'cm',
#   '036165',
#   'a',
#   'a',
#   'technlcal',
#   'm',
#   'A',
#   'thls',
#   't',
#   '0F',
#   'STANDARDS...',
#   'publlshed',
#   'a',
#   '"World',
#   'Plastlcs',
#   'Standards,"',
#   'a',
#   'snnn',
#   'plastlcs',
#   'whlch',
#   'n:352',
#   ',',
#   '$5.50',
#   'Prlntlng',
#   'Washlngton,',
#   '2nqn2.',
#   '”.5“',
#   'Asslstant',
#   'm',
#   'Dlvlslon',
#   'A.',
#   'H111',
#   'cm',
#   '036166'],
#  ['A',
#   'oncernlng',
#   'Commlttee',
#   'Membershlp',
#   'u',
#   'a',
#   '1970,',
#   'o',
#   'Commlttee,',
#   'r',
#   'membershlp',
#   'o',
#   'thls',
#   'commlttee.',
#   'M',
#   '.',
#   'resentlng',
#   'a',
#   '"General',
#   'Prlnclples',
#   'Appllcable',
#   'm',
#   'Commlttees"',
#   'th',
#   't',
#   'membershlp',
#   'restrlcted',
#   'm',
#   'Th',
#   '1971,',
#   'reconflrmatlon',
#   'by',
#   'm',
#   'a',
#   'A1',
#   'Commlttee,',
#   'rd',
#   'cc',
#   'cm',
#   '035159',
#   'ST',
#   'F',
#   'cernlng',
#   'A1',
#   'Commlttee',
#   'Membershlp',
#   'Fr',
#   'k',
#   'L.',
#   'Commlttee',
#   '1949,',
#   'outstandlng',
#   'contrlbutor',
#   'ts',
#   '"General',
#   'Prl',
#   'Appllcable',
#   'Commlttees"',
#   '1n1tlatlve',
#   'commlttee',
#   'membershlp',
#   'd',
#   'd',
#   'thls',
#   'praiexlstlng',
#   'menlbershlp',
#   'undlsturbed.',
#   '(:1',
#   'WinsDn,',
#   'a',
#   'B05',
#   'd',
#   '1nd1cates',
#   'recognltlon',
#   'ms',
#   'membershlp',
#   'commlttees',
#   'by',
#   'Commlttee',
#   'tln',
#   'a',
#   'partlclpatlon.',
#   'ms',
#   'ershlp',
#   'thls',
#   'trl',
#   'm',
#   "Commlttee's",
#   'J01',
#   't',
#   'Subcommlttee',
#   'rdlngly,',
#   'a',
#   'settlng',
#   'a',
#   'recognltlon',
#   'by',
#   'Commlttee',
#   'ly',
#   'Dlr',
#   'membershlp',
#   'Commlttee',
#   'quallflcatlon,',
#   '3515“'],
#  ['D',
#   '13mm:',
#   'mmmmmms',
#   'BARTON.',
#   'a',
#   "Commlttee's",
#   'actlvltles.',
#   'my',
#   '1975,',
#   'I',
#   'contrlbutlons',
#   'Chemlsts',
#   'I',
#   'remlss,',
#   'I',
#   'I',
#   'descrlbed',
#   'opportunlty"',
#   'amendlng',
#   'posltlve',
#   'actlvlty',
#   'enforclng',
#   'Act...as',
#   'dld',
#   'a',
#   'cases...but',
#   'emerglng',
#   'llttle',
#   'a',
#   'opportunlty"',
#   'fluenclng',
#   'strlngent',
#   'ngm',
#   'rlghts,',
#   'crltlcal,',
#   'deflnlng',
#   '"slgnlflcant',
#   'arbltrary',
#   'mm',
#   '"plannlng"',
#   'a',
#   'Hlth',
#   'I',
#   'Commlttee',
#   'submltted,',
#   'amendments...as',
#   'obtalned...but',
#   'posltlve',
#   'I',
#   'I',
#   'Commltt',
#   'dlllgence',
#   'attemptlng',
#   'm',
#   'brlng',
#   '1513mm.',
#   '035912',
#   'r',
#   'proceedlngs.',
#   'whlch',
#   '5:111',
#   'EPA,',
#   'Hlth',
#   'j',
#   'III',
#   'emlsslons',
#   'whlch',
#   '>',
#   'constltute"',
#   'a',
#   'courSE,',
#   "Agency's",
#   'll2...the',
#   'provlslon...to',
#   'emlsslons',
#   'mlst',
#   '.',
#   'III',
#   'a',
#   'efflclency',
#   'approach...best',
#   'Hill...fthlch',
#   'thls',
#   "Commlttee's",
#   'propenslty',
#   '1nd1v1dual',
#   'lltlgate',
#   'waltlng...',
#   'thls',
#   'by',
#   'technlcal',
#   'I',
#   'a',
#   'hydrocarboniphotochemleal',
#   'February...',
#   'a',
#   'publlshed',
#   'EPA.',
#   'r',
#   'emlsslons',
#   'oxldant...or',
#   'smog...fom1ng',
#   'tlghteniup',
#   'emlsslon',
#   '1::',
#   'control.requ1rements,',
#   '"Rule',
#   'photochemlcallyireactlve',
#   '11mm:',
#   '"Volatlle',
#   'thls',
#   'shlft',
#   'by',
#   'by',
#   "EPA'S",
#   'asslstance.',
#   'th',
#   'y',
#   'by',
#   'Instltute',
#   'a',
#   "EPA'S",
#   'CMADM913',
#   'a',
#   'Commlttee',
#   'ch',
#   'leadershlp',
#   'a',
#   'technlcal',
#   'A11“',
#   'Commlttee',
#   'Texas...where',
#   'shlfted',
#   'Commlttee',
#   'whlch',
#   'emlsslon',
#   'deflnltlve',
#   'relatlonshlps',
#   'Speclflc',
#   'fundlng',
#   "Councll's",
#   'a',
#   "Commlttee's",
#   'dlfflcult',
#   'a',
#   'thls',
#   'a',
#   '1nv1ted',
#   'partlclpatlon',
#   'Reactlvlty',
#   'whlch',
#   'mg',
#   'supportlng',
#   'I',
#   'a',
#   'I',
#   '$100,000',
#   'a',
#   'thls',
#   'effort...and',
#   'I',
#   '$50,000,',
#   'a',
#   'speclflc',
#   '1::',
#   'whlch',
#   "EPA'S",
#   'posslble',
#   'whlch',
#   'I',
#   'thls',
#   "Commlttee's",
#   'flrst',
#   'I',
#   '1ntercomm1ttee',
#   'actlvltles',
#   'whlch',
#   "AQC'S",
#   'Turnlng',
#   'Commlttee',
#   'Actlvlty...one',
#   'whlch',
#   'a',
#   'by',
#   'commlttee',
#   'year...we',
#   'by',
#   'commlttee',
#   'resolvlng',
#   'commlttee',
#   'relatlonshlp',
#   'sensltlve',
#   '035914',
#   'whlch',
#   '1n1tlatlon',
#   'whlch',
#   'enllghtenment.',
#   'Thls,',
#   'I',
#   'Commlttees',
#   'staff...and.',
#   'membershlp',
#   'MCA.',
#   'Addltlonally,',
#   'I',
#   'by',
#   'a',
#   'commlttee',
#   'm',
#   'staff/Comnlttee',
#   'confllcts.',
#   'I',
#   'remalnlng',
#   'whlch',
#   'I',
#   'requlre...1ndeed',
#   'demand...a',
#   'technlcal...legal',
#   'partnershlp',
#   'm',
#   'maxlmlze',
#   'Hlth',
#   'worklng',
#   'Commlttee',
#   'thls',
#   'dlfflcult',
#   'Commlttee',
#   'a',
#   'partlclpatlng',
#   'meetlngs',
#   'I',
#   'brlng',
#   'I',
#   '"Tami',
#   'porarlly"',
#   'resolved...problem',
#   'I',
#   'a',
#   'strengthisapplng',
#   'thls',
#   'ex1sts~but',
#   'by',
#   'commlttee.',
#   'a',
#   'b',
#   't',
#   'I',
#   'c',
#   'I',
#   'my',
#   'by',
#   'A',
#   'a',
#   'I',
#   'A11“',
#   "Commlttee's",
#   'fr',
#   'm',
#   'Th',
#   'a',
#   'soph15*',
#   'nlngful',
#   'contrlbutlons',
#   'm',
#   'I',
#   'envlslon',
#   'a',
#   'ommlttee/staff',
#   'necesslty',
#   'bulldlng...',
#   'properly...1mage',
#   '=',
#   'cm',
#   '035915',
#   'convlnce',
#   't',
#   'unportantly,',
#   'a',
#   'a',
#   'st',
#   'enterprlse',
#   'a',
#   'cl',
#   'my',
#   'clvll',
#   'w',
#   'I',
#   '035915'],
#  ['Exhlblt',
#   'E',
#   'ummmns',
#   'P.',
#   'BRIDGE.',
#   'soLm',
#   'Commlttee',
#   '(stcy',
#   '"Hazardous',
#   'stc',
#   '1nd1cated',
#   'actlvlty',
#   'restrlctlve',
#   'I',
#   'forebodlngs',
#   'I',
#   'qulckly',
#   'slmllar',
#   'thls',
#   'flrst',
#   'Hlth',
#   '197D.',
#   'actlvlty',
#   'thls',
#   'a',
#   'reachlng',
#   'slgnlflcantly',
#   'stc',
#   'worklng',
#   'concernlng',
#   'Commlttee',
#   '3111',
#   'by',
#   'Jennlngs',
#   'Commlttee,',
#   'commlttee',
#   'worklng',
#   'by',
#   'Admlnlstratlon',
#   'a',
#   'mm',
#   '1nd1cated',
#   '2150.',
#   '1::',
#   'mm',
#   "Randolph's",
#   'mm',
#   '"Hazardous',
#   'compllcated',
#   'permlts',
#   'a',
#   'addltlon',
#   'cm',
#   '035917',
#   'a',
#   'recycllng.',
#   'worklng',
#   '1::',
#   'toxlclty,',
#   'quantlty',
#   'a',
#   'thls',
#   'restrlcts',
#   'speclflc',
#   'packaglng,',
#   'a',
#   'm',
#   'a',
#   'technlcal',
#   'strlve',
#   'sufflclent',
#   'flexlblllty',
#   ',',
#   'mm',
#   'thls',
#   'actlvlty,',
#   'by',
#   'whlch',
#   'stc',
#   'whlch',
#   'mlght',
#   'addltlon',
#   'Hlth',
#   '(NSWMA7',
#   'm',
#   'a',
#   'by',
#   'A1',
#   'stc',
#   'actlvlty',
#   'thls',
#   'stC',
#   "Commlttee's",
#   'asslstance',
#   'thls',
#   'whlch',
#   'a',
#   'cm',
#   '035919',
#   'A',
#   'stc',
#   'meanlngful',
#   'Hlth',
#   'EPA.',
#   'a',
#   'm',
#   'establlsh',
#   'a',
#   'sclentlflc',
#   '5:111',
#   'complylng',
#   'mm',
#   'strlngent',
#   'enabllng',
#   'stc',
#   "EPA'S",
#   'opportunlty.',
#   'stc',
#   'Hlth',
#   'EPA:',
#   '20721,',
#   'meetlng,',
#   "EPA'S",
#   '105nm?)',
#   'a',
#   'mllllon',
#   'landflll',
#   'mm',
#   'm',
#   '5111',
#   'technlques.',
#   'thls',
#   '1975,',
#   'meetlngs',
#   'stc',
#   'a',
#   'a',
#   '1::',
#   'a',
#   'Hlth',
#   "EPA'S",
#   'Dlvlslon,',
#   'Munlclpal',
#   'Clnclnnatl,',
#   'Hlth',
#   'a',
#   'stc',
#   'meetlng.',
#   'stc',
#   'a',
#   'posslbllltles',
#   'contractlng',
#   '£111',
#   'exlstlng',
#   'landflll',
#   'actlvltles.',
#   'actlvlty,',
#   'by',
#   'Technlcal',
#   'Subcommlttee.',
#   'A',
#   'recycllng',
#   'by',
#   'Technlcal',
#   'posltlve',
#   'm',
#   'mm',
#   'A',
#   'subcommlttEE,',
#   'stc',
#   'CommlttEE,',
#   'publlshed.',
#   'cm',
#   '035919',
#   'm',
#   'stc',
#   'commlttees.',
#   '1n51dlous',
#   'punltlvely',
#   'CPI.',
#   'm',
#   'a',
#   '1mpllcatlons',
#   'thls',
#   'conslstlng',
#   'commlttees.',
#   'establlshed',
#   "stC's",
#   'Hlth',
#   'posslble',
#   'unpllcatlons',
#   'a',
#   'deflnlte',
#   'mm',
#   'exlstlng',
#   'actlvlty,',
#   'Subcommlttee',
#   'msgm',
#   'thls',
#   'by',
#   '1975.',
#   '1::',
#   'm',
#   '1975.',
#   'e',
#   'by',
#   'L',
#   'Commlttee',
#   'r',
#   'm',
#   'by',
#   't',
#   'asslstance',
#   'p',
#   'by',
#   's',
#   'c',
#   'asslstance.',
#   'Th',
#   'pr',
#   'technlcal',
#   'Hlth',
#   '1Ve',
#   'asslstance',
#   'a',
#   'm',
#   'h',
#   'n',
#   'whlch',
#   'hlghllghted',
#   'm',
#   'stc',
#   'Commlttee',
#   'meetlngs',
#   'commlttee',
#   'M',
#   'admlnlstratlve',
#   'by',
#   'whlch',
#   'A5',
#   'a',
#   'tlngs',
#   'commlttee',
#   'meetlngs',
#   'a',
#   'A',
#   'm',
#   'asslgned',
#   'mm',
#   'stc',
#   'capaclty.',
#   'ddltlon',
#   'm',
#   'conslstent',
#   'm',
#   'stc',
#   'actlvltles.',
#   'a',
#   'I',
#   'a',
#   'mg',
#   'commlttee',
#   'a',
#   'admlnlstratlon',
#   'lvlng',
#   'commlttees.',
#   'stc',
#   'mm',
#   'a',
#   'ms',
#   'accompllshed',
#   '~',
#   'technlcally',
#   'technlcal',
#   'whlch',
#   'llnk',
#   'P.',
#   'Brldge,',
#   'cm',
#   '035921'],
#  ['Exhlblt',
#   'E',
#   'BY',
#   'M',
#   '0N',
#   'Commlttee',
#   'by',
#   'mldiJune.',
#   "Commlttee's",
#   "'",
#   'posslble',
#   '51mply',
#   'whlch',
#   'a',
#   'Conxnlttee,',
#   '1nd1cated',
#   'a',
#   'a',
#   'dlstlnct',
#   'posslblllty.',
#   'commlttee',
#   'mm',
#   'llttle',
#   '1ndustry.',
#   'llmltatlons',
#   'restrlctlons',
#   'blll',
#   '13.11.',
#   '105127.',
#   'Conmlctee',
#   '5:111',
#   'a',
#   'W',
#   'a',
#   'a',
#   'W',
#   'reformlnded',
#   'a',
#   'm',
#   'dE*',
#   'subsldlarles,',
#   'restrlct',
#   'ellmlnate',
#   '(AER)',
#   'cm',
#   '035997',
#   'convlnce',
#   'a',
#   'by',
#   'E.',
#   'secondiranklng',
#   'Commlttee.',
#   'addresslng',
#   "MCA'S",
#   'offlclals',
#   'm',
#   'Commlttee.',
#   'savlngs',
#   '1nd1cated',
#   'by',
#   'Admlnlstratlon',
#   'by',
#   'ellmlnate',
#   'm',
#   'flrmly',
#   'competltlve',
#   'Commlttee',
#   'mm',
#   'constltuent',
#   'thls',
#   'm',
#   'Commlttees',
#   'flrst',
#   '(PL',
#   '9175047.',
#   '"slgnlflcant',
#   'establlsh',
#   'I',
#   'addltlonal',
#   'Commlttees',
#   'classlflcatlon',
#   "EPA'S",
#   'thls',
#   'thlnly',
#   'cm',
#   '035999',
#   'by',
#   'leadershlp',
#   'dE*',
#   'b111,',
#   's',
#   '3219.',
#   'M055',
#   'restrlctlons',
#   'a',
#   'Commlsslon',
#   'Quallty,',
#   'establlshed',
#   'b111,',
#   'technlcal',
#   'm',
#   'By',
#   'Aprll,',
#   '1nd1catlon',
#   'backlng',
#   'm',
#   'solldlfy',
#   'urglng',
#   'mm',
#   'thls',
#   'posslble,',
#   'ﬁlls',
#   'mlght',
#   'Commlttee',
#   '1::',
#   'proceedlng.',
#   'PASS7',
#   'Commlttee',
#   'utlllzatlon',
#   'Commlttee',
#   'Jennlngs',
#   'mrwnla.)',
#   '2150,',
#   'resultlng',
#   'hearlngs',
#   '1975.',
#   'Commlttee',
#   'a',
#   'worklng',
#   'prlnt',
#   'b111,',
#   'whlch',
#   'a',
#   'whlch',
#   'Subcommlttee',
#   'flrst',
#   'whlch',
#   'Subcommlttee',
#   'hearlngs',
#   'cm',
#   '035999',
#   'submltted',
#   'Commlttee.',
#   'dld',
#   'mm',
#   'Subcommlttee',
#   'commlttee',
#   'overslght',
#   'hearlngs',
#   'a',
#   'Subcommlttee',
#   'hearlngs',
#   'Overslght',
#   'posslble',
#   'by',
#   '1::',
#   'Judglng',
#   '3111,',
#   'a',
#   'posslblllty',
#   'thls',
#   'ownsmm',
#   'Hearlngs',
#   'Subcomnlttee',
#   'thls',
#   'Subcommlttee',
#   'Instltute',
#   'Subcomnlttee',
#   'Asslstant',
#   'OSHA.',
#   'a',
#   'MCA,',
#   'E.',
#   'Chrlstofano,',
#   'Commlttee.',
#   'Chrlstofano',
#   'cm',
#   '035990'],
#  ['Exhlblt',
#   'F',
#   '13mm:',
#   'ummmns',
#   'mmmcmnms',
#   'A.',
#   'SUNSHINE.',
#   'DRUG,',
#   'cosMETIc',
#   'a',
#   'actlvltles',
#   'FDCC',
#   'Commlttee',
#   'mm',
#   'my',
#   'mm',
#   'Commlttee',
#   'FDCC',
#   'Commlttee',
#   '"To',
#   'thp',
#   'concernlng',
#   'cosmetlcs,',
#   'mm',
#   'mg',
#   'prlnclples',
#   'technlcal',
#   'm',
#   'Hlth',
#   'responslbllltles',
#   'actlvltles',
#   'Commlttee',
#   'unplementlng',
#   '1n1tlated',
#   'establlshed',
#   'conslsts',
#   'a',
#   'subcommlttee,',
#   'a',
#   'sclentlflc',
#   'subcommlttee,',
#   'a',
#   'subcommlttEE,',
#   'whlch',
#   'subcommlttees.',
#   'subcommlttee,',
#   'by',
#   'referrlng',
#   'Commlttee',
#   'by',
#   'establlshlng',
#   'a',
#   'dlvlslon',
#   'ellmlnatlng',
#   'meetlngs,',
#   'Commlttee',
#   'mm',
#   'speclflc',
#   'asslgni',
#   'dlvlslon',
#   '035991',
#   'Commlttee',
#   'submltted',
#   'Admlnlstratlve',
#   'by',
#   'a',
#   '1::',
#   'constltute',
#   'a',
#   'speclflcally',
#   'by',
#   'submlsslon."',
#   'admlnlstratlon',
#   'by',
#   'a',
#   'thls',
#   'submlsslon',
#   'FDA.',
#   'whlch',
#   'submltted',
#   'a',
#   'llmltatlon',
#   'hearlngs,',
#   'establlshment',
#   'whlch',
#   'constltuted',
#   'a',
#   'whlch',
#   'a',
#   'rlght',
#   'a',
#   'hearlng.',
#   'Varylng',
#   'a',
#   'codlflcatlon',
#   'exlstlng',
#   'a',
#   "restrlct'",
#   'rlghts',
#   '1nd1v1duals',
#   "agency's",
#   'jurlsdlctlon',
#   'm',
#   'whlch',
#   'by',
#   'subcommlttee',
#   'Survelllance',
#   '13111',
#   '5.541.',
#   'orlglnally',
#   'applylng',
#   'processlng',
#   'establlshi',
#   'thls',
#   'unpllcatlons',
#   'extendlng',
#   'survelllance',
#   'establlshment',
#   'Hlthln',
#   'codlng,',
#   'keeplng,',
#   'addltlon',
#   '13111',
#   'requlrlng',
#   'reglstratlon',
#   'establlshments.',
#   'a',
#   '13111',
#   '1n5t1tutlon',
#   'a',
#   'Cltlzens',
#   'clvll',
#   '13111.',
#   'Addltlonally,',
#   '13111',
#   'addltlon',
#   'actlvltles.',
#   'Commlttee',
#   'FCC',
#   'FAD/WHD',
#   '035992',
#   'actlvltles',
#   'sclentlflc',
#   'mm',
#   'a',
#   'technlcal',
#   'by',
#   'thls',
#   'addltlon.',
#   'technlcal',
#   'mm',
#   'actlvltles',
#   'PMA,',
#   'Hlth',
#   'GMA,',
#   'A',
#   'Hlthln',
#   'commlttee',
#   'a',
#   'a',
#   'a',
#   'establlshment',
#   'a',
#   "publlc's",
#   'understandlng',
#   '1ndustry.',
#   'descrlbe',
#   'actlxk,',
#   'a',
#   "Commlttee's",
#   'actlvltles',
#   'thls',
#   'Commltt',
#   'responslbllltles',
#   'MCA.',
#   'llght',
#   'exlsts',
#   'thls',
#   'a',
#   'strlvlng',
#   'm',
#   'Hlth',
#   'superflclally',
#   'dlllgent',
#   'FDCC',
#   'CommlttEE.',
#   'a',
#   'actlvlty',
#   'thls',
#   'courSE,',
#   'a',
#   'whlch',
#   'thls',
#   'actlvltles',
#   'I',
#   'thls',
#   'whlch',
#   'commlttee',
#   'worklng',
#   'I',
#   'thls',
#   '035993',
#   '5::',
#   'e',
#   'I',
#   'thls',
#   'a',
#   'commlttee',
#   'leadershlp',
#   'commlttee',
#   'm',
#   'x',
#   'thls',
#   'glv',
#   'a',
#   'I',
#   'c',
#   'A',
#   '035994'],
#  ['Exhlblt',
#   'G',
#   'T-E',
#   'ummmns',
#   "MANUFACTURI'G",
#   'A.',
#   'CWFFENBERG,',
#   '0N',
#   'ursmmmmu',
#   'commm',
#   'Dlstrlbutlon',
#   'Commlttee',
#   'a',
#   'I',
#   'restrlcted',
#   'my',
#   'nlflcance',
#   'h-Vlng',
#   '1ndustry.',
#   'A',
#   't',
#   'e',
#   "Commlttee's",
#   'actlvltles',
#   'my',
#   'my',
#   'I',
#   '57,000',
#   'by',
#   'a',
#   '11.071',
#   '23.914',
#   'pr',
#   'dependlng',
#   'r51]:',
#   'a',
#   'c-nslderatlon',
#   'a',
#   'supplylng',
#   '1954,',
#   'a',
#   'A',
#   'a',
#   'a',
#   '1ndustry,',
#   'by',
#   'a',
#   'a',
#   'establlshed',
#   '1954.',
#   'w',
#   'Commlsslon',
#   'Hlth',
#   'thls',
#   '1971,',
#   'declsl-',
#   'm',
#   'tabllshed',
#   'a',
#   'm',
#   'by',
#   'establlshed',
#   '1959.',
#   'T',
#   '-',
#   '35537',
#   '1n5t1tuted',
#   'by',
#   't',
#   'm',
#   'a',
#   'lltlgants.',
#   'a',
#   'by',
#   'Dlvlslon',
#   'my',
#   "MCA'S",
#   '~',
#   'Instltute,',
#   'Instltute',
#   'Allled',
#   'accompllshes',
#   'followlng:',
#   'm',
#   'thlrty',
#   'by',
#   '2271/21.',
#   '1975.',
#   '1971.',
#   'addltlonal',
#   'I',
#   "dustry's",
#   'cm',
#   '035995',
#   '51n<.e',
#   'upw.rd',
#   'a',
#   'T',
#   'e',
#   'a',
#   'm',
#   'mg',
#   's',
#   'flrst',
#   'a',
#   '$27,000',
#   'a',
#   '23.914',
#   'thls',
#   'by',
#   'a',
#   'a',
#   '$19,500',
#   'a',
#   '21.394.',
#   'Exlstlng',
#   'reasslgned',
#   'establlshi',
#   'by',
#   '105A.',
#   'Hll',
#   'a',
#   'establlshlng',
#   'detemlnlng',
#   'prescrlblng',
#   'w',
#   'sms',
#   '1::',
#   'g',
#   ',',
#   'llght',
#   't',
#   '-',
#   'dlfflcult',
#   'Hlth',
#   '1::',
#   'p',
#   '-scr1bed',
#   'mm',
#   '92,500,',
#   'spllls',
#   'clvll',
#   'spllls',
#   'I',
#   '1nter71ndustry',
#   'commlttee,',
#   '‘',
#   'CA,',
#   'thls',
#   'c',
#   'b111,',
#   'm',
#   'mg',
#   'th',
#   'commlttEE,',
#   'a',
#   'exlstlng',
#   'testlfled',
#   'mm',
#   'mm',
#   '03599.',
#   'by',
#   'mm',
#   'Envlrnmental',
#   "MCA'S",
#   'Admlnlstrator,',
#   'testlfled',
#   '9550,',
#   'by',
#   'dllng',
#   'n',
#   'Commlttee',
#   'a',
#   'a',
#   '$50,000.',
#   'Commlttee',
#   '$5,000,000',
#   'a',
#   '$500,000',
#   'a',
#   'faclllty,',
#   'Commlttee',
#   'a',
#   'a',
#   '550,000',
#   'a',
#   'flrst',
#   'a',
#   '$100,000',
#   'a',
#   'a',
#   '$500,000',
#   'spllls',
#   'a',
#   'concernlng',
#   'spllls',
#   'olvlng',
#   'wlllful',
#   'wlllful',
#   'a',
#   'Commlttee',
#   'by',
#   'thls',
#   'tt',
#   'famlllar',
#   'Hlth',
#   'commlttee',
#   'mm',
#   'a',
#   '"Chrlstmas',
#   'b111,',
#   'a',
#   'by',
#   'thls',
#   '2710,',
#   '9550,',
#   'orlglnal',
#   'ellmlnate',
#   '1::',
#   'publlclty',
#   'm',
#   '1::',
#   'dE*',
#   'T',
#   'e',
#   '1::',
#   'testlfylng',
#   'bllllon',
#   'Hlth',
#   '250,000',
#   'shlpments',
#   '1nvolv1ng',
#   'g',
#   '1959,',
#   'attemptlng',
#   '.',
#   'mm',
#   'a',
#   "DDT'S",
#   '1dent1£1ed',
#   'XT',
#   'by',
#   'a',
#   "MCA'S",
#   'a',
#   'modlflcatlon',
#   '1::',
#   'shlpplng',
#   'CHEKTREC.',
#   'dom-stlcally',
#   'shlpments.',
#   'mg',
#   'by',
#   'a',
#   'a',
#   'cm',
#   '0359";',
#   'M',
#   'ommlttee',
#   'a',
#   'thlrtyislx',
#   'a',
#   'ght',
#   'standlng',
#   'subcommlttees',
#   'mm',
#   'responsmllltyﬁhazamous',
#   'hlghway',
#   'physlcal',
#   'dlstrlbutlon,',
#   'a',
#   'subcommlttee',
#   'comprlsed',
#   'subcommlttee',
#   'commlttee',
#   '1nvolv1ng',
#   'mstmbm',
#   'u',
#   'I',
#   '(Hm',
#   'HMR3',
#   '73710,',
#   'a',
#   'twoidlglt',
#   'a',
#   'a',
#   'glvlng',
#   'a',
#   'DDT',
#   'HMrlD3',
#   'mm',
#   ':-',
#   'mm',
#   'M7103,',
#   'DDT',
#   '1n5t1tuted',
#   'Vltlng',
#   'HMrlm.',
#   'a',
#   '1975.',
#   'whlch',
#   's',
#   '127...Exemptlon',
#   'slmllar',
#   'by',
#   '"Spy',
#   '1:5."',
#   'obtalnlng',
#   'I',
#   't',
#   '1975,',
#   's',
#   'admlnlstrator',
#   'hlghway,',
#   'a',
#   'd',
#   '311‘7-',
#   's',
#   'Hlth',
#   'responslblllty',
#   'Hlth',
#   'M113',
#   '(HMRB)',
#   'whlch',
#   'c',
#   'R311',
#   '1975,',
#   'swltchlng',
#   'mm',
#   'llttle',
#   'justlflcatlon.',
#   'wlthdra',
#   'n',
#   'by',
#   'DDT',
#   'requlrlng',
#   'DDT',
#   'Speclflcatlons',
#   '112A',
#   'contalnlng',
#   'humplng',
#   'rolllng',
#   'swltchi',
#   '=',
#   'whlch',
#   'c',
#   'm',
#   'shlpment',
#   'handlln.',
#   'thls',
#   'arbltrary',
#   'w',
#   'cm',
#   '035999',
#   'III.',
#   '.',
#   'MC732155',
#   'by',
#   '1dent1y,',
#   'acountlng',
#   'dld',
#   'supportlng',
#   '1dent11catlon',
#   'Classlflcatlon',
#   'arbltr.ry',
#   'reclasslflcatlon',
#   'A',
#   'B',
#   'flrst',
#   'LTL',
#   'shlpments',
#   'flrst',
#   'shlpments',
#   'classlflcatlon',
#   'a',
#   'thls',
#   'arbltrary',
#   'by',
#   '(115551',
#   'by',
#   'a',
#   '73,290',
#   'm',
#   '90,000',
#   'frelght,',
#   '11mm:',
#   'welght.',
#   'commlttee',
#   'welghts',
#   'm',
#   'Phy51.l',
#   'Dlstrlbutlon.',
#   'a',
#   'M.',
#   'Dlstrlbutlon',
#   'Commlttee',
#   'meetlng,',
#   'descrlbed',
#   'descrlbed.',
#   'meetlng,',
#   'by',
#   '1ndustry.',
#   'mm',
#   'meetlngs.',
#   'm',
#   'clvll',
#   'P.L.',
#   '927500,',
#   'Envlr-nmental',
#   '1111mm,',
#   '1::',
#   'conslderlng,',
#   'gh',
#   'by',
#   'partlclpated',
#   'hearlngs',
#   'EPA.',
#   'ellmlnates',
#   'appllcai',
#   'm',
#   'cm',
#   '135999',
#   'a',
#   'nd',
#   'a',
#   '"',
#   'Effluentsﬁnegulauons',
#   'Dlsp-sltlon"',
#   '10711,',
#   'Unlverslty',
#   'M.dlson.',
#   'asslgned',
#   'a',
#   'dlscharged',
#   'understandlng',
#   't',
#   'meetlng.',
#   'testlfled',
#   ':1:',
#   'affectlng',
#   '13.11.',
#   '9302,',
#   '7137.',
#   '1975."',
#   'by',
#   'Th',
#   'Admlnlstratlon',
#   'a',
#   'Th',
#   '"Truck',
#   'Th',
#   'T&D',
#   'Conmlttee',
#   'Hlth',
#   'pnncy',
#   'p',
#   'hearlngs',
#   'MeanwhllE,',
#   'meetlngs',
#   'Hlth',
#   '1n51ght',
#   '.3515',
#   '037nm'],
#  ['Exhlblt',
#   'a',
#   'fry',
#   '13mm:',
#   'ummmns',
#   'BY',
#   'R.',
#   'E.',
#   'PHILLIPS,',
#   'Commlttee.',
#   'a',
#   '1::',
#   'Commlttee',
#   'comprlsed',
#   'technlcal',
#   'technlcally',
#   'mm',
#   'by',
#   'accompllsh',
#   'thls',
#   'standlng',
#   'subcommlttees',
#   'r311,',
#   'E.',
#   'G.',
#   'M.',
#   'M.',
#   'J.',
#   'R.',
#   'Hopklns',
#   'by',
#   'technlcal',
#   'actlvlt',
#   '1nd1v1dual',
#   'a',
#   "AAR'",
#   'Commlttee.',
#   'a',
#   'Instltute',
#   'commlttee',
#   'Hlth',
#   'mm',
#   'Subcommltte',
#   'Commltte',
#   '.',
#   'J.',
#   'T.',
#   'Curtls,',
#   'DDT.',
#   'nghllghts',
#   'Actlvltles',
#   'M.',
#   'Commlttee',
#   'actlvltes',
#   '5:111',
#   'actlvlty',
#   'concernlng',
#   'carrylng',
#   'whlch',
#   'mm',
#   'whlch',
#   'Shleldlng,',
#   'speclflcatlons',
#   'cm',
#   '037001',
#   'current...',
#   'flrst',
#   'a',
#   'worklng',
#   'respondlng',
#   'm',
#   'antlclpated',
#   'a',
#   'slmllar',
#   '"Guldellnes',
#   'Spllls',
#   'R311',
#   'rulemaklng.',
#   'mm',
#   "Agency's",
#   'spllls',
#   'contrlbutlng',
#   "MCA'S",
#   'classlflcatlon',
#   'actlvltles',
#   'requallflcatfon',
#   'partlclpated',
#   'a',
#   'Posslble',
#   'a',
#   'whlch',
#   'Commlttee',
#   'a',
#   'a',
#   'spllls',
#   'a',
#   'addltlonal',
#   'classlflcatlon',
#   'cm',
#   '037002',
#   'n',
#   'w',
#   'btalnlng',
#   'mm',
#   'justlflcatlon',
#   'Vd',
#   'haldllng',
#   'Commlttee',
#   'hcndllng',
#   "1ndustry's",
#   'by',
#   'm',
#   'speclflc',
#   'cm',
#   '037nm'],
#  ['F',
#   'R',
#   'BY',
#   'WILL]:',
#   ',',
#   'GRowING',
#   't',
#   'endlng',
#   '1::',
#   'remalnlng',
#   '1ncreaslngly',
#   'actlng',
#   '.',
#   'A',
#   'a',
#   'm',
#   'dlfflculty',
#   '~',
#   'remalnlng',
#   'a',
#   'dlfflcult',
#   '1::',
#   'actlvltles',
#   'dlstractlons',
#   'posslble',
#   'Hlth',
#   'whlch',
#   'months:',
#   'b111,',
#   'by',
#   'CommlttEE;',
#   '1977.',
#   'provldlng',
#   'cm',
#   '037039',
#   'a',
#   '"PARENS',
#   'A',
#   'antktrus:',
#   'a',
#   'A5',
#   'a',
#   'by',
#   'Commlsslon;',
#   'notlflcatlon',
#   'FTC',
#   'trlgger',
#   'glvlng',
#   'brlng',
#   'cltlzens.',
#   'a',
#   'amendlng',
#   'wordlng',
#   'resultlng',
#   '£111',
#   'munlclpal',
#   'fundlng',
#   'modlflcatlon',
#   'whlch',
#   'cm',
#   '037039',
#   'r',
#   'a',
#   'wrltten',
#   'by',
#   'orlglnal',
#   '19275007.',
#   'A',
#   'Commlttees',
#   'a',
#   'ductlng',
#   'PL',
#   '927500',
#   'Commlsslon',
#   'Quallty.',
#   'soLm',
#   'a',
#   'M',
#   'Commlttee',
#   'Subcommlttee',
#   'a',
#   'Commlttee',
#   'dlfflculty',
#   'a',
#   '1ncllned',
#   'm',
#   'Hlth',
#   'technlcal',
#   'a',
#   '1nc1neratlon,',
#   'cm',
#   '037040',
#   'plastlcs',
#   'a',
#   '1nd1v1dual',
#   'by',
#   '1nd1v1dual',
#   'mm',
#   'Commlttees.',
#   'mm',
#   'somethlng',
#   'a',
#   'Commlttee',
#   'budgetisettlng',
#   'Sprlng',
#   'hearlngs',
#   'Commlttee',
#   'months.',
#   'F.',
#   'testlfled',
#   'MCA,',
#   'urglng',
#   'whlch',
#   'Commlttee',
#   'mm',
#   'mldiJune',
#   'A',
#   'by',
#   'a',
#   ":'I",
#   '1ndustry:',
#   'cm',
#   '037041',
#   'I',
#   'flrst',
#   '$50,000.',
#   '1977.',
#   'a',
#   'a',
#   'addltlonal',
#   'holdlng',
#   'm',
#   '1977,',
#   'appllcable',
#   'whlch',
#   'recelpts.',
#   'm',
#   '1975.',
#   'offlclals',
#   'earnlngs',
#   'proflts,',
#   'complylng',
#   'Hlth',
#   'by',
#   'b111,',
#   'preferrlng',
#   'thls',
#   'a',
#   'cw',
#   '057042'],
#  ['G',
#   'TD',
#   'L.',
#   'P-llcy',
#   'commlttee',
#   'by',
#   '‘',
#   'Certalnly,',
#   'strength.',
#   'agglng',
#   '1ndustry,',
#   'mm',
#   'sllght',
#   'utlllzatlon',
#   'a',
#   ':-',
#   'klnd',
#   'whlch',
#   'entltled?',
#   'dlvldendipayout',
#   's',
#   'justlfy',
#   '..',
#   'a',
#   'a',
#   'whlch',
#   'mlght',
#   'admlttlng',
#   'condltlons',
#   'a',
#   'a',
#   'lengthy',
#   'r',
#   'th',
#   's',
#   'c',
#   'Tllllch',
#   's',
#   'm',
#   'mm',
#   'amblgulty".',
#   '03704-',
#   'ln',
#   'slmllar',
#   'whlch',
#   '197171974',
#   't',
#   'e',
#   'Stablllty',
#   '1nflatlon-ry.',
#   'authorlty.',
#   'o',
#   '1mposlt1-of',
#   'a.‘',
#   't',
#   '3111:',
#   '.1“:',
#   'a',
#   '"',
#   'e',
#   '.',
#   'sllghtly',
#   'mm',
#   'faclllta',
#   '-',
#   'spllttlng',
#   'unlts,',
#   'arbltrary',
#   'arlthmetlcal',
#   '1nd1cate',
#   '1nustry.',
#   'a',
#   'posslble',
#   'ml',
#   'by',
#   'thls',
#   '1::',
#   '"polltlcally',
#   'a',
#   '34297.',
#   'A',
#   'tliTrust',
#   'ellmlnate',
#   'm',
#   'by',
#   'ellmlnate',
#   'a',
#   'by',
#   'ellmlnate',
#   'a',
#   'trlple',
#   'thls',
#   'thls',
#   'b111,',
#   'n',
#   'e',
#   'flrst',
#   '0370.4',
#   'r',
#   'erslty',
#   '35515:',
#   "dustry's",
#   '"An',
#   'Analysls',
#   'avall-nle.',
#   'Subcommlttee',
#   'dld',
#   'hearlngs',
#   '1ndustry,',
#   'c',
#   '1::',
#   '1ndustry.',
#   't',
#   'e',
#   '1n1tlated',
#   'by',
#   '1973,',
#   't',
#   '1n51de',
#   'd1v.st1ture',
#   'llmltlng',
#   'reflnlng,',
#   'marketlng)',
#   'dlvestlturE,',
#   'requlrlng',
#   'By',
#   'a',
#   'a',
#   'm',
#   'Commlttee',
#   '.337,',
#   'a',
#   'holdlng-',
#   'Hlthln',
#   'th',
#   'nlstratlon',
#   '1:.',
#   'urE,',
#   'Commlttee',
#   '"leglsl.t1ve',
#   '...51mllar',
#   'A',
#   'Commlttee',
#   'hearlngs,',
#   'by',
#   'thls',
#   'responslblllty/federal',
#   'charterlng,',
#   'a',
#   'whlch',
#   'a',
#   'mm',
#   'F0',
#   '-',
#   'Admlnlstratlon',
#   'thls,',
#   'Commlttee',
#   'thls',
#   'Plannlng',
#   'cMAnsT4a',
#   'A',
#   'h',
#   'by',
#   'm',
#   'lannlng',
#   'hld',
#   'flrst',
#   'Commlttee',
#   'by',
#   'a',
#   'mm',
#   'Commlttees',
#   'Pollcy,',
#   'Multln-tlonal',
#   'n',
#   's',
#   'Hlth',
#   'a',
#   's',
#   'whlch',
#   'conductlng',
#   'a',
#   't',
#   '1ndu5lry,',
#   "Church's",
#   'tax*wr1t1ng',
#   'th',
#   'Lsk',
#   'WC:',
#   'Commlttees.',
#   'iSSuE,',
#   'a',
#   'calllng,',
#   'a',
#   'by',
#   'Banklng',
#   'Commlttee',
#   'thls',
#   'n',
#   'Commlsslon',
#   'By',
#   'by',
#   'a',
#   '"Internatlonal',
#   'Enterprlses.”',
#   '037045',
#   'lengthy',
#   'prlnclples',
#   'by',
#   '~',
#   'p',
#   'enterprlses',
#   'by',
#   'enterprlses',
#   '~',
#   'sanctlty',
#   'enezprlsesi',
#   '~',
#   'posltlve',
#   'contrlbutlons',
#   'whlch',
#   'exprlses',
#   '~',
#   'arbltratlon',
#   'resolvlng',
#   'enterprlses.',
#   'T',
#   'a',
#   'a',
#   'a',
#   'A',
#   '037047'],
#  ['Exhlblt',
#   'ummmns',
#   'Commlttee',
#   'flrst',
#   'Commlttee,',
#   'establlshed',
#   'by',
#   '1::',
#   'meetlng.',
#   'beglnnlng',
#   '1974,',
#   'commlttee',
#   'mm',
#   'Commlttee',
#   'malntalnEd,',
#   'a',
#   'mm',
#   'mm',
#   '1::',
#   '1::',
#   'establlshment.',
#   'responslbllltles:',
#   'Commlttee',
#   'mm',
#   'Supervlslng',
#   'm',
#   'F',
#   'Admlnlstratlon.',
#   'A5',
#   'thls',
#   'submltt',
#   'd',
#   'thls',
#   'whlch',
#   'partlclpated.',
#   'mm',
#   'a',
#   '1972,',
#   '4.9%.',
#   'overirldlng',
#   '74.2%',
#   '1975,',
#   'mm',
#   '93.5%',
#   '1972.',
#   "MCA'S",
#   'reportlng',
#   'Fertlllzer',
#   'Instltute',
#   '1nd1v1dually',
#   'offlclals',
#   'offlclals',
#   'thls',
#   'meetlng,',
#   'a',
#   'by',
#   'mm',
#   'cm',
#   '037049',
#   '1972.',
#   '1975,',
#   'Commlttee',
#   'mm',
#   'whlch',
#   'thls',
#   'by',
#   'twoidlglt',
#   'offlclally',
#   '1dent1£1ed',
#   'thls',
#   'surprlslngly,',
#   'flrst.',
#   'whlch',
#   'operatlng.',
#   'Hlth',
#   'whlch,',
#   'modlfy.',
#   '1ndustry,',
#   '1n1tlally',
#   'dlfflculty',
#   'gettlng',
#   "MCA'S",
#   'a',
#   'thls',
#   'responslblllty,',
#   'Instltute',
#   '1:,',
#   'Hlth',
#   'technlcal',
#   'subcommlttee',
#   'Commlttee',
#   'mm',
#   '1nd1v1dually',
#   'demandlng',
#   'contrlbutlng',
#   'submltted',
#   'publlshed',
#   'Hlth',
#   'hearlngs',
#   'posslble',
#   'testlfy',
#   '1ndustry,',
#   'testlfy',
#   '1::',
#   'by',
#   'Commlttee',
#   'a',
#   'mm',
#   '1dentlfy',
#   'hlghestiranklng',
#   'a',
#   'trllllon',
#   "BTU'S",
#   'whlchever',
#   'reportlng',
#   'a',
#   'trllllon',
#   "BTU'S",
#   'a',
#   'reportlng',
#   'Fertlllzer',
#   'Instltute,',
#   'a',
#   'trllllon',
#   "BTU'S",
#   'cm',
#   '037049',
#   'r',
#   'reportlng',
#   "MCA'S",
#   'reportlng,',
#   'publlshed',
#   'REGISTER.',
#   'falllng',
#   'a',
#   '50/50',
#   '1nd1v1dual',
#   '1977.',
#   'subsldy',
#   "MCA'S",
#   'exemptlng',
#   'reportlng',
#   'm',
#   'reportlng,',
#   'u',
#   'reportlng.',
#   'hearlngs',
#   'testlfled',
#   'thls',
# ...
#   '”.95"',
#   'm',
#   '100th',
#   'whlch',
#   'a',
#   'a',
#   'whlch',
#   'o',
#   'mm',
#   'partlclpated',
#   "CMA'S",
#   '"Get',
#   'o',
#   'Identlflcatlon',
#   'Vlslblllty',
#   '1999',
#   'o',
#   'analysls',
#   'cm',
#   'contrlbutlons',
#   'o',
#   'analysls',
#   'cm',
#   'Actlvltles',
#   'thls',
#   '"Get',
#   'Hlth',
#   '"Issues',
#   '1dentlfy',
#   'Washlngton',
#   "party's",
#   'm',
#   'facllltate',
#   'cm',
#   'm',
#   '1ndustry.',
#   'Hlth',
#   'Hlth',
#   '1999',
#   '{The',
#   '039791',
#   'm',
#   'capabllltles.',
#   'Technlcal',
#   'actlvlty',
#   'shlfted',
#   'm',
#   'III.',
#   'a',
#   'cm',
#   'cm',
#   'commlttee',
#   'mm',
#   'commlttees',
#   'speclflc',
#   'notlflcatlon',
#   'posslbly',
#   'thls',
#   'by',
#   'CMA.',
#   "CMA'S",
#   'actlvltles',
#   'HUSD7',
#   'Cofflsnmlcatlons',
#   'dlvlslon',
#   'dlstrlbutlon',
#   'satelllte',
#   'by',
#   'Admlnlstrator',
#   'TV',
#   'country.',
#   'A',
#   'satelllte',
#   'Byrd',
#   'Coamnmlty',
#   '1nc1dents',
#   'flrst',
#   'a',
#   'shlpment',
#   'orlglnatlng',
#   'Franclsco',
#   '039792',
#   'cammmc',
#   'shlpper',
#   '1dent1£1catlon',
#   'by',
#   '1nc1dent.',
#   'a',
#   'mm',
#   'a',
#   'cammm',
#   'Hlth',
#   '039793',
#   'PoLICy',
#   '1936,',
#   'Commlttee',
#   'affectlng',
#   '1ndustry.',
#   'Respondlng',
#   'm',
#   'Coomllttee',
#   'responslbly',
#   'a',
#   'by',
#   'bllllon',
#   'Commlttee',
#   'mm',
#   '1935,',
#   'a',
#   'shlft',
#   '1nd1v1dual',
#   'm',
#   'Vlthln',
#   '1nd1v1dual',
#   'by',
#   'actlvltles',
#   '1935,',
#   'a',
#   'mm',
#   'by',
#   "CMA'S",
#   'actlvlty',
#   'Commlttee',
#   'addltlon',
#   'm',
#   '1dent1£1ed',
#   'b111,',
#   'cm',
#   'Commlttee',
#   'a',
#   'dlsproportlonate',
#   '1ndustry.',
#   'Commltta',
#   'm',
#   '1dent1£1ed',
#   'by',
#   'cm',
#   'cm',
#   't',
#   'a',
#   'by',
#   '._',
#   'thls',
#   'Commlttee',
#   'm',
#   'technlcal',
#   'asslstance',
#   'm',
#   'Commlttee',
#   'fundlng',
#   'a',
#   'contrlbutlon',
#   "CMA'S",
#   's',
#   'K',
#   'THE,STATES',
#   'OBJECTIVE:',
#   'slngled',
#   'dlscrlmlnatory',
#   'Commlttee',
#   '1::',
#   'meetlng,',
#   'Commlttee',
#   'a',
#   'a',
#   '1995/97',
#   'actlvlty.',
#   'Actlvlty.',
#   '1935.',
#   'mm',
#   'munlclpal',
#   'Vashlngton,',
#   't',
#   'a',
#   'actlvlty',
#   '~',
#   'modlflcatlon',
#   'ellmlnatlon',
#   'l.b111ty',
#   '~',
#   'Hlth',
#   '1nvolv1ng',
#   'llmltatlon',
#   'o',
#   'llablllty.',
#   'Actlvltles.',
#   'cm',
#   'followlng.ct1v1t1es',
#   'posltlve',
#   'dlstrlbuted',
#   '5::',
#   'dlvlded',
#   '1ndustry.',
#   'flrst',
#   'whlch',
#   'meanlngful',
#   '~',
#   'by',
#   'lly',
#   'scrutlnlzed',
#   'by',
#   'llablllty',
#   'contlngency',
#   'Ellmlnate',
#   'llablllty',
#   'Harnlngs',
#   'thlrd',
#   'Ellmlnate',
#   'Ellmlnate',
#   'llablllty',
#   'mm',
#   'Ellmlnate',
#   'vsmg',
#   'a',
#   'g',
#   'partlclpated',
#   'by',
#   'Councll.',
#   'a',
#   '2nnn',
#   "ALEC'S",
#   '"Source',
#   'A',
#   '1997799."',
#   "CMA'S",
#   "refom'lssues",
#   'utlllzed',
#   'thls',
#   'A',
#   '7,451',
#   'n',
#   'mm',
#   'a',
#   'speclflc',
#   'supportlng',
#   "ATRA'S",
#   'whlch',
#   'supportlng',
#   "ALEC'S",
#   'bllls.',
#   'a',
#   "ALEC'S",
#   'publlshed',
#   'o',
#   'a',
#   'by',
#   'counclls.',
#   'o',
#   'mm',
#   'addltlon,',
#   'a',
#   '-',
#   'by',
#   'worklng',
#   'mm',
#   'm',
#   'a',
#   'd',
#   'b',
#   'mm',
#   'a',
#   'by',
#   'RECOMMENDATIONS:',
#   'o',
#   '1::',
#   'exlstlng',
#   'dr.ft1ng',
#   'a',
#   'by',
#   'a',
#   'whlch',
#   'MA.',
#   'm',
#   'whlch',
#   'colnclde',
#   'Hlth',
#   "1ndustry's",
#   'Dr.ft1ng',
#   'addltlonal',
#   'thls',
#   'a',
#   'dlvldlng',
#   'a',
#   'mm',
#   'c',
#   'by',
#   'o',
#   'counclls',
#   'partlclpate',
#   'a',
#   'by',
#   'cm',
#   'shmld',
#   'counclls',
#   't.‘',
#   't',
#   'a',
#   'm',
#   'partlclpate',
#   '1n1tlate',
#   'm',
#   'REQUIRED:',
#   '039797',
#   'L',
#   'm',
#   'E.',
#   '~',
#   'thls',
#   'by',
#   'deflnltlon',
#   'a',
#   'whlch',
#   'famlllar',
#   '"Are',
#   'I',
#   '-',
#   'm',
#   'commlttEE,',
#   'a',
#   'convlctlon',
#   'standlng',
#   'mm',
#   'gettlng',
#   'commlttee',
#   'a',
#   'ry',
#   'commltment',
#   'a',
#   'a',
#   '1nc1dent,',
#   'a',
#   "1ndustry's",
#   'K',
#   'frankly,',
#   'a',
#   'a',
#   '1935.',
#   'Startlng',
#   'CAER,',
#   'toxlcs.',
#   'a',
#   'a',
#   '1nc1dent',
#   'reklndle',
#   '1nc1dent',
#   'dld',
#   'a',
#   'a',
#   'a',
#   'm',
#   'a',
#   'reportlng',
#   'I',
#   'crlnglng',
#   'tv',
#   'watchlng',
#   'ng',
#   'J1',
#   'dlscusslng',
#   '...D1r-ctoricozporate',
#   'n',
#   'c',
#   'Rhln-',
#   'splll',
#   'Swltzerland.',
#   'Frankly,',
#   'a',
#   'why',
#   "dldn't",
#   'crltlcal',
#   'U.s.,',
#   'complalnlng',
#   '1:.',
#   'a',
#   '1nc1dent',
#   '193.51“',
#   'a',
#   "stry's",
#   'I',
#   'thls',
#   'Hlth',
#   'p',
#   'I',
#   'A',
#   'overwhelmlngly',
#   'posltlve',
#   'actlvltles.',
#   'I',
#   'a',
#   'actlvltles',
#   '1935.',
#   'actlvltles',
#   'a',
#   'communlty.'],
#  ['1nd1v1duals',
#   'representlng',
#   'commlttee',
#   'skllls',
#   '1996,',
#   'commlttee',
#   'recelV-d',
#   'relatlonshlps',
#   'Hlth',
#   'mg',
#   'Famlllarlty',
#   'thls',
#   "1ndustry's",
#   'credlblllty',
#   'Hlth',
#   'addltlon,',
#   'sklns',
#   'a',
#   'llttle',
#   'worklng',
#   'a',
#   'A5',
#   'a',
#   'crltlcal',
#   'g',
#   'worklng',
#   'Hlth',
#   'a',
#   't',
#   '1996,',
#   "publlc's",
#   'I',
#   'statlstlcs,',
#   'I',
#   'a',
#   'trnds',
#   'Accordlng',
#   'prestlglous',
#   "publlc's",
#   'thls',
#   'by',
#   '1995.',
#   'mm',
#   'a',
#   'by',
#   'sllght,',
#   'cm',
#   '039799',
#   '115-.',
#   'Vry',
#   'electrlc',
#   '1ndustry.',
#   'standlng',
#   "doe-n't",
#   'mm',
#   'ratlngs',
#   'retalllng',
#   '.',
#   'ranklng',
#   'plastlcs',
#   'lSilndustry',
#   'plastlcs,',
#   'thls',
#   'encouraglng.',
#   'secondly,',
#   't',
#   'e',
#   '1ndustry,',
#   'whlch',
#   "publlc's",
#   'By',
#   'posslble',
#   "publlc's",
#   'sllghtly.',
#   'reboundlng',
#   'sllght',
#   'Hlth',
#   "publlc's",
#   '1ndustry.',
#   'preferrlng',
#   'Hlth',
#   'a',
#   '1mprov1ng,',
#   'progresslng',
#   'actlng',
#   'qulckly',
#   '1::',
#   'conslstntly',
#   "country's",
#   'Hlth',
#   'condltlons.',
#   "commlttee's",
#   "CHA'S",
#   'm',
#   'posslblE,',
#   'Hlth',
#   '1935.',
#   'cm',
#   'a',
#   'actlvlty,',
#   't',
#   'Hlth',
#   '1ndustry.',
#   'cm',
#   '039790',
#   'TH',
#   'leadershlp',
#   'thls',
#   'W',
#   'a',
#   "commlttee's",
#   'a',
#   'establlshlng',
#   'a',
#   'mg',
#   'm',
#   "1ndustry's",
#   'c',
#   'agshlp',
#   'conductlng',
#   'a',
#   'tlvltles',
#   'mm',
#   'thls',
#   'commlttee',
#   'cm',
#   'bulldlng',
#   "CAER'S",
#   'tackllng',
#   "stry's",
#   't',
#   'e',
#   'III',
#   'a',
#   'commlttee',
#   'd',
#   'communlcatl-ns',
#   'thlng,',
#   'c',
#   '1::',
#   'emlssl-ns,',
#   'a',
#   'a',
#   'a',
#   'mg',
#   'why',
#   'emlsslons',
#   'ms',
#   'hlghlyitoxlc',
#   'pl-nts',
#   "'",
#   'communlty.',
#   'unplementlng',
#   'progr.ms.',
#   'Admlttlng',
#   'm',
#   'a',
#   'emlsslons.',
#   'commlttee,',
#   'cm',
#   'a',
#   'flrst',
#   'thls',
#   't',
#   'a',
#   'thls',
#   'I',
#   'nth',
#   'thlnklng.',
#   'cm',
#   '039791',
#   'w',
#   '.',
#   'helplng',
#   'pl.nt',
#   'mm',
#   'III',
#   '111',
#   '1:.',
#   '‘',
#   'mm',
#   'commlttee',
#   'a',
#   'L;',
#   '~11cy',
#   'thls',
#   '55515:',
#   '"unclls',
#   'capabllltles.',
#   'W-‘Ve',
#   '1111x1915,',
#   'worklng',
#   'mm',
#   'Ie',
#   'actlvlty',
#   '*657type',
#   'CICs',
#   'm',
#   'thls',
#   'partnershlp.',
#   'conslst',
#   'extendlng',
#   'actlvltles',
#   'm',
#   'c-Ver',
#   'III',
#   'iSSuES,',
#   'worklng',
#   'Hlth',
#   'CICs.',
#   'addltlon,',
#   'mm',
#   'commlttees',
#   'Hlthln',
#   'm',
#   'commlttee',
#   'Hlth',
#   'mm',
#   'I',
#   'mm',
#   'a',
#   'toplcs.',
#   'commlttee',
#   'thls',
#   'a',
#   'a',
#   'admlnlstratlon,',
#   'everythlng',
#   'worklng',
#   'e',
#   'm',
#   '1nefflc1ent',
#   't',
#   'sacrlflclng',
#   'r',
#   'lln-s,',
#   'GM',
#   'flrst',
#   'thls',
#   '50750',
#   'mm',
#   'closmgs,',
#   'a',
#   'm',
#   's',
#   'cm',
#   '039792',
#   'GM',
#   'flrst,',
#   "shouldn't",
#   'thlnklng',
#   "publlc's",
#   'a',
#   'm',
#   "1ndustry's",
#   'mm',
#   '1mprmve',
#   'flrst',
#   'uptlck',
#   'dld',
#   'by',
#   "publlc's",
#   'legltlmate',
#   'conc-rns',
#   'a',
#   'beglnnlng',
#   'I',
#   'earnlng',
#   '1997.',
#   'I',
#   'try',
#   'mlght',
#   'commlttee',
#   'cm',
#   'cm',
#   '039793',
#   'exhlblt',
#   'm',
#   "'ADEMARK",
#   '1936,',
#   't',
#   'Commlttee',
#   '("PATC...',
#   'Commlttee"',
#   ',',
#   '1nstrumental',
#   'provldlng',
#   '..',
#   'Admlnlstratlon',
#   'mm',
#   'mm',
#   'stry',
#   'PATC,',
#   'rlghts',
#   'a',
#   'd',
#   'SDllClt',
#   "CMA'S",
#   'pendlng',
#   'tlclpated',
#   'Commlttee',
#   'Commlttee',
#   'cm',
#   'utlllzatlon',
#   'pollcy,',
#   '1930,',
#   'addltlon',
#   'Commlttee',
#   'Hrltte',
#   'submlsslon',
#   'by',
#   'cm',
#   'a',
#   'Comnlttee',
#   'partlclpated',
#   "Admlnlstratlon's",
#   'actlvltles',
#   'rlghts',
#   'Commlttee',
#   'thls',
#   'Commlttee',
#   'productlvlty.',
#   "CMA'S",
#   'apprlsed',
#   'rlghts',
#   'Commlttee',
#   'mm',
#   'a',
#   'mechanlsms',
#   'cm',
#   'By',
#   'thls',
#   'Commlttee',
#   'Commlttee,',
#   'a',
#   'cm',
#   'exlstlng',
#   'ignlflcant',
#   'Conmlttee',
#   'mm',
#   'asslstance,',
#   'technlcal',
#   'actlvltles',
#   'by',
#   'ommlttee',
#   'asslsta',
#   '1937.',
#   'cm',
#   'cm',
#   '039794',
#   'N',
#   '13mm:',
#   'ummmns',
#   "Conmlttee's",
#   'Mlnlmlzatlon',
#   'a',
#   'descrlblng',
#   'mlnlmlzatlon',
#   'a',
#   'posslble',
#   'meetlng.',
#   'thls',
#   'm',
#   'appr-Val',
#   'a',
#   '(RCRA7',
#   'establlsh',
#   'mlnlmlzatlon',
#   'c-rtlfy',
#   'requlrlng',
#   'mlnlmlzatlon.',
#   'mlnlmlzatlon',
#   'scrutlnlzed',
#   'facllltl-s',
#   'by',
#   'Ass-ssment',
#   'EPA.',
#   'mlnlmlza',
#   'a',
#   'hlgh',
#   'dlscharge',
#   '51mm;',
#   't',
#   'unplementlng',
#   'mlnlmlzatlon',
#   'by',
#   'hearlngs',
#   'beglnnlng',
#   '1-37.',
#   'sufflclent',
#   'c',
#   'convlnce',
#   "RCRA'S",
#   'whlch',
#   '1-39.',
#   '1nt-1ndustry',
#   '11mm:',
#   'restrl-tlons,',
#   'audlts.',
#   'Hlth',
#   'E?',
#   'RCRA.',
#   'tlghtens',
#   'slgnlflcantly',
#   'thls',
#   '1nustryw1de',
#   "F.?A's",
#   'III.',
#   'mlnlmlzallon',
#   'hearlngs',
#   '.',
#   'addltlon.',
#   'E.A',
#   'commltted',
#   'm',
#   'mlnlmlzatlon',
#   '1937,',
#   'whlch',
#   'overslght',
#   '1::',
#   'n',
#   'asslstance',
#   'a',
#   'by',
#   'establlshlng',
#   'a',
#   'cm',
#   'cm',
#   '039795',
#   'sourCE,',
#   'rlsks.',
#   'ts',
#   'thls',
#   'o',
#   'o',
#   'llablllty;',
#   'o',
#   'c',
#   'understandlng',
#   'P-sltlon',
#   'Mlnlmlzatlon',
#   'cm',
#   'a',
#   '1::',
#   'cm',
#   'u',
#   '1nd1v1dual',
#   'p',
#   'addltlonal',
#   'mlnlmlzatlon',
#   '35515:',
#   '1::',
#   'by',
#   'unplementlng',
#   'a',
#   'mlnlmlza',
#   'Actlvltles',
#   'pr-gram',
#   '55515:',
#   'carrylng',
#   'mlnlmlzatlon',
#   '(1.e.,',
#   'mlnlmlzatlon',
#   'EPA.',
#   'mlnlmlzatlon',
#   'deflnltlons',
#   'deflnltlon',
#   'exlstlng',
#   'modlflcatlon',
#   't',
#   'o',
#   'mlnlmlzatlon',
#   'a',
#   '(1.e.,',
#   '1dent1£1catlon',
#   'a',
#   '1ndustryw1de',
#   '.',
#   'd',
#   'a',
#   'b.5157.',
#   'cm',
#   'pr-grammatlc',
#   '1.e.,',
#   'establlshlng',
#   'slmllar',
#   'm',
#   "CMA'S",
#   'snsrgy',
#   '.',
#   'Hlth',
#   'cm',
#   '039795',
#   "RESAHJ'KCE",
#   'NEE!',
#   'cm',
#   't',
#   'actlvltles',
#   'a',
#   'a',
#   'A',
#   '55.1“:',
#   "CMA'S",
#   'FT',
#   '97/99',
#   'Purch.sed',
#   '$ADK',
#   'fundlng',
#   'FT',
#   '97/99',
#   'm',
#   'thls',
#   'mcommmnm',
#   'unplementlng',
#   'a',
#   'mlnlmlzatlon',
#   'Rmvmm',
#   't',
#   'a',
#   'BM:',
#   'cm',
#   'cm',
#   '039797',
#   'C1.t1.2an5',
#   'offlclals',
#   'a',
#   'Consequently,',
#   'a',
#   'Burdlck',
#   'a',
#   '100th',
#   'Slmllar',
#   'restrlctlns',
#   '(e.g.,',
#   'pestlcldes,',
#   'solvents),',
#   'addltlonal',
#   'actlvltles,',
#   'enactlng',
#   'unplementlng',
#   'establlsh',
#   'restrlctlons,',
#   'plannlng',
#   'Vlctlm',
#   '51te*speclflc',
#   'whlch',
#   'consumlng.',
#   "CMA'S",
#   'ly',
#   'establlsh',
#   'a',
#   'artlclpatlon',
#   'vsmg',
#   'strlve',
#   'm',
#   "CMA'S",
#   'posslble.',
#   'thls',
#   'cm',
#   'partlclpate',
#   '100th',
#   'partlclatlon',
#   'emerglng',
#   '1dentlfy',
#   'II.',
#   "CMA'S",
#   'Slblllty',
#   'm',
#   'a',
#   'A',
#   'pr-gram',
#   'p',
#   'annlngi',
#   'protsctlon;',
#   'monltorlng;',
#   '55515',
#   'ms',
#   'asslstance',
#   'fundlng',
#   '35515:',
#   'technlcal',
#   'sclentlflcallyibased',
#   'ths',
#   'alllty',
#   'cm',
#   '039799',
#   'III.',
#   'H11',
#   'a',
#   '100th',
#   'debatE,',
#   'CMA...5',
#   'concpts',
#   '1937.',
#   'IV.',
#   'r-Vlewed',
#   'l-glslatlon.',
#   "CMA'S",
#   'cm',
#   'cm',
#   '039799',
#   'Groundw.ter',
#   'a',
#   '1mplement.tlon',
#   'responslblllty',
#   'asslstance',
#   'by',
#   'a',
#   '.',
#   'asslstance',
#   '.',
#   'A',
#   'A',
#   'plannlng.',
#   'A',
#   'A',
#   'A',
#   'A',
#   'descrlptlons',
#   'establlsh',
#   'a',
#   'plannlng.',
#   'exlstlng',
#   'Hlth',
#   'mscsy',
#   'ld',
#   's',
#   '1.:',
#   'dlvlde',
#   'whlch',
#   'dlffrent',
#   'establlsh',
#   'm',
#   '1nd1v1dual',
#   'objecth-s',
#   '1dentlfy',
#   'antlclpated',
#   't',
#   'e',
#   '1dentlfy',
#   'avallablllty',
#   'sclentlflcal',
#   'drlnklng',
#   'supply,',
#   'Conbmlnant',
#   "(MCL'57",
#   'by',
#   'Drlnkln',
#   'a',
#   'MCL.',
#   'by',
#   'a',
#   'crltrla',
#   'EPA.)',
#   'p',
#   'inlmlzlng',
#   'a',
#   'Tn',
#   '1dentlfy',
#   'exlstlng',
#   '.',
#   'wlthdrawal',
#   'llmltatlons,',
#   'mm',
#   'exlstlng',
#   'RCRA.',
#   'sDwA,',
#   'FTFRA,',
#   '(IVA,',
#   'onslstent',
#   'mm',
#   'exlstlng',
#   'concernlng',
#   'capaclty.',
#   '.',
#   'contr-ls',
#   '161::',
#   '1nd1v1dual',
#   'contr-l',
#   'dlstlnctlons',
#   'speclflc',
#   'appllcable',
#   'cm',
#   '039901',
#   'm',
#   't',
#   '1::',
#   'ljnplananta',
#   '(e.g.,',
#   'tralnlng,',
#   'a',
#   'St',
#   'a',
#   'a',
#   'c',
#   'objectlves/standards.',
#   'Hlth',
#   'appllcable',
#   'r',
#   'ghts',
#   'St',
#   'whlch',
#   't',
#   'St',
#   'a',
#   't',
#   'e',
#   'whlch',
#   'appllcable',
#   '.',
#   'sclentlflcally',
#   'Hlth',
#   'establlsh',
#   'a',
#   'cm',
#   '039902',
#   'I',
#   'p',
#   'a',
#   'cm',
#   '039903',
#   '35515:',
#   'a',
#   'ubmlts',
#   'a',
#   'fundlng',
#   '55515:',
#   'certlfles',
#   'mm',
#   'U55',
#   '55515:',
#   'by',
#   'provldlng',
#   'technlcal',
#   'cm',
#   'cm',
#   '039904',
#   'p',
#   "'MEDIES",
#   'n',
#   'u',
#   'restrlct',
#   'w',
#   'securlty.',
#   'A',
#   'hy',
#   'Admlnlstratlon.',
#   'Addltlons',
#   'm',
#   'h.ndled',
#   'by',
#   'a',
#   'A',
#   'by',
#   '.u:',
#   'whlch',
#   'm',
#   'addltlonal',
#   '115:.',
#   'A',
#   'o',
#   'antlclpated',
#   '100th',
#   'cm',
#   'Commlttee',
#   'a',
#   'whlch',
#   'exlstlng',
#   'whlch',
#   'co.lltlons',
#   'cm',
#   'PDSITIIN:',
#   'cm',
#   'thls',
#   'o',
#   'exlstlng',
#   'exlst,',
#   'by',
#   'whlch',
#   'dlsclosure',
#   'cm',
#   'cm',
#   'o',
#   'restrlct',
#   'whlch',
#   'securlty.',
#   'a',
#   'securlty,',
#   'a',
#   'Hlthln',
#   '1n1tlatlon',
#   'thls',
#   'a',
#   'speclflc',
#   'Sampllng',
#   'o',
#   'establlsh',
#   'Presldent1.l',
#   'a',
#   'recelvlng',
#   'establlsh',
#   'a',
#   't',
#   '-',
#   'n',
#   'recelvlng',
#   'ld',
#   'Hlthln',
#   'recelvlng',
#   "'",
#   'cm',
#   '10M:',
#   'p',
#   'ty',
#   'fr',
#   'Admlnlstratlon',
#   'However,lransferr1ng',
#   'm',
#   'vsm',
#   'Admlnlstratlon',
#   'a',
#   'c',
#   'm',
#   'securlty.',
#   'by',
#   'n',
#   'cm',
#   '‘',
#   'cm',
#   'ts',
#   'Ssctlon',
#   't',
#   'a',
#   '1n1tlate',
#   'a',
#   'by',
#   'by',
#   'coaaerce',
#   'a',
#   'by',
#   'mm',
#   'whlch',
#   '1n1tlated',
#   'by',
#   'whlch',
#   'recommend-tlons',
#   'a',
#   '1n1tlated',
#   's',
#   'cm',
#   'cm',
#   '(ANSI',
#   '2129.1719977',
#   'EACKGRD',
#   '-:',
#   '1946,',
#   '1ndustry.',
#   '1975,',
#   '2129.1:',
#   'Industr1.l',
#   'a',
#   'Instltute',
#   '(M517.',
#   '212-.1',
#   'publlshed',
#   '1932,',
#   'extenslV-ly',
#   'by',
#   'cm',
#   "Commlttee's",
#   'a',
#   'Commlttee',
#   'by',
#   'whlch',
#   'submlsslon',
#   'm1d71987.',
#   '2129.»',
#   '2129.1',
#   'part1cul.rly',
#   'o',
#   '1936,',
#   'a',
#   'organ/system',
#   'Harnlngs',
#   'perf-mance*or1ented',
#   '2129.1',
#   'flexlblllty',
#   'm',
#   'cm',
#   'o',
#   'A',
#   '11:1g1ms',
#   'llablllty',
#   'lllnesses',
#   'rlsk',
#   'o',
#   'Eulflll',
#   'pnrmny',
#   '2129.171997;',
#   'o',
#   'llgh',
#   'A',
#   '2129.171997',
#   'flrst',
#   'o',
#   'posslble"',
#   'Hlth',
#   'e.g.,',
#   'TSCA,',
#   '[CT',
#   'PLANS;',
#   'avallablllty',
#   'cm',
#   'offlclals',
#   '199771999.',
#   'submlsslon',
#   '(ANSI',
#   '21294719977',
#   'by',
#   'Instltu',
#   'e',
#   'cm',
#   'cm',
#   'pnouvcmzs',
#   '...mm',
#   'sammm',
#   'SITEs,',
#   'A',
#   'CHEM]:',
#   'L',
#   '152.5',
#   '227.5',
#   '325.0',
#   '125.0',
#   '107.5',
#   '150.5',
#   '215.0',
#   '110.0',
#   's',
#   '575014',
#   '525024',
#   'a',
#   '550024',
#   '510024',
#   '515014',
#   '55014',
#   '~',
#   'PRoosED',
#   'cm',
#   'DBBlD',
#   'soURcEs',
#   '94/95',
#   '95/95',
#   '95/97',
#   '97/99',
#   '99/99',
#   '99/9.',
#   'cm',
#   "DTHE'",
#   'coumnsmmus',
#   'Rm',
#   'u-xmsmam',
#   'exhllt',
#   's',
#   'mmmmmms',
#   "WHE'",
#   'A5,',
#   'Savlngs',
#   '1nd1v1dual',
#   'mm',
#   'INTEREST.',
#   'RETURN.',
#   'ADVANTAGEs,',
#   'A',
#   'couvmmm',
#   ':',
#   'Hlth',
#   'by',
#   'ng',
#   'sovmwmm',
#   'BDRRDWING',
#   'm',
#   'T5,',
#   'Hlth',
#   'a',
#   'DEBT.',
#   't',
#   's',
#   "'DNGL‘I",
#   'TD',
#   "TH'REFDRE:",
#   'Dranlzlng',
#   'whlch',
#   'u.S.',
#   'Savlngs',
#   '1nd1v1dually',
#   'T-E',
#   'PROGRAM.',
#   'ALLDTMENTS',
#   "P'TICIPATING.",
#   ...]]

# %%
herp = [''.join(w) for w in trash[0]]   
herp
# Out:
# ['thls',
#  'CMA/LINC',
#  'crltlcal',
#  '1dent1£1ed',
#  'by',
#  'm',
#  'whlch',
#  'by',
#  'cm',
#  'rlghtitoiknow',
#  '"Toxlc',
#  'reportlng',
#  'concernlng',
#  "1ndustry's",
#  'rlsk',
#  'thls',
#  'Hlth',
#  "CMA'S",
#  'partlclpant',
#  "CMA'S",
#  'pollcy.',
#  'A',
#  'rapldly',
#  "CMA'S",
#  'partlclpatlng',
#  '1nd1v1dual',
#  'Councll.',
#  'thls',
#  'm',
#  '1935.',
#  'cm',
#  '039507',
#  'toxlcs.',
#  'flrst',
#  'actlvltles',
#  '115mm;',
#  'analysls,',
#  'reconclllatlon',
#  'thls',
#  'mlght',
#  'antlclpated',
#  'a',
#  '1nc1dents',
#  'exlstlng',
#  'Instltute,',
#  'Illlnols,',
#  'Pennsylvanla',
#  'thls',
#  'Hlth',
#  'deslgn.',
#  'actlvltles',
#  'actlvltles',
#  'a',
#  'addltlon.',
#  'a',
#  'mm',
#  'a',
#  'llttle',
#  'relatlonshlp',
#  'Marltlme',
#  'Commlsslon.',
#  'A',
#  'I',
#  'affldavlts,',
#  'convlnced',
#  'Admlnlstratlve',
#  'carrlers...',
#  'antltrust',
#  'thls',
#  'Commlsslon.',
#  'a',
#  'obtalnlng',
#  'antltrust',
#  'settlng',
#  'actlvltles',
#  'mllllon',
#  'Commlsslon.',
#  'Commlsslon',
#  'a',
#  'cm',
#  '(Order',
#  'by',
#  'facllltatlng',
#  'by',
#  'a',
#  'savlngs',
#  'savlngs',
#  'cm',
#  'mllllon.',
#  'addltlon.',
#  'cm',
#  'a',
#  'bllllng',
#  'testlfled',
#  'bllllng',
#  'slgnlflcantly',
#  'A',
#  'submltted',
#  'by',
#  'cm',
#  '1nd1cated',
#  "FERC'S",
#  'a',
#  'cm',
#  'Commlsslon',
#  '1::',
#  'bllllng',
#  '5:111',
#  'posslble.',
#  'Actlvlty',
#  'by',
#  'a',
#  'Commlttee',
#  'fundlng',
#  'reconclllatlon',
#  'whlch',
#  '”Ham',
#  'fundlng',
#  'reconclllatlon',
#  'm',
#  '1::',
#  'a',
#  'Actlvlty',
#  '391733',
#  'm',
#  'by',
#  'slgnlflcantly',
#  '&',
#  "Commlttee's",
#  'whlch',
#  'by',
#  'envlronmentallsts,',
#  'a',
#  'Hlth',
#  'thls',
#  'cm',
#  '039509',
#  '(Drum',
#  '13111',
#  '2207206,',
#  '510.3',
#  'bllllon',
#  'a',
#  'bllllon',
#  'bllllon',
#  'a',
#  'a',
#  'bllllon',
#  'a',
#  '&',
#  '&',
#  'Commlttees',
#  'cltlzen',
#  'rlghtitoiknow',
#  'a',
#  'a',
#  'whlch',
#  'a',
#  'fundlng',
#  'dlscretlon',
#  'EPA.',
#  '1:,',
#  "CMA'S",
#  'Commlttee',
#  '1::',
#  'A',
#  'fundlng',
#  'reconclllatlon',
#  'fundlng',
#  'a',
#  'fundlng',
#  'a',
#  'fundlng',
#  'bllllon',
#  'strlke',
#  'passlng',
#  'reconclllatlon,',
#  'fundlng',
#  'by',
#  'dlfflcult',
#  'fundlng',
#  '1935.',
#  'L15:',
#  "EMC'S",
#  'submltted',
#  'Llst.',
#  'cm',
#  "EPA'S",
#  'retalnlng',
#  'flexlblllty',
#  'requlrlng',
#  'RCRA.',
#  '1nd1cated',
#  'cm',
#  '039510',
#  'by',
#  'Analytlcal',
#  'Actlvltles',
#  'Contlngency',
#  'cm',
#  'lltlgatlon',
#  'challenglng',
#  "EPA'S",
#  'Contlngency',
#  "CMA'S",
#  'addltlon',
#  'm',
#  'determlnlng',
#  'establlshlng',
#  '1ncon515tent',
#  'mm',
#  'deflnlng',
#  "Dlvlslon's",
#  'Brleflngs',
#  'Washlngton',
#  '1w.v.7',
#  '(M1ch.7',
#  'Scrlpps*ﬂoward',
#  'SerV1CE,',
#  '1935,',
#  'cm',
#  'partlclpated',
#  'brleflngs',
#  'actlvlty',
#  'cm',
#  'TV',
#  'provldlng',
#  'dlstrlcts.',
#  'fundlng',
#  'Commlttee',
#  'fundlng;',
#  '1dent1£1catlon',
#  'whlch',
#  'contrlbuted',
#  'TV',
#  'dlstrlbuted',
#  'dlstrlcts.',
#  'dependlng',
#  'mllllon',
#  'mllllon',
#  'slmllar',
#  '5%.',
#  'asslsted',
#  'wrltten',
#  'cm',
#  '039511',
#  'a',
#  'Washlngton',
#  'urglng',
#  'dlstrlbutlng',
#  '"Cleanlng',
#  'dlstrlbuted',
#  'prlnts',
#  'cm',
#  "CMA'S",
#  'launchlng',
#  'a',
#  'dlstrlbutlon',
#  'cm',
#  'publlclty,',
#  '£11m.',
#  '(RCRA7',
#  'flrst',
#  'prohlblted',
#  'constltuents',
#  'establlsh',
#  'constltuents,',
#  'thls',
#  'lengthy',
#  'Leachlng',
#  '1935,',
#  'a',
#  'adoptlng',
#  'a',
#  'predlcts',
#  'leachlng,',
#  'perslstence',
#  'whlch',
#  'Hlth',
#  'whlch',
#  'Leachlng',
#  '1935,',
#  'a',
#  'predictlng',
#  'leachlng,',
#  'perslstence',
#  '51mllar',
#  '1935.',
#  'Burnlng',
#  'partlclpate',
#  'regardlng',
#  'burnlng',
#  'A',
#  'a',
#  'thls',
#  'actlvlty.',
#  'a',
#  's',
#  'cm',
#  '039512',
#  'dlvldes',
#  'burnlng',
#  'mm',
#  'Analytlcal',
#  'Actlvltles',
#  "EMC'S",
#  'publlshed',
#  'a',
#  'landfllls',
#  '1nc1nerators',
#  'analysls',
#  '199171994.',
#  'a',
#  '1935,',
#  'Hlth',
#  'concernlng',
#  'Codlflcatlon',
#  'cm',
#  'lltlgatlon',
#  'challenglng',
#  "EPA'S",
#  '1934.',
#  'quantlty',
#  'labelllng',
#  'mlnlmlze',
#  'llmltlng',
#  'Court...s',
#  'a',
#  'bannlng',
#  'Hlthln',
#  'by',
#  'a',
#  'a',
#  'a',
#  '1::',
#  'thls',
#  'a',
#  'Burnlng',
#  'a',
#  'concernlng',
#  'burnlng',
#  "EPA'S",
#  'antlclpated',
#  'burnlng',
#  'cm',
#  '039513',
#  'addltlon.',
#  'cm',
#  'burnlng',
#  'Industry,',
#  '1nv1ted',
#  'm',
#  'partlclpate',
#  'thls',
#  'a',
#  'by',
#  'a',
#  'by',
#  'technlcal,',
#  "CMA'S",
#  '1nv1ted',
#  'partlclpate',
#  'mrpcy',
#  'm',
#  'appllcable',
#  'meanlngful',
#  'A',
#  'partlclpate',
#  'actlvlty.',
#  'Actlvltles',
#  'Deflnltlon',
#  'cm',
#  'challenglng',
#  "EPA'S",
#  'deflnlng',
#  'resultlng',
#  'a',
#  'thd',
#  '3000',
#  'by',
#  'cm',
#  'convlnced',
#  '1::',
#  'thls',
#  'jurlsdlctlon.',
#  'supportlng',
#  'Codlflcatlon',
#  'a',
#  "EPA'S",
#  'codlfylng',
#  'by',
#  'cm',
#  'lltlgatlon',
#  'partlclpate',
#  'mm',
#  'clarlfylng',
#  'I',
#  'cm',
#  '039514',
#  'Actlvlty.',
#  'a',
#  'rlghtitoiknow',
#  'by',
#  'emlsslons',
#  'reportlng',
#  '(See',
#  'descrlptlon',
#  '"nghtitoiknow".7',
#  'whlch',
#  'hearlngs',
#  'Hlth',
#  '1935,',
#  'addltlonal',
#  'hearlngs,',
#  '2575,',
#  'regardlng',
#  'emlsslons',
#  'addltlonal',
#  'actlvlty',
#  '1935.',
#  'Actlvlty.',
#  'rlghtitoiknow',
#  'emlsslon',
#  'reportlng',
#  'emlsslons.',
#  'thls',
#  'by',
#  'hearlngs',
#  'hearlngs',
#  '1935,',
#  '&',
#  'Commlttee.',
#  "EMC'S",
#  'Emlsslon',
#  'submltted',
#  "Agency's",
#  "CMA'S",
#  'technlcal',
#  'by',
#  'technlcal',
#  'emlsslons',
#  'Emlsslons',
#  'mm',
#  'publlsh',
#  'emlsslons',
#  'mm',
#  'orlglnal',
#  'challenglng',
#  'emlsslons',
#  'pollcy.',
#  'cm',
#  '039515',
#  'emlsslons',
#  'emlsslons',
#  'pollcy.',
#  'publlsh',
#  'emlsslons',
#  'facllltates',
#  'Emlsslons',
#  "EMC'S",
#  'submltted',
#  'a',
#  'technlcal',
#  'a',
#  "CMA'S",
#  'technlcal',
#  'emlsslons',
#  '55515:',
#  'predlctlve',
#  'emlsslons',
#  'comprlslng',
#  'Analytlcal',
#  'Actlvltles',
#  'Prlnclples.',
#  'prlnclples',
#  'addresslng',
#  'prlnclples',
#  'emlsslons',
#  'emlsslons.',
#  'prlnclples,',
#  'by',
#  "CMA'S",
#  'Pollcy.',
#  'asslsted',
#  'Commlttee',
#  'a',
#  'pollcy.',
#  'thls',
#  'actlvlty,',
#  'pollcy,',
#  '1dent1£1ed',
#  'a',
#  'by',
#  'cm',
#  'by',
#  "CMA'S",
#  'a',
#  'technlcal',
#  '55515:',
#  'unplementlng',
#  'pollcy.',
#  'Actlvltles',
#  'submltted',
#  'a',
#  'by',
#  'Councll,',
#  'challenglng',
#  "EPA'S",
#  'emlsslon',
#  '"zeroirlsk,',
#  'emlsslon"',
#  'InstltutE.',
#  'a',
#  "EPA'S",
#  'feaslblllty',
#  'settlng',
#  'emlsslon',
#  '1nvolv1ng',
#  'emlsslon',
#  'whlch',
#  '"zeroirlsk,',
#  'emlsslon"',
#  'cm',
#  '039515',
#  'r',
#  'I',
#  'I',
#  'cm',
#  'flexlblllty',
#  'o',
#  'feaslblllty',
#  'settlng',
#  'emlsslon',
#  'cm',
#  'a',
#  'by',
#  'challenglng',
#  "EPA'S",
#  'emlsslon',
#  'flrst',
#  'm',
#  'm',
#  'rgln',
#  'h',
#  'a',
#  'thls',
#  'sprlng.',
#  'c',
#  'T',
#  'a',
#  'a',
#  't',
#  'e',
#  'a',
#  'c',
#  'Th',
#  'tlmlng',
#  'gr',
#  'nts',
#  'fundlng,',
#  'whlch',
#  'a',
#  'whlch',
#  'dlstrlbutlng',
#  'technlcal',
#  'dlscusslng',
#  'by',
#  'th',
#  'followlng:',
#  'cm',
#  'applylng',
#  'a',
#  'rs',
#  'cm',
#  'provldlng',
#  'admlnlstratlve',
#  '(APA7',
#  'admlnlstratlve',
#  'cltlzen',
#  'admlnlstratlve',
#  'clvll',
#  'crlmlnal',
#  'Eu',
#  'mm',
#  'cm',
#  'trlctlve',
#  'tiBest',
#  '(EAT)',
#  'cm',
#  'provldlng',
#  'responslblllty.',
#  'o',
#  'whlch',
#  'dlscharges',
#  'a',
#  'cm',
#  '039517',
#  'F',
#  "EMC'S",
#  'p',
#  'EPA...5',
#  'nlc',
#  'plastlcs,',
#  'synthetlc',
#  '(ocPsFy',
#  "CMA'S",
#  'hlghllght',
#  'technlcal',
#  "EPA'S",
#  'm',
#  "CMA'S",
#  "EPA'S",
#  'hlgh',
#  'addltlonal',
#  'mlght',
#  'mm',
#  '1::',
#  'Hlth',
#  "EPA'S",
#  'Asslstant',
#  'Admlnlstrator',
#  "CMA'S",
#  'mm',
#  "EMC'S",
#  'Permlts',
#  'p',
#  'submltted',
#  "EPA'S",
#  'modlflcatlons',
#  'stry',
#  'cm',
#  'mm',
#  'a',
#  'Prl',
#  'rlty',
#  'Llstlng/Dellstlng',
#  "EMC'S",
#  'mm',
#  'Pht',
#  "EPA'S",
#  '115mm;',
#  'ranklng',
#  '307157',
#  't',
#  '307157']

# %% [markdown]
# port to csv file

# %%
import pandas as pd
df = pd.DataFrame([name, arr, trash]).transpose()

# %%
df.head()
# Out:
#                                          0  \
# 0  ../data/tesseract/group5_00000009_5.txt
# 1  ../data/tesseract/group5_00000012_6.txt
# 2  ../data/tesseract/group4_00000009_1.txt
# 3  ../data/tesseract/group5_00000012_7.txt
# 4  ../data/tesseract/group5_00000009_4.txt
#
#                                                    1  \
# 0  communlcatlons network. Member companles are s...
# 1  general publlc. am has been meetlng Hlth congr...
# 2  AGENDA\nMEETING 017 THE cm BOARD 017 ummmns\nM...
# 3  24\nCMA 039755\nthere are 94 actlve partlclpan...
# 4  member company actlons m 1mprove the effectlve...
#
#                                                    2
# 0  [thls, CMA/LINC, crltlcal, 1dent1£1ed, by, m, ...
# 1  [publlc., Hlth, thls, thls, mlnlmlzatlon, a, t...
# 2  [cm, ummmns, Commlttee, Commlttee, E., Commltt...
# 3  [039755, partlclpants, appllcants, 1935,, mm, ...
# 4  [m, (:1:, gener.lly., m, speclflc, mm, 1nd1v1d...

# %%
problem_input = pd.read_csv('../output/output.csv')

# %%
#problem_input.head()

# %%
import ast
problem_list = ast.literal_eval(problem_input.iloc[0,3])
for i in range(1,problem_input.shape[0]):
    problem_list = problem_list + ast.literal_eval(problem_input.iloc[i,3])

# %%
problem_list
# Out:
# [('provlde', 'thls', 'needed'),
#  ('new', 'CMA/LINC', 'computer'),
#  ('the', 'crltlcal', 'envlronmental'),
#  ('lssues', '1dent1£1ed', 'by'),
#  ('1dent1£1ed', 'by', 'the'),
#  ('contlnue', 'm', 'be'),
#  ('Superfund:', 'whlch', 'are'),
#  ('study', 'by', 'the'),
#  ('the', 'cm', 'State'),
#  ('State', 'rlghtitoiknow', 'actlon'),
#  ("Jersey's", '"Toxlc', 'Catastrophe'),
#  ('the', 'reportlng', 'of'),
#  ('1nformatlon', 'concernlng', "1ndustry's"),
#  ('concernlng', "1ndustry's", 'operatlons'),
#  ('order', 'rlsk', 'reductlon'),
#  ('pushes', 'thls', 'lssue'),
#  ('along', 'Hlth', 'groundwater'),
#  ('states.', "CMA'S", 'State'),
#  ('actlve', 'partlclpant', '1n'),
#  ('1n', "CMA'S", 'development'),
#  ('toxlcs', 'pollcy.', 'A'),
#  ('pollcy.', 'A', 'new,'),
#  ('but', 'rapldly', 'growlng'),
#  ('reform.', "CMA'S", 'State'),
#  ('actlvely', 'partlclpatlng', '1n'),
#  ('and', '1nd1v1dual', 'companles'),
#  ('Exchange', 'Councll.', 'Nearly'),
#  ('of', 'thls', 'issue.'),
#  ('contlnue', 'm', 'be'),
#  ('1n', '1935.', 'Medla'),
#  ('3', 'cm', '039507'),
#  ('cm', '039507', 'The'),
#  ('air', 'toxlcs.', 'The'),
#  ('The', 'flrst', 'annlversary'),
#  ('related', 'actlvltles', 'of'),
#  ('chemlcals', '115mm;', 'and.'),
#  ('medla', 'analysls,', 'made'),
#  ('budget', 'reconclllatlon', 'process.'),
#  ('of', 'thls', 'attentlon'),
#  ('as', 'mlght', 'have'),
#  ('been', 'antlclpated', 'followlng'),
#  ('became', 'a', 'year'),
#  ('acute', '1nc1dents', '1n'),
#  ('of', 'exlstlng', 'law.'),
#  ('the', 'Instltute,', 'w.v.'),
#  ('Virginia,', 'Illlnols,', 'Dhlo'),
#  ('and', 'Pennsylvanla', 'were'),
#  ('about', 'thls', 'lssue'),
#  ('lssue', 'Hlth', 'questlons'),
#  ('and', 'deslgn.', 'New'),
#  ('our', 'actlvltles', 'relatlng'),
#  ('toxlcs', 'actlvltles', 'were'),
#  ('for', 'a', 'broad'),
#  ('1n', 'addltlon.', 'those'),
#  ('over', 'a', 'perlod'),
#  ('agree', 'mm', 'the'),
#  ('that', 'a', 'waste'),
#  ('bears', 'llttle', 'relatlonshlp'),
#  ('llttle', 'relatlonshlp', 'to'),
#  ('Federal', 'Marltlme', 'Commlsslon.'),
#  ('Marltlme', 'Commlsslon.', 'A'),
#  ('Commlsslon.', 'A', 'Vlctory'),
#  ('Vlctory', 'I', 'am,'),
#  ('and', 'affldavlts,', 'convlnced'),
#  ('affldavlts,', 'convlnced', 'an'),
#  ('an', 'Admlnlstratlve', 'Law'),
#  ('conanon', 'carrlers...', 'and'),
#  ('from', 'antltrust', 'laws.'),
#  ('Whlle', 'thls', 'declslon'),
#  ('entlre', 'Commlsslon.', '1:'),
#  ('as', 'a', 'precedent'),
#  ('from', 'obtalnlng', 'antltrust'),
#  ('obtalnlng', 'antltrust', 'exemptlons'),
#  ('price', 'settlng', 'and'),
#  ('Those', 'actlvltles', 'could'),
#  ('2mm', 'mllllon', 'dollars'),
#  ('Regulatory', 'Commlsslon.', 'Another'),
#  ('Regulatory', 'Commlsslon', '(mum'),
#  ('approved', 'a', 'rule'),
#  ('4', 'cm', 'means'),
#  ('rule', '(Order', 'No.'),
#  ('market', 'by', 'facllltatlng'),
#  ('by', 'facllltatlng', 'the'),
#  ('unplemented', 'by', 'the'),
#  ('be', 'a', 'substantlal'),
#  ('cost', 'savlngs', 'to'),
#  ('annual', 'savlngs', 'for'),
#  ('for', 'cm', 'members'),
#  ('$750', 'mllllon.', 'In'),
#  ('In', 'addltlon.', 'cm'),
#  ('addltlon.', 'cm', 'and'),
#  ('of', 'a', 'new'),
#  ('block', 'bllllng', 'mechanlsm'),
#  ('CMA', 'testlfled', 'that'),
#  ('block', 'bllllng', 'would'),
#  ('would', 'slgnlflcantly', 'ralse'),
#  ('consumers.', 'A', 'study'),
#  ('study', 'submltted', 'by'),
#  ('submltted', 'by', 'cm'),
#  ('by', 'cm', '1nd1cated'),
#  ('cm', '1nd1cated', 'that'),
#  ('million.', "FERC'S", 'actlon'),
#  ('15', 'a', 'major'),
#  ('for', 'cm', 'and'),
#  ('the', 'Commlsslon', '15'),
#  ('contlnulng', '1::', 'assessment'),
#  ('block', 'bllllng', 'and'),
#  ('15', '5:111', 'posslble.'),
#  ('5:111', 'posslble.', '11.'),
#  ('Senate', 'Actlvlty', 'The'),
#  ('sltes', 'by', 'freezlng'),
#  ('unposlng', 'a', 'broadibased'),
#  ('Flnance', 'Commlttee', 'put'),
#  ('Superfund', 'fundlng', 'package'),
#  ('budget', 'reconclllatlon', 'mu'),
#  ('mu', 'whlch', 'passed'),
#  ('Helms', '”Ham', 'offered'),
#  ('Superfund', 'fundlng', 'from'),
#  ('budget', 'reconclllatlon', 'leglslatlon.'),
#  ('as', 'm', '32.'),
#  ('conflmed', '1::', 'support'),
#  ('for', 'a', 'broadibased'),
#  ('House', 'Actlvlty', 'The'),
#  ('Voted', '391733', 'on'),
#  ('10', 'm', 'reauthorlze'),
#  ('program', 'by', 'slgnlflcantly'),
#  ('by', 'slgnlflcantly', '1ncreaslng'),
#  ('Ways', '&', 'Means'),
#  ('Means', "Commlttee's", 'broadibased'),
#  ('tax', 'whlch', 'was'),
#  ('opposed', 'by', 'Presldent'),
#  ('the', 'envlronmentallsts,', 'and'),
#  ('and', 'a', 'broad'),
#  ('manufacturers,', 'Hlth', 'thls'),
#  ('Hlth', 'thls', 'Page'),
#  ('5', 'cm', '039509'),
#  ('cm', '039509', 'support,'),
#  ("Downey's", '(Drum', 'and'),
#  ('and', '13111', "Frenzel's"),
#  ('amendment.', '2207206,', 'to'),
#  ('the', '510.3', 'bllllon'),
#  ('510.3', 'bllllon', 'Superfund'),
#  ('from', 'a', '$2'),
#  ('$2', 'bllllon', 'tax'),
#  ('53.1', 'bllllon', 'from'),
#  ('from', 'a', 'crude'),
#  ('from', 'a', 'waste'),
#  ('51.5', 'bllllon', 'from'),
#  ('were', 'a', 'compromlse'),
#  ('Energy', '&', 'Commerce'),
#  ('Works', '&', 'Transportatlon'),
#  ('Transportatlon', 'Commlttees', 'proposals.'),
#  ('standards,', 'cltlzen', 'sluts,'),
#  ('and', 'rlghtitoiknow', 'provlslons'),
#  ('1nclud1ng', 'a', 'requlrement'),
#  ('create', 'a', 'federal'),
#  ('provlslons,', 'whlch', 'was'),
#  ('was', 'a', 'key'),
#  ('the', 'fundlng', 'level,'),
#  ('much', 'dlscretlon', 'to'),
#  ('give', 'EPA.', 'The'),
#  ('do', '1:,', 'where'),
#  ('of', "CMA'S", 'Government'),
#  ('Relatlons', 'Commlttee', 'will'),
#  ('focus', '1::', 'attentlon'),
#  ('conferees.', 'A', 'strategy'),
#  ('provlde', 'fundlng', 'for'),
#  ('budget', 'reconclllatlon', 'began'),
#  ('Superfund', 'fundlng', 'lssues.'),
#  ('on', 'a', 'compromlse'),
#  ('Senate', 'fundlng', 'mechanlsm'),
#  ('and', 'a', 'broadibased'),
#  ('House', 'fundlng', 'level'),
#  ('$10', 'bllllon', 'over'),
#  ('to', 'strlke', 'the'),
#  ('wlthout', 'passlng', 'budget'),
#  ('budget', 'reconclllatlon,', 'the'),
#  ('dlfferent', 'fundlng', 'approaches'),
#  ('approved', 'by', 'the'),
#  ('how', 'dlfflcult', 'the'),
#  ('the', 'fundlng', 'lssue'),
#  ('1n', '1935.', 'Regulatory'),
#  ('Prlorlty', 'L15:', 'Comments.'),
#  ('The', "EMC'S", 'Superfund'),
#  ('Group', 'submltted', 'comments'),
#  ('Prlorlty', 'Llst.', 'The'),
#  ('prlmary', 'cm', 'concern'),
#  ('was', "EPA'S", 'retalnlng'),
#  ("EPA'S", 'retalnlng', 'flexlblllty'),
#  ('retalnlng', 'flexlblllty', '1n'),
#  ('1n', 'requlrlng', 'cleanups'),
#  ('or', 'RCRA.', 'we'),
#  ('we', '1nd1cated', 'Page'),
#  ('5', 'cm', '039510'),
#  ('cm', '039510', 'that'),
#  ('governed', 'by', 'one'),
#  ('Development,', 'Analytlcal', 'and'),
#  ('Program', 'Actlvltles', 'Natlonal'),
#  ('Natlonal', 'Contlngency', 'Plan'),
#  ('authorlzed', 'cm', 'to'),
#  ('1n', 'lltlgatlon', 'challenglng'),
#  ('lltlgatlon', 'challenglng', "EPA'S"),
#  ('challenglng', "EPA'S", 'revlslons'),
#  ('Natlonal', 'Contlngency', 'Plan.'),
#  ('Plan.', "CMA'S", 'concerns'),
#  ('1n', 'addltlon', 'm'),
#  ('addltlon', 'm', 'healthibased'),
#  ('of', 'determlnlng', 'what'),
#  ('EPA', 'establlshlng', 'costieffectlveness'),
#  ('crlterla', '1ncon515tent', 'mm'),
#  ('1ncon515tent', 'mm', 'the'),
#  ('of', 'deflnlng', 'the'),
#  ('Servlce', "Dlvlslon's", 'efforts'),
#  ('perlod.', 'Brleflngs', 'on'),
#  ('on', 'Washlngton', 'correspondents'),
#  ('Charleston', '1w.v.7', 'Dally'),
#  ('Detrolt', '(M1ch.7', 'Free'),
#  ('Press,', 'Scrlpps*ﬂoward', 'News'),
#  ('News', 'SerV1CE,', 'and'),
#  ('of', '1935,', 'cm'),
#  ('1935,', 'cm', 'offlcers,'),
#  ('have', 'partlclpated', '1n'),
#  ('133', 'brleflngs', 'on'),
#  ('radlo', 'actlvlty', '1ncreased'),
#  ('December.', 'cm', 'made'),
#  ('"alternatlve', 'TV', 'network,"'),
#  ('network,"', 'provldlng', 'speclally'),
#  ('Congresslonal', 'dlstrlcts.', 'Subjects'),
#  ('Superfund', 'fundlng', 'proposal'),
#  ('Means', 'Commlttee', 'passed'),
#  ('Superfund', 'fundlng;', 'and'),
#  ('and', '1dent1£1catlon', 'of'),
#  ('1ndustr1es', 'whlch', 'have'),
#  ('have', 'contrlbuted', 'waste'),
#  ('Targeted', 'TV', 'newsfeeds'),
#  ('were', 'dlstrlbuted', '1n'),
#  ('Congresslonal', 'dlstrlcts.', 'Usage,'),
#  ('Usage,', 'dependlng', 'on'),
#  ('1.9', 'mllllon', 'to'),
#  ('4.5', 'mllllon', 'people.'),
#  ('on', 'slmllar', 'Superfund'),
#  ('nearly', '5%.', 'The'),
#  ('also', 'asslsted', '1n'),
#  ('of', 'wrltten', 'materlals'),
#  ('7', 'cm', '039511'),
#  ('cm', '039511', 'Immedlately'),
#  ('placed', 'a', 'full'),
#  ('the', 'Washlngton', 'Post'),
#  ('Post', 'urglng', 'members'),
#  ('15', 'dlstrlbutlng', '"Cleanlng'),
#  ('dlstrlbutlng', '"Cleanlng', 'Up"'),
#  ('been', 'dlstrlbuted', 'to'),
#  ('110', 'prlnts', 'have'),
#  ('to', 'cm', 'member'),
#  ('programs.', "CMA'S", 'Communlty'),
#  ('15', 'launchlng', 'a'),
#  ('launchlng', 'a', '£11m'),
#  ('£11m', 'dlstrlbutlon', 'plan'),
#  ('1ncludes', 'cm', '1nvolvement,'),
#  ('contacts,', 'publlclty,', 'natlonal'),
#  ('the', '£11m.', 'Hazardous'),
#  ('Management', '(RCRA7', 'Regulatory'),
#  ('1:5', 'flrst', 'set'),
#  ('be', 'prohlblted', 'unless'),
#  ('hazardous', 'constltuents', '1n'),
#  ('will', 'establlsh', 'for'),
#  ('hazardous', 'constltuents,', 'or'),
#  ('on', 'thls', 'unportant'),
#  ('and', 'lengthy', 'new'),
#  ('Inorganlc', 'Leachlng', 'Model.'),
#  ('27,', '1935,', 'EPA'),
#  ('lssued', 'a', 'flnal'),
#  ('rule', 'adoptlng', 'a'),
#  ('adoptlng', 'a', 'model'),
#  ('that', 'predlcts', 'the'),
#  ('the', 'leachlng,', 'mlgratlon'),
#  ('and', 'perslstence', 'of'),
#  ('determlne', 'whlch', '1norgan1c'),
#  ('model.', 'Hlth', 'some'),
#  ('detemlne', 'whlch', '1norgan1c'),
#  ('Drganlc', 'Leachlng', 'Model.'),
#  ('27,', '1935,', 'EPA'),
#  ('proposed', 'a', 'model'),
#  ('for', 'predictlng', 'the'),
#  ('the', 'leachlng,', 'mlgratlon,'),
#  ('and', 'perslstence', 'or'),
#  ('15', '51mllar', 'to'),
#  ('13,', '1935.', 'Burnlng'),
#  ('1935.', 'Burnlng', 'of'),
#  ('Hill', 'partlclpate', '1n'),
#  ('1995', 'regardlng', 'the'),
#  ('of', 'burnlng', 'hazardous'),
#  ('hollers.', 'A', 'consensus'),
#  ('of', 'a', 'rule'),
#  ('regulate', 'thls', 'actlvlty.'),
#  ('thls', 'actlvlty.', 'The'),
#  ('prepared', 'a', 'regulatory'),
#  ('Page', 's', 'cm'),
#  ('s', 'cm', '039512'),
#  ('cm', '039512', 'Workshop.'),
#  ('proposal', 'dlvldes', 'hazardous'),
#  ('waste', 'burnlng', '1nto'),
#  ('categorles', 'mm', 'greater'),
#  ('Development,', 'Analytlcal', 'and'),
#  ('Program', 'Actlvltles', '1994'),
#  ('The', "EMC'S", 'RCRA'),
#  ('has', 'publlshed', 'the'),
#  ('show', 'a', 'contlnulng'),
#  ('on', 'landfllls', 'for'),
#  ('on', '1nc1nerators', 'for'),
#  ('trend', 'analysls', 'compares'),
#  ('years', '199171994.', '1995'),
#  ('conduct', 'a', '1995'),
#  ('1n', '1935,', 'Hill'),
#  ('CMA', 'Hlth', 'the'),
#  ('matters', 'concernlng', 'hazardous'),
#  ('RCRA', 'Codlflcatlon', 'Rule'),
#  ('authorlzed', 'cm', 'to'),
#  ('1n', 'lltlgatlon', 'challenglng'),
#  ('lltlgatlon', 'challenglng', "EPA'S"),
#  ('challenglng', "EPA'S", 'regulatlons'),
#  ('of', '1934.', 'These'),
#  ('small', 'quantlty', 'generator'),
#  ('the', 'labelllng', 'requlrements'),
#  ('waste', 'mlnlmlze', 'provlslons,'),
#  ('certaln', 'llmltlng', 'factors.'),
#  ('supreme', 'Court...s', 'conslderatlon'),
#  ('of', 'a', 'local'),
#  ('ordlnance', 'bannlng', 'all'),
#  ('facilities', 'Hlthln', 'the'),
#  ('addressed', 'by', 'the'),
#  ('preempt:', 'a', 'local'),
#  ('to', 'a', 'federal'),
#  ('can', 'a', 'locallty'),
#  ('Within', '1::', 'borders.'),
#  ('of', 'thls', 'case'),
#  ('have', 'a', 'longiterm'),
#  ('wastes.', 'Burnlng', '1n'),
#  ('approved', 'a', 'revlsed'),
#  ('paper', 'concernlng', 'regulatlon'),
#  ('the', 'burnlng', 'of'),
#  ('to', "EPA'S", 'antlclpated'),
#  ("EPA'S", 'antlclpated', 'proposed'),
#  ('the', 'burnlng', 'of'),
#  ('9', 'cm', '039513'),
#  ('cm', '039513', '1n'),
#  ('In', 'addltlon.', 'the'),
#  ('3', 'cm', 'sponsored'),
#  ('on', 'burnlng', 'hazardous'),
#  ('hollers.', 'Industry,', 'government,'),
#  ('been', '1nv1ted', 'm'),
#  ('1nv1ted', 'm', 'partlclpate'),
#  ('m', 'partlclpate', '1n'),
#  ('1n', 'thls', 'consensus'),
#  ('developed', 'a', '115:'),
#  ('dlsposed', 'by', 'underground'),
#  ('have', 'a', 'threat'),
#  ('dlsposed', 'by', 'underground'),
#  ('address', 'technlcal,', 'legal,'),
#  ('Negotlatlons.', "CMA'S", 'Underground'),
#  ('been', '1nv1ted', 'to'),
#  ('to', 'partlclpate', '1n'),
#  ('Councll', 'mrpcy', 'exploratory'),
#  ('meetlng', 'm', 'determlne'),
#  ('ban', 'appllcable', 'to'),
#  ('to', 'meanlngful', 'and'),
#  ('negotlatlons.', 'A', 'fundamental'),
#  ('to', 'partlclpate', '1n'),
#  ('negotlatlon', 'actlvlty.', 'thlgatlon'),
#  ('Related', 'Actlvltles', 'Deflnltlon'),
#  ('Actlvltles', 'Deflnltlon', 'of'),
#  ('waste.', 'cm', '15'),
#  ('15', 'challenglng', '1n'),
#  ('Appeals', "EPA'S", 'January'),
#  ('rule', 'deflnlng', 'solld'),
#  ('materlals', 'resultlng', 'from'),
#  ('from', 'a', 'manufacturlng'),
#  ('1n', 'thd', 'same'),
#  ('estlmated', '3000', 'to'),
#  ('used', 'by', 'cm'),
#  ('by', 'cm', 'members'),
#  ('has', 'convlnced', 'EPA'),
#  ('to', '1::', 'rules'),
#  ('exclude', 'thls', '"closediloop"'),
#  ('EPA', 'jurlsdlctlon.', 'EPA'),
#  ('comments', 'supportlng', 'the'),
#  ('amendment.', 'Codlflcatlon', 'Rule/Correctlve'),
#  ('1n', 'a', 'challenge'),
#  ('to', "EPA'S", 'July'),
#  ('rule', 'codlfylng', 'the'),
#  ('damaged', 'by', 'prior'),
#  ('releases.', 'cm', '15'),
#  ('the', 'lltlgatlon', 'and'),
#  ('may', 'partlclpate', '1n'),
#  ('negotlatlons', 'mm', 'EPA'),
#  ('at', 'clarlfylng', 'the'),
#  ('Alr', 'I', 'Page'),
#  ('10', 'cm', '039514'),
#  ('cm', '039514', 'Congresslonal'),
#  ('House', 'Actlvlty.', 'The'),
#  ('contalns', 'a', 'communlty'),
#  ('communlty', 'rlghtitoiknow', 'amendment'),
#  ('sponsored', 'by', 'Rep.'),
#  ('alr', 'emlsslons', 'reportlng'),
#  ('emlsslons', 'reportlng', 'requlrements.'),
#  ('requlrements.', '(See', 'further'),
#  ('further', 'descrlptlon', 'under'),
#  ('under', '"nghtitoiknow".7', 'The'),
#  ('257a,', 'whlch', 'Rep.'),
#  ('held', 'hearlngs', 'on'),
#  ('preoccupled', 'Hlth', 'Superfund,'),
#  ('1n', '1935,', 'Waxman'),
#  ('mean', 'addltlonal', 'hearlngs,'),
#  ('addltlonal', 'hearlngs,', 'changes'),
#  ('3.x.', '2575,', 'or'),
#  ('sources', 'regardlng', 'air'),
#  ('air', 'emlsslons', 'and'),
#  ('for', 'addltlonal', 'alr'),
#  ('toxlcs', 'actlvlty', '1n'),
#  ('1n', '1935.', 'Senate'),
#  ('Senate', 'Actlvlty.', 'The'),
#  ('communlty', 'rlghtitoiknow', 'emlsslon'),
#  ('rlghtitoiknow', 'emlsslon', 'reportlng'),
#  ('emlsslon', 'reportlng', 'requlrements'),
#  ('alr', 'emlsslons.', 'am'),
#  ('address', 'thls', 'provlslon,'),
#  ('sponsored', 'by', 'Senator'),
#  ('Senate', 'hearlngs', 'or'),
#  ('Senate', 'hearlngs', 'on'),
#  ('December', '1935,', 'and'),
#  ('Envlronment', '&', 'Publlc'),
#  ('Works', 'Commlttee.', 'Regulatory'),
#  ('The', "EMC'S", 'Process'),
#  ('Process', 'Emlsslon', 'Regulatlons'),
#  ('Group', 'submltted', 'comments'),
#  ('the', "Agency's", 'notlce'),
#  ('pollutants.', "CMA'S", 'comments'),
#  ('the', 'technlcal', 'adequacy'),
#  ('conducted', 'by', 'EPA'),
#  ('more', 'technlcal', 'analyses'),
#  ('chromlum', 'emlsslons', 'result'),
#  ('problems.', 'Emlsslons', 'Tradlng'),
#  ('conjunctlon', 'mm', 'other'),
#  ('to', 'publlsh', 'an'),
#  ('an', 'emlsslons', 'tradlng'),
#  ('llne', 'mm', 'the'),
#  ('the', 'orlglnal', '1ntent'),
#  ('partles', 'challenglng', 'an'),
#  ('alr', 'emlsslons', 'pollcy.'),
#  ('emlsslons', 'pollcy.', 'The'),
#  ('11', 'cm', '039515'),
#  ('cm', '039515', 'an'),
#  ('air', 'emlsslons', 'tradlng'),
#  ('an', 'emlsslons', 'tradlng'),
#  ('tradlng', 'pollcy.', 'The'),
#  ('to', 'publlsh', 'an'),
#  ('an', 'emlsslons', 'tradlng'),
#  ('that', 'facllltates', '1ndustry'),
#  ('Secondary', 'Emlsslons', 'Comments.'),
#  ('The', "EMC'S", 'Process'),
#  ('Group', 'submltted', 'comments'),
#  ('on', 'a', 'technlcal'),
#  ('a', 'technlcal', 'report'),
#  ('developmg', 'a', 'program'),
#  ('facilities.', "CMA'S", 'comments'),
#  ('on', 'technlcal', 'aspects'),
#  ('air', 'emlsslons', 'from'),
#  ('to', '55515:', '1n'),
#  ('accurate', 'predlctlve', 'models'),
#  ('alr', 'emlsslons', 'from'),
#  ('unlts', 'comprlslng', 'waste'),
#  ('Development,', 'Analytlcal', 'and'),
#  ('Program', 'Actlvltles', '1'),
#  ('Leglslatlve', 'Prlnclples.', 'The'),
#  ('recommended', 'prlnclples', 'for'),
#  ('for', 'addresslng', 'federal'),
#  ('recommended', 'prlnclples', 'address'),
#  ('routlne', 'emlsslons', 'and'),
#  ('accldental', 'emlsslons.', 'The'),
#  ('The', 'prlnclples,', '15'),
#  ('adopted', 'by', 'the'),
#  ('developlng', "CMA'S", 'alr'),
#  ('Control', 'Pollcy.', 'The'),
#  ('has', 'asslsted', 'members'),
#  ('Executlve', 'Commlttee', '1n'),
#  ('developlng', 'a', 'proposed'),
#  ('control', 'pollcy.', 'As'),
#  ('of', 'thls', 'actlvlty,'),
#  ('thls', 'actlvlty,', 'EMC'),
#  ('control', 'pollcy,', 'and'),
#  ('and', '1dent1£1ed', 'Varlous'),
#  ('such', 'a', 'pollcy'),
#  ('1mplemented', 'by', 'cm'),
#  ('by', 'cm', 'member'),
#  ('approved', 'by', "CMA'S"),
#  ('by', "CMA'S", 'Board'),
#  ('plans', 'a', 'Significant'),
#  ('and', 'technlcal', 'program'),
#  ('to', '55515:', 'the'),
#  ('1n', 'unplementlng', 'the'),
#  ('control', 'pollcy.', 'thlgatlon'),
#  ('Related', 'Actlvltles', 'Benzene'),
#  ('has', 'submltted', '1:5'),
#  ('1n', 'a', 'court'),
#  ('brought', 'by', 'the'),
#  ('Defense', 'Councll,', 'Inc.'),
#  ('(mum)', 'challenglng', "EPA'S"),
#  ('challenglng', "EPA'S", 'emlsslon'),
#  ("EPA'S", 'emlsslon', 'standards'),
#  ('set', '"zeroirlsk,', 'zero'),
#  ('zero', 'emlsslon"', 'standards'),
#  ('Petroleum', 'InstltutE.', 'who'),
#  ('15', 'a', 'party,'),
#  ('of', "EPA'S", 'posltlon'),
#  ('and', 'feaslblllty', '1nto'),
#  ('1n', 'settlng', 'emlsslon'),
#  ('settlng', 'emlsslon', 'standards.'),
#  ('case', '1nvolv1ng', 'emlsslon'),
#  ('1nvolv1ng', 'emlsslon', 'standards'),
#  ('case,', 'whlch', 'ralses'),
#  ('set', '"zeroirlsk,', 'zero'),
#  ('zero', 'emlsslon"', 'standards'),
#  ('12', 'cm', '039515'),
#  ('cm', '039515', 'r'),
#  ('039515', 'r', 'I'),
#  ('r', 'I', 'I'),
#  ('I', 'I', 'all'),
#  ('carclnogens.', 'cm', 'counters'),
#  ('has', 'flexlblllty', 'under'),
#  ('statute', 'o', 'conslder'),
#  ('and', 'feaslblllty', '1n'),
#  ('1n', 'settlng', 'emlsslon'),
#  ('settlng', 'emlsslon', 'standards.'),
#  ('Litigation.', 'cm', 'prevlously'),
#  ('1n', 'a', 'court'),
#  ('rough:', 'by', 'mum'),
#  ('mum', 'challenglng', "EPA'S"),
#  ('challenglng', "EPA'S", 'emlsslon'),
#  ("EPA'S", 'emlsslon', 'standards'),
#  ('the', 'flrst', 'm'),
#  ('flrst', 'm', 'declde'),
#  ('"ample', 'm', 'rgln'),
#  ('m', 'rgln', 'of'),
#  ('brlefs', 'h', 'we'),
#  ('and', 'a', 'declslon'),
#  ('expected', 'thls', 'sprlng.'),
#  ('thls', 'sprlng.', 'c'),
#  ('sprlng.', 'c', 'mmunlcatlons'),
#  ('mmunlcatlons', 'T', 'a'),
#  ('T', 'a', 'department'),
#  ('prepared', 'a', 'summary'),
#  ('on', 't', 'e'),
#  ('t', 'e', 'mngen'),
#  ('Water', 'a', 'gresslonal'),
#  ('Response', 'c', 'ference'),
#  ('Superfund.', 'Th', 'tlmlng'),
#  ('Th', 'tlmlng', 'depends'),
#  ('constructlon', 'gr', 'nts'),
#  ('gr', 'nts', 'fundlng,'),
#  ('nts', 'fundlng,', 'whlch'),
#  ('fundlng,', 'whlch', '15'),
#  ('cm.', 'a', "'5"),
#  ('on', 'whlch', 'the'),
#  ('un', 'dlstrlbutlng', 'technlcal'),
#  ('dlstrlbutlng', 'technlcal', 'papers'),
#  ('and', 'dlscusslng', '1mprovements'),
#  ('needed', 'by', 'th'),
#  ('by', 'th', 'conferees,'),
#  ('the', 'followlng:', '0'),
#  ('7', 'cm', 'supports'),
#  ('Verslon', 'applylng', 'a'),
#  ('applylng', 'a', '3'),
#  ('ye', 'rs', 'deadllne.'),
#  ('7', 'cm', 'supports'),
#  ('Verslon', 'provldlng', 'for'),
#  ('for', 'admlnlstratlve', 'pe'),
#  ('hearlng', '(APA7', 'procedures;'),
#  ('maxlmum', 'admlnlstratlve', 'c1'),
#  ('penaltles;', 'cltlzen', '5m:'),
#  ('to', 'admlnlstratlve', 'pe'),
#  ('judlclal', 'clvll', 'penaltles;'),
#  ('agalnst', 'crlmlnal', 'penaltles.'),
#  ('0', 'Eu', 'damentally'),
#  ('Factors', 'mm', 'Varlances'),
#  ('7', 'cm', 'supports'),
#  ('re', 'trlctlve', 'Senate'),
#  ('Po', 'tiBest', 'Avallable'),
#  ('Technology', '(EAT)', 'Requlrements'),
#  ('7', 'cm', 'prefers'),
#  ('Verslon', 'provldlng', 'more'),
#  ('state', 'responslblllty.', 'o'),
#  ('responslblllty.', 'o', '5:'),
#  ('Verslon', 'whlch', 'better'),
#  ('of', 'dlscharges', 'that'),
#  ('for', 'a', 'better'),
#  ('13', 'cm', '039517'),
#  ('cm', '039517', 'ocp'),
#  ('ocp', 'F', 'Effluent'),
#  ('Comments.', "EMC'S", 'Effluent'),
#  ('Gro', 'p', 'developed'),
#  ('on', 'EPA...5', 'proposed'),
#  ('org', 'nlc', 'chemlcals,'),
#  ('chemlcals,', 'plastlcs,', 'and'),
#  ('and', 'synthetlc', 'flbers'),
#  ('flbers', '(ocPsFy', 'effluent'),
#  ('ellnes.', "CMA'S", 'comments'),
#  ('comments', 'hlghllght', 'technlcal'),
#  ('hlghllght', 'technlcal', 'problems'),
#  ('1n', "EPA'S", 'reg'),
#  ('alternatlves', 'm', 'achleve'),
#  ('results.', "CMA'S", 'comments'),
#  ('on', "EPA'S", 'fallure'),
#  ('the', 'hlgh', 'levels'),
#  ('enomous', 'addltlonal', 'costs'),
#  ('that', 'mlght', 'be'),
#  ('mposed', 'mm', 'minimal'),
#  ('and', '1::', 'member'),
#  ('met', 'Hlth', "EPA'S"),
#  ('Hlth', "EPA'S", 'Asslstant'),
#  ("EPA'S", 'Asslstant', 'Admlnlstrator'),
#  ('Asslstant', 'Admlnlstrator', 'for'),
#  ('dlscussed', "CMA'S", 'concern'),
#  ('concern', 'mm', 'the'),
#  ('Comments.', "EMC'S", 'Water'),
#  ('Water', 'Permlts', 'Task'),
#  ('Gro', 'p', 'submltted'),
#  ('p', 'submltted', 'comments'),
#  ('for', "EPA'S", '"ge'),
#  ('several', 'modlflcatlons', 'to'),
#  ('1nd', 'stry', 'concerns.'),
#  ('concerns.', 'cm', 'representatlves'),
#  ('recommedatlons', 'mm', 'EPA'),
#  ('be', 'a', 'reasonable'),
#  ('requlrement.', 'Prl', 'rlty'),
#  ('Prl', 'rlty', 'Pollutant'),
#  ('Pollutant', 'Llstlng/Dellstlng', 'Comments.'),
#  ('The', "EMC'S", 'Water'),
#  ('conjunctlon', 'mm', 'the'),
#  ('the', 'Pht', 'slate'),
#  ('on', "EPA'S", 'report'),
#  ('est', '115mm;', '3'),
#  ('3', 'ranklng', '115:'),
#  ('Sectlon', '307157', 'prlorlty'),
#  ('rep', 't', 'offers'),
#  ('on', '307157', 'prlorlty'),
#  ('general', 'publlc.', 'am'),
#  ('meetlng', 'Hlth', 'congresslonal'),
#  ('dlscuss', 'thls', 'issue.'),
#  ('At', 'thls', 'point,'),
#  ('waste', 'mlnlmlzatlon', 'Will'),
#  ('be', 'a', 'prlorlty'),
#  ('on', 'thls', 'lssue'),
#  ('Very', 'llttle', 'actlvlty'),
#  ('llttle', 'actlvlty', '1:'),
#  ('the', 'flrst', 'part'),
#  ('of', '1937,', 'waste'),
#  ('waste', 'mlnlmlzatlon', 'Will'),
#  ('an', 'emerglng', 'lssue'),
#  ('Inlectlon', 'Commlttee.', 'The'),
#  ('led', 'by', 'the'),
#  ('the', 'ellmlnatlon', 'of'),
#  ('CMA', '039755', 'prlorltles.'),
#  ('leglslatlon', 'prohlbltlng', 'underground'),
#  ('chemlcal', '1ndustry,', 'whlch'),
#  ('1ndustry,', 'whlch', '15'),
#  ('been', 'contactlng', 'Congressmen'),
#  ('thelr', 'dlstrlcts', 'to'),
#  ('on', 'a', 'regular'),
#  ('1njectlon', 'perslsts.', 'Although'),
#  ('no', 'hearlngs', 'Will'),
#  ('held', 'speclflcally', 'on'),
#  ('early', '1937,', 'we'),
#  ('lssue', 'm', 'be'),
#  ('RCRA', 'overslght', 'hearlngs'),
#  ('overslght', 'hearlngs', 'throughout'),
#  ('comnunlcata', 'Hlth', 'Congress'),
#  ('begln', 'm', 'recelve'),
#  ('January', '1937.', '2.'),
#  ('CMA', 'submltted', 'comments'),
#  ('on', "EPA'S", 'announcement'),
#  ('the', 'avaliablllty', 'of'),
#  ('dlsposal', 'restrlctlons.', 'The'),
#  ('1n', 'landfllls.', "CMA'S"),
#  ('landfllls.', "CMA'S", 'comments'),
#  ('the', 'varlablllty', 'factor'),
#  ('base', 'modlflcatlons,', 'and'),
#  ('from', 'a', 'treatment'),
#  ('Development,', 'Analytlcal', 'and'),
#  ('Program', 'Actlvltles', 'RCRA'),
#  ('Workshop.', 'cm', 'sponsored'),
#  ('sponsored', 'a', 'RCRA'),
#  ('December', '1112,', '1935.'),
#  ('1112,', '1935.', 'Approxlmately'),
#  ('representatlves', 'partlclpated', '1n'),
#  ('workshop.', 'cm', 'and'),
#  ('addressed', 'a', 'Wide'),
#  ('lssues,', '1.e.,', 'land'),
#  ('organlc', 'toxlclty', 'proposal,'),
#  ('strategy,', 'mmmum', 'technology'),
#  ('Related', 'Actlvltles', 'CMA'),
#  ('EPA', '(Closure', 'rulel.'),
#  ('rulel.', 'cm', '15'),
#  ('15', 'challenglng', "EPA'S"),
#  ('challenglng', "EPA'S", 'flnal'),
#  ('or', 'landflll', 'm'),
#  ('landflll', 'm', 'recelve'),
#  ('stops', 'recelvlng', 'hazardous'),
#  ('closed', 'Hlthln', '180'),
#  ('negotlatlons,', 'Hlth', 'the'),
#  ('than', 'retroflttlng', 'luvpoundments'),
#  ('luvpoundments', 'Hlth', 'double'),
#  ('CMA', '039755', 'Hazardous'),
#  ('EPA', '(Land', 'Dlsposal'),
#  ('Dlsposal', 'Rastrlcuonsy.', 'CMA'),
#  ('1n', 'a', 'challenge'),
#  ('challenge', 'by', 'the'),
#  ('Councll', 'm', "EPA'S"),
#  ('m', "EPA'S", 'November'),
#  ('7,', '1935,', 'flnal'),
#  ('rule', 'restrlctlng', 'the'),
#  ('and', 'dloxlns.', 'CMA'),
#  ('support', "EPA'S", 'rule'),
#  ('15', '1nsufflc1ent', 'capaclty'),
#  ('treat', 'a', 'waste,'),
#  ('an', 'exlstlng', 'unlt'),
#  ('not', 'doublE*llned', 'for'),
#  ('of', "EPA'S", 'flnal'),
#  ('rule.', 'Speclflcally,', 'am'),
#  ('challenge', "EPA'S", 'llmltatlon'),
#  ("EPA'S", 'llmltatlon', 'of'),
#  ('to', '1nd1v1dual', 'wastes'),
#  ('at', '1nd1v1dual', 'unlts.'),
#  ('1nd1v1dual', 'unlts.', '"No'),
#  ('unlts.', '"No', 'mlgratlon"'),
#  ('Flnally,', 'cm', 'may'),
#  ('challenge', "EPA'S", 'requlrement'),
#  ('requlrement', 'm', 'use'),
#  ('use', 'a', 'zero'),
#  ('extractor', '(zaEy', 'for'),
#  ('when', 'assesslng', 'the'),
#  ('be', 'landfllled.', 'The'),
#  ('The', 'Varlablllty', 'of'),
#  ('the', "Agency's", 'November'),
#  ('13,', '1935,', 'rule'),
#  ('rule', 'adoptlng', 'the'),
#  ('for', 'dellstlng', 'organlc'),
#  ('1n', 'landfllls.', 'am'),
#  ('challenge', "EPA'S", 'refusal'),
#  ('conslderlng', '51te*speclflc', 'factors'),
#  ('when', 'decldlng', 'm'),
#  ('decldlng', 'm', 'dellst'),
#  ('of', '51te*speclflc', 'factors'),
#  ('Groundwater', '(Includes', 'Safe'),
#  ('Safe', 'Drlnklng', 'Water'),
#  ('leglslatlon.', 'cm', 'contlnues'),
#  ('contlnues', 'm', 'belleve'),
#  ('could', 'establlsh', 'new'),
#  ('remedlatlon', 'actlvltles', 'whlch'),
#  ('actlvltles', 'whlch', 'Hill'),
#  ('the', '1ndustry.', '1:'),
#  ('use', 'restrlctlons', 'on'),
#  ('as', 'pestlcldes.', 'detergents,'),
#  ('concepts', 'concernlng', 'product'),
#  ('product', 'llablllty,', '1nclud1ng'),
#  ('taxlng', 'mechanlsms.', 'CMA'),
#  ('been', 'a', 'major'),
#  ('major', 'partlclpant', '1n'),
#  ('1n', "EPA'S", 'development'),
#  ('Groundwater', 'Pollcy,', 'whlch'),
#  ('Pollcy,', 'whlch', 'was'),
#  ('August,', '1934.', 'am'),
#  ('worked', 'mm', 'several'),
#  ('occaslons,', 'addresslng', 'both'),
#  ('Safe', 'Drlnklng', 'Water'),
#  ('October,', '1935,', 'dlrectly'),
#  ('Relatlons', "Commlttee's", 'Groundwater'),
#  ('CMA', '039757', '3.'),
#  ('Legal', 'Actlvltles', 'RMCL'),
#  ('Actlvltles', 'RMCL', 'Litigation.'),
#  ('case', 'challenglng', "EPA'S"),
#  ('challenglng', "EPA'S", 'Recommended'),
#  ('Levels', '(RMCL57', 'for'),
#  ('eight', 'synthetlc', 'organlc'),
#  ('ﬁlled', '1::', 'response'),
#  ('ﬁlled', 'by', 'cm'),
#  ('by', 'cm', 'and'),
#  ('Petroleum', 'Instltute', '(APB'),
#  ('Instltute', '(APB', '(jolntlw,'),
#  ('(APB', '(jolntlw,', 'the'),
#  ('Industry', 'Alllance', 'msmy,'),
#  ('Alllance', 'msmy,', 'and'),
#  ('20,', '1935,', 'the'),
#  ('the', 'challenglng', 'partles'),
#  ('thelr', 'addltlonal', 'brlefs'),
#  ('brlefs', 'replylng', 'm'),
#  ('replylng', 'm', 'the'),
#  ('posltlon.', 'cm', 'and'),
#  ('and', 'AP]:', 'ﬁlled'),
#  ('brlefs,', 'AP]:', 'concentratlng'),
#  ('"zero', 'RMCL"', 'lssue'),
#  ('and', 'cm', 'brleflng'),
#  ('ralsed', 'by', 'mum,'),
#  ('regulate', 'a', 'substance'),
#  ('as', 'a', 'carclnogen'),
#  ('of', 'carclnogenlclty.', 'Oral'),
#  ('27,', '1937.', 'A'),
#  ('1937.', 'A', 'declslon'),
#  ('fall,', '1937.', 'Surface'),
#  ('15.', '11287', 'just'),
#  ('sent', 'a', 'letter'),
#  ('Reagan', 'urglng', 'mm'),
#  ('urglng', 'mm', 'to'),
#  ('the', 'mm', 'on'),
#  ('7,', 'cltlng', 'the'),
#  ('the', '100th', 'Congress,'),
#  ('same', 'b111,', 'as'),
#  ('mu', 'm', 'commlttee'),
#  ('m', 'commlttee', 'and'),
#  ('mule', 'commlttee', 'and'),
#  ('and', 'subcommlttee', 'chalrmen'),
#  ('chalrmen', 'responslble', 'for'),
#  ('equally', 'commltted', 'm'),
#  ('commltted', 'm', 'passage'),
#  ('1dent1cal', 'm', 'the'),
#  ('s.', '1128,', 'and'),
#  ('15', 'worklng', 'to'),
#  ('compromlsed', 'by', "opponents'"),
#  ('communlcatlon', 'mm', 'other'),
#  ('and', 'munlclpal', 'groups'),
#  ('groups', 'regardlng', 'clean'),
#  ('on', '1::', 'prlmary'),
#  ('Legal', 'Actlvltles', 'Pestlcldes'),
#  ('Actlvltles', 'Pestlcldes', 'Effluent'),
#  ('15,', '1996,', 'EPA'),
#  ('EPA', 'publlshed', 'a'),
#  ('publlshed', 'a', 'notlce'),
#  ('and', 'announclng', 'that'),
#  ('25,', '1995."', 'Th1:'),
#  ('as', 'a', 'result'),
#  ('the', 'CMA/NACA', 'lawsult'),
#  ('lawsult', 'challenglng', 'the'),
#  ('1nfomed', 'cm', 'and'),
#  ('the', 'pestlcldes', '1ndustry.'),
#  ('pestlcldes', '1ndustry.', 'EPA'),
#  ('undertake', 'a', '17'),
#  ('CMA', '039759', 'new'),
#  ('and', 'technlcal', 'aspects'),
#  ('issue', 'a', 'new'),
#  ('June,', '1991.', 'Removal'),
#  ('19,', '1936,', 'the'),
#  ('ﬁlled', 'a', 'brlef'),
#  ('brlef', 'mm', 'the'),
#  ('Court', 'respondlng', 'm'),
#  ('respondlng', 'm', 'the'),
#  ('ﬁlled', 'by', 'cm'),
#  ('by', 'cm', 'and'),
#  ('and', 'by', 'a'),
#  ('by', 'a', 'group'),
#  ('agreed', 'Hlth', 'CMA'),
#  ('the', 'Thlrd', 'Clrcult'),
#  ('agreed', 'mm', 'am'),
#  ('on', '1ndustry.', 'Nevertheless,'),
#  ('further', 'revlew....', "mum's"),
#  ('to', "CMA'S", 'petition'),
#  ('Senate', 'W', 'had'),
#  ('hlndered', 'by', '1nterreglonal'),
#  ('1nterreglonal', 'confllct', 'and'),
#  ('slowed', 'by', 'opposltlon'),
#  ('from', 'electrlclty', 'producers'),
#  ('chemlcal', '1ndustry.', 'The'),
#  ('Tltle', 'III', 'of'),
#  ('coverlng', 'emlsslons', 'reportlng,'),
#  ('emlsslons', 'reportlng,', 'emergency'),
#  ('emergency', 'plannlng', 'and'),
#  ('communlty', 'rlghtitoiknow.', 'Early'),
#  ('1n', '1937,', 'the'),
#  ('resume', 'mm', 'focus'),
#  ('carbon', 'monoxldE,', 'alr'),
#  ('control.', 'By', 'Sprlng'),
#  ('By', 'Sprlng', '1937,'),
#  ('Sprlng', '1937,', 'clean'),
#  ('alr', 'hearlngs', 'probably'),
#  ('Senate', 'leadershlp', 'does'),
#  ('Vorks', "Commlttee's", 'agenda'),
#  ('Robert', 'Byrd', '(DrwvAy'),
#  ('Byrd', '(DrwvAy', '1n'),
#  ('posltlon', 'm', '1nfluence'),
#  ('the', 'HouSE,', 'Energy'),
#  ('Commerce', 'Commlttee', 'Chalrman'),
#  ('however.', 'ranklng', 'mlnorlty'),
#  ('was', 'a', 'co*sponsor'),
#  ('co*sponsor', 'c', 'the'),
#  ('the', 'Commlttee', 'and'),
#  ('Envlronment', 'Subcommlttee', 'are'),
#  ('15', 'dlfflcult', 'to'),
#  ('Votes.', '.', 'cm'),
#  ('.', 'cm', '15'),
#  ('15', 'a', 'major'),
#  ('major', 'partlclpant', '1n'),
#  ('the', '1nter71ndustry', 'Coalltlon'),
#  ('the', 'leadershlp', 'on'),
#  ('control', 'iSSuE,', 'but'),
#  ('has', 'publlshed', 'a'),
#  ('publlshed', 'a', 'comprehenslve'),
#  ('to', '35515:', 'members'),
#  ('1n', 'unplementlng', 'the'),
#  ('control', 'pollcy.', 'The'),
#  ('coordlnator.', 'Addltlonal', 'Copies'),
#  ('to', '35515:', 'member'),
#  ('1n', 'deslgnlng', 'approprlate'),
#  ('process', 'emlsslons.', 'Copies'),
#  ('to', 'EPA,', 'state'),
#  ('on', 'Emlsslon', 'Imrentorles'),
#  ('developed', 'a', 'twoiday'),
#  ('provlde', 'emlsslons', '1nventory'),
#  ('Hill', '35515:', 'member'),
#  ('January', '1314,', '1937,'),
#  ('1314,', '1937,', 'hlghllghts'),
#  ('1937,', 'hlghllghts', '1ncluded:'),
#  ('1ncluded:', 'o', 'o'),
#  ('o', 'o', 'o'),
#  ('o', 'o', 'o'),
#  ('o', 'o', 'o'),
#  ('o', 'o', 'o'),
#  ('o', 'o', 'emlsslon'),
#  ('o', 'emlsslon', '1nventory'),
#  ('1nventory', 'technlques,', 'updated'),
#  ('fugitive', 'emlsslons', 'procedures,'),
#  ('procedures,', 'notlflcatlon', 'and'),
#  ('and', 'reportlng', 'requlrements,'),
#  ('address', "EPA'S", 'publlcatlon,'),
#  ('publlcatlon,', '"Implementlng', 'the'),
#  ('Toxlcs', 'Pollcy",', 'and'),
#  ('u.', 'E.', 'Wenger'),
#  ('the', 'Unlverslty', 'of'),
#  ('address', '"Human', 'Response'),
#  ('Control', 'Pollcy.', 'CMA'),
#  ('developed', 'a', 'workshop'),
#  ('for', 'asslstance', '1n'),
#  ('20,', '1937,', 'addressed'),
#  ('addressed', 'rlsk', 'lssues'),
#  ('on', 'exlstlng', 'CAER'),
#  ('used', 'a', '"handsmn...'),
#  ('a', '"handsmn...', 'approach'),
#  ('approach', 'mm', '1nd1v1dual'),
#  ('mm', '1nd1v1dual', 'partlclpants'),
#  ('1nd1v1dual', 'partlclpants', 'worklng'),
#  ('partlclpants', 'worklng', 'through'),
#  ('Issue', 'Analysls.', 'The'),
#  ('Management', 'Commlttee', 'has'),
#  ('use', 'by', 'the'),
#  ('Affalrs', 'CommlttEE,', 'an'),
#  ('Issue', 'Analysls', 'on'),
#  ('15', 'conslstent', 'mm'),
#  ('conslstent', 'mm', 'exlstlng'),
#  ('mm', 'exlstlng', 'cm'),
#  ('exlstlng', 'cm', 'pollcy'),
#  ('usable', 'by', 'cm'),
#  ('by', 'cm', 'member'),
#  ('state', 'actlvltles.', 'The'),
#  ('15', 'm', 'obtaln'),
#  ('sources', 'handllng', 'Significant'),
#  ('Significant', 'quantltles', 'of'),
#  ('of', 'hlghly', 'toxlc'),
#  ('wlthout', 'penallzlng', 'sources'),
#  ('Grassroots', 'Actlvltles', 'Congresslonal'),
#  ('are', 'establlshlng', 'dlstrlct'),
#  ('establlshlng', 'dlstrlct', 'coalltlons'),
#  ('partles', 'Hlth', 'an'),
#  ('tallor', 'a', 'speclflc'),
#  ('a', 'speclflc', 'message'),
#  ('CMA', '039751', 'CMA'),
#  ('general', 'prlnclples', 'on'),
#  ('air', 'toxlcs.', 'Meetlngs'),
#  ('toxlcs.', 'Meetlngs', 'between'),
#  ('and', "CMA'S", 'posltlons.'),
#  ('been', '1dent1£1ed', 'as'),
#  ('of', 'membershlp', 'on'),
#  ('congresslonal', 'commlttees', 'of'),
#  ('of', 'jurlsdlctlon', 'as'),
#  ('as', 'a', 'large'),
#  ('1ndustry', 'constltuent', 'presence'),
#  ('thelr', 'dlstrlcts.', 'The'),
#  ('so', '1dent1£1ed', 'for'),
#  ('for', 'actlvlty', '1n'),
#  ('congresslonal', 'commlttee', 'asslgnments'),
#  ('commlttee', 'asslgnments', 'are'),
#  ('revlsed,', 'accordlngly.', '4.'),
#  ('CMA', 'submltted', 'comments'),
#  ('on', "EPA'S", 'proposed'),
#  ('sources,', 'lndustr1al*commcrclali1nst1tutlonal', 'steam'),
#  ('generatlng', 'unlts.', 'cm'),
#  ('unlts.', 'cm', 'crltlclzed'),
#  ('cm', 'crltlclzed', 'the'),
#  ('hollers.', 'cm', 'recommended'),
#  ('set', 'emlsslon', 'limits'),
#  ('met', 'by', 'Either'),
#  ('electlon.', 'praicleanlng,', 'or'),
#  ('or', 'scrubblng', 'whlchever'),
#  ('scrubblng', 'whlchever', '15'),
#  ...]

# %% [markdown]
# # correction

# %%
import correction_lib as corr
from word_dict import Create_Words_Dictionary, Create_Word_Pair

# %%
import collections
import timeit
import string

# %%
def clean_word(w):
    out = []
    for c in w:
        c = c.lower()
        # Searching set is faster than list: O(1) vs. O(n=26)
        if c in set(string.ascii_lowercase):
            out.append(c)
    return(''.join(out))

# %%
# create a list of words from ground truth; include repeatition and order of words
word_list = []
gt_filenames = glob.glob('../data/ground_truth/*.txt')


count = 0
for gt_f in gt_filenames:
    with open(gt_f) as file:
        raw = file.read()
        # Split file content into words (by '\n', '\t', ' ', etc.)
        uncleaned_words = raw.split()
        # Clean up words, leave only all-alpha chars of length > 1 (function programming)
        word_list += list(filter((lambda x: 1 < len(x) < 21), map(clean_word, uncleaned_words)))
        #, map(clean_word, uncleaned_words)

# %%
word_set = set(word_list)

# %%
N = len(word_list)
V = len(word_set)
denominator = N + V/2

# %%
Delection = pd.read_csv("../data/confusion_matrix/del_matrix.csv", index_col=0)
Insertion = pd.read_csv("../data/confusion_matrix/add_matrix.csv", index_col=0)
Substitution = pd.read_csv("../data/confusion_matrix/sub_matrix.csv", index_col=0)
Reversal = pd.read_csv("../data/confusion_matrix/rev_matrix.csv", index_col=0)

# %%
import numpy as np
Deletion_Confusion = np.array(Delection).tolist()
Insertion_Confusion = np.array(Insertion).tolist()
Substitution_Confusion = np.array(Substitution).tolist()
Reversal_Confusion = np.array(Reversal).tolist()

# %%
# Input a detected error word;
# return a list of (correction candidates, changed letters),
# ordered by types of correction (from the ground truth word set)
def get_correction_candidates(w):
    alphabet = 'abcdefghijklmnopqrstuvwxyz'
    candidate_list = [[] for _ in range(4)]
    
    ### 4 kinds of correction candidates (see Table 2, C-4)
    # 0. Deletion
    for i in range(len(w) + 1):
        for c in alphabet:
            correction = w[:i] + c + w[i:]
            if correction in word_set:
                diff = corr.find_deletion_letters(correction, w) 
                candidate_list[0].append((correction, diff['pre_letter'], diff['delete_letter']))
            
    # 1. Insertion
    for i in range(len(w)):
        correction = w[:i] + w[i+1:]
        if correction in word_set:
            diff = corr.find_insertion_letters(correction, w) 
            candidate_list[1].append((correction, diff['pre_letter'], diff['insert_letter']))
    
    # 2. Substitution
    for i in range(len(w)):
        for c in alphabet:
            if c != w[i]:
                correction = w[:i] + c + w[i+1:]
                if correction in word_set:
                    diff = corr.find_sub_rev_letters(correction, w) 
                    if diff['tag'] == 'sub':
                        candidate_list[2].append((correction, diff['pre_letter'], diff['changed_letter']))
    
    # 3. Reversal
    for i in range(len(w) - 1):
        correction = w[:i] + w[i+1] + w[i] + w[i+2:]
        if correction in word_set:
            diff = corr.find_sub_rev_letters(correction, w) 
            if diff['tag'] == 'rev':
                candidate_list[3].append((correction, diff['pre_letter'], diff['changed_letter']))
    
    return(candidate_list)
#get_correction_candidates('aded')

# %%
# Create a dictionary of all candidates of each detected error
start = timeit.default_timer()

all_candidates = collections.defaultdict(dict)
for word in problem_list:
    all_candidates[word[0]] = get_correction_candidates(word[0])
    
stop = timeit.default_timer()
print('Time:', stop - start, 'seconds')
# Out:
# Time: 9.863873904000002 seconds

# %%
#all_candidates['aded']

# %%
##prc

# %%
##one gram final
from sklearn.feature_extraction.text import CountVectorizer
bigram_vectorizer1 = CountVectorizer(ngram_range=(1, 1),
                                    token_pattern=r'\b\w+\b')
X1 = bigram_vectorizer1.fit_transform(word_list)
#X1.toarray()

feature_list = bigram_vectorizer1.get_feature_names()

# %%
a = pd.DataFrame([feature_list, list(np.asarray(X1.sum(axis=0))[0])]).T

# %%
a.to_csv('../output/1-gram_output.csv',index= False)

# %%
one_gram = pd.read_csv("../output/1-gram_output.csv")

one_gram.columns=['word','freq']
one_gram.set_index('word')

def get_Pr_c(correction):
    r = int(np.array(one_gram[one_gram['word']==correction][['freq']]))
    Nr = one_gram[one_gram['freq']==r].shape[0]
    Nr1 = one_gram[one_gram['freq']==r+1].shape[0]
    return((r+1)*Nr1/(Nr*N))

def get_Pr_c_ele(correction):
    r = int(np.array(one_gram[one_gram['word']==correction][['freq']]))
    return (r + 0.5)/denominator

# %%
#one_gram[one_gram['word']=='added'][['freq']]
# Out:
#      freq
# 224    44

# %%
#prtc

# %%
def char_to_index(c):
    return(ord(c) - ord('a'))

# %%
# prtc
# chars[x] and chars[xy]
chars_x = [0] * 26 + [N]
chars_xy = [[0] * 26 for _ in range(27)]
for word in word_list:
    for i, c in enumerate(word):
        chars_x[char_to_index(c)] += 1
        if i:
            chars_xy[26][char_to_index(c)] += 1
        else:
            chars_xy[char_to_index(word[i-1])][char_to_index(c)] += 1
for i in range(len(chars_xy)):
    for j in range(len(chars_xy[0])):
        if not chars_xy[i][j]:
            chars_xy[i][j] = 0.5

# %%
def get_Pr_tc(typo, correction, pre, cur, error_type):
    if error_type == 'del':
        return Deletion_Confusion[char_to_index(pre)][char_to_index(cur)] \
               / chars_xy[char_to_index(pre)][char_to_index(cur)]
    if error_type == 'ins':
        return Insertion_Confusion[char_to_index(pre)][char_to_index(cur)] \
               / chars_x[char_to_index(pre)]
    if error_type == 'sub':
        return Substitution_Confusion[char_to_index(pre)][char_to_index(cur)] \
               / chars_x[char_to_index(pre)]
    if error_type == 'rev':
        return Reversal_Confusion[char_to_index(pre)][char_to_index(cur)] \
               / chars_xy[char_to_index(pre)][char_to_index(cur)]

# %%
# A dictionary, the key of which is the words in ground truth,
# the value to each key records the two neighbor words and their frequencies.
neighbor_dict = Create_Words_Dictionary()
neighbor_dict['reliable']
# Out:
# {'left': {'and': 4,
#   'that': 1,
#   'patents': 1,
#   'provide': 1,
#   'are': 1,
#   'from': 1,
#   'more': 1,
#   'no': 1},
#  'right': {'service': 1,
#   'human': 1,
#   'assets': 1,
#   'data': 2,
#   'basis': 1,
#   'and': 1,
#   'long': 1,
#   'sources': 1,
#   'we': 1,
#   'national': 1}}

# %%
bi_gram = pd.read_csv("../output/bigram_output.csv")
bi_gram.columns=['word','freq']
bi_gram.set_index('word')
# Out:
#                          freq
# word
# in the                   1497
# to the                   1072
# on the                    835
# and the                   687
# will be                   618
# by the                    582
# for the                   569
# with the                  524
# chemical industry         480
# to be                     443
# that the                  442
# the chemical              405
# task group                372
# has been                  351
# the house                 340
# at the                    291
# the senate                283
# have been                 272
# it is                     260
# from the                  246
# member companies          237
# the cma                   226
# the panel                 213
# the committee             204
# should be                 191
# the board                 191
# would be                  188
# the state                 184
# the us                    174
# cma cma                   172
# ...                       ...
# possiblity that             1
# three resolutions           1
# delegations from            1
# el ction                    1
# the inside                  1
# stage by                    1
# was attained                1
# sites project               1
# be defined                  1
# bill highway                1
# similar meetings            1
# keymen and                  1
# more stock                  1
# major us                    1
# ec member                   1
# within congress             1
# fortign govarnmant          1
# disease at                  1
# engineering disciplines     1
# treatment requirements      1
# anticipated following       1
# argued against              1
# toxicological field         1
# it within                   1
# of ul                       1
# advocacy aaterials          1
# it administrator            1
# are adjusted                1
# attendees to                1
# effective companies         1
#
# [124650 rows x 1 columns]

# %%
def get_Pr_context_correction(cand, left, right):
    """
    word:   a correction candidate
    left:   the left neighbor of the error word in tesseract
    right:  the right neighbor of the error word in tesseract
    return: GT of Pr(l|c) * Pr(r|c)
    """
    # r_left = freq of left appearing, r_right = freq of right appearing
    temp_left = left + ' ' + cand
    try:
        r_left = int(np.array(bi_gram[bi_gram['word']==temp_left][['freq']]))
    except:
        r_left = 0
    if(r_left != 0):
        Nr_left = bi_gram[bi_gram['freq']==r_left].shape[0]
    else:
        Nr_left = N
    Nr1_left = bi_gram[bi_gram['freq']==r_left+1].shape[0]
    temp_right = cand + ' ' + right
    try:
        r_right = int(np.array(bi_gram[bi_gram['word']==temp_right][['freq']]))
    except:
        r_right = 0
    if(r_left != 0):
        Nr_right = bi_gram[bi_gram['freq']==r_right].shape[0]
    else:
        Nr_right = N
    Nr1_right = bi_gram[bi_gram['freq']==r_right+1].shape[0]
    
    return((r_left+1)*(r_right+1)*Nr1_left*Nr1_right/(Nr_left*Nr_right))

# %%
N
# Out:
# 277888

# %%
get_Pr_context_correction("hi",'hello','right')
# Out:
# 0.11136235334012003

# %%
def get_Pr_context_correction_ele(cand, left, right):
    """
    word:   a correction candidate
    left:   the left neighbor of the error word in tesseract
    right:  the right neighbor of the error word in tesseract
    return: ELE of Pr(l|c) * Pr(r|c)
    """
    # r_left = freq of left appearing, r_right = freq of right appearing
    r_left, r_right = 0, 0
    if left in neighbor_dict[cand]['left']:
        r_left = neighbor_dict[cand]['left'][left]
    if right in neighbor_dict[cand]['right']:
        r_right = neighbor_dict[cand]['right'][right]        
    return((r_left + 0.5)*(r_right + 0.5))

# %%
result = Create_Word_Pair()
word_pairs = result[:-1]
num_corrections_found_tesseract, sum_letters = result[-1][0], result[-1][1]
#print(sum_letters)
#print(word_pairs)

# %%
start = timeit.default_timer()
detected_error_tuples2 = []


for t in problem_list:
    for pair in word_pairs:
        try:
            if t[0] == pair[1]:
                detected_error_tuples2.append((t[0], pair[0], t[1], t[2]))
                break
        except:
            continue
stop = timeit.default_timer() 
print('Time:', stop - start, 'seconds')
print(detected_error_tuples2)
# Out:
# Time: 345.90594331600005 seconds
# [('provlde', 'provide', 'thls', 'needed'), ('new', 'view', 'CMA/LINC', 'computer'), ('the', 'emcs', 'crltlcal', 'envlronmental'), ('lssues', 'issues', '1dent1£1ed', 'by'), ('contlnue', 'continue', 'm', 'be'), ('study', 'showed', 'by', 'the'), ('the', 'emcs', 'cm', 'State'), ('the', 'emcs', 'reportlng', 'of'), ('concernlng', 'concerning', "1ndustry's", 'operatlons'), ('along', 'with', 'Hlth', 'groundwater'), ('actlve', 'active', 'partlclpant', '1n'), ('toxlcs', 'toxics', 'pollcy.', 'A'), ('but', 'they', 'rapldly', 'growlng'), ('actlvely', 'actively', 'partlclpatlng', '1n'), ('and', 'the', '1nd1v1dual', 'companles'), ('of', 'the', 'thls', 'issue.'), ('contlnue', 'continue', 'm', 'be'), ('cm', 'cma', '039507', 'The'), ('air', 'and', 'toxlcs.', 'The'), ('related', 'matters', 'actlvltles', 'of'), ('chemlcals', 'chemicals', '115mm;', 'and.'), ('medla', 'media', 'analysls,', 'made'), ('budget', 'matters', 'reconclllatlon', 'process.'), ('of', 'the', 'thls', 'attentlon'), ('as', 'an', 'mlght', 'have'), ('been', 'filed', 'antlclpated', 'followlng'), ('of', 'the', 'exlstlng', 'law.'), ('the', 'emcs', 'Instltute,', 'w.v.'), ('and', 'the', 'Pennsylvanla', 'were'), ('about', 'four', 'thls', 'lssue'), ('lssue', 'issue', 'Hlth', 'questlons'), ('and', 'the', 'deslgn.', 'New'), ('our', 'sage', 'actlvltles', 'relatlng'), ('toxlcs', 'toxics', 'actlvltles', 'were'), ('for', 'epas', 'a', 'broad'), ('over', 'sole', 'a', 'perlod'), ('agree', 'agreed', 'mm', 'the'), ('that', 'would', 'a', 'waste'), ('llttle', 'little', 'relatlonshlp', 'to'), ('and', 'the', 'affldavlts,', 'convlnced'), ('an', 'and', 'Admlnlstratlve', 'Law'), ('from', 'the', 'antltrust', 'laws.'), ('entlre', 'entire', 'Commlsslon.', '1:'), ('as', 'an', 'a', 'precedent'), ('from', 'the', 'obtalnlng', 'antltrust'), ('obtalnlng', 'obtaining', 'antltrust', 'exemptlons'), ('approved', 'freezing', 'a', 'rule'), ('rule', 'the', '(Order', 'No.'), ('market', 'markets', 'by', 'facllltatlng'), ('by', 'the', 'facllltatlng', 'the'), ('unplemented', 'implemented', 'by', 'the'), ('be', 'the', 'a', 'substantlal'), ('cost', 'item', 'savlngs', 'to'), ('annual', 'animal', 'savlngs', 'for'), ('for', 'epas', 'cm', 'members'), ('of', 'the', 'a', 'new'), ('would', 'create', 'slgnlflcantly', 'ralse'), ('study', 'showed', 'submltted', 'by'), ('submltted', 'submitted', 'by', 'cm'), ('by', 'the', 'cm', '1nd1cated'), ('cm', 'cma', '1nd1cated', 'that'), ('for', 'epas', 'cm', 'and'), ('the', 'emcs', 'Commlsslon', '15'), ('contlnulng', 'continuing', '1::', 'assessment'), ('sltes', 'sites', 'by', 'freezlng'), ('unposlng', 'imposing', 'a', 'broadibased'), ('budget', 'matters', 'reconclllatlon', 'mu'), ('mu', 'un', 'whlch', 'passed'), ('budget', 'matters', 'reconclllatlon', 'leglslatlon.'), ('as', 'an', 'm', '32.'), ('conflmed', 'confirmed', '1::', 'support'), ('for', 'epas', 'a', 'broadibased'), ('program', 'recently', 'by', 'slgnlflcantly'), ('by', 'the', 'slgnlflcantly', '1ncreaslng'), ('tax', 'in', 'whlch', 'was'), ('the', 'emcs', 'envlronmentallsts,', 'and'), ('and', 'the', 'a', 'broad'), ('cm', 'cma', '039509', 'support,'), ('and', 'the', '13111', "Frenzel's"), ('the', 'emcs', '510.3', 'bllllon'), ('from', 'the', 'a', '$2'), ('from', 'the', 'a', 'crude'), ('from', 'the', 'a', 'waste'), ('were', 'asked', 'a', 'compromlse'), ('and', 'the', 'rlghtitoiknow', 'provlslons'), ('create', 'joint', 'a', 'federal'), ('was', 'or', 'a', 'key'), ('the', 'emcs', 'fundlng', 'level,'), ('much', 'more', 'dlscretlon', 'to'), ('give', 'given', 'EPA.', 'The'), ('do', 'not', '1:,', 'where'), ('of', 'the', "CMA'S", 'Government'), ('provlde', 'provide', 'fundlng', 'for'), ('budget', 'matters', 'reconclllatlon', 'began'), ('on', 'the', 'a', 'compromlse'), ('and', 'the', 'a', 'broadibased'), ('to', 'cma', 'strlke', 'the'), ('wlthout', 'without', 'passlng', 'budget'), ('budget', 'matters', 'reconclllatlon,', 'the'), ('dlfferent', 'different', 'fundlng', 'approaches'), ('approved', 'freezing', 'by', 'the'), ('how', 'to', 'dlfflcult', 'the') ...

# %%
def get_final_Pr_correction(cand, typo, pre, cur, error_type, left, right):
    return get_Pr_c(cand) * get_Pr_tc(typo, cand, pre, cur, error_type)*get_Pr_context_correction(cand, left, right)

err_type = ['del', 'ins', 'sub', 'rev']
result = {}
for typo, truth, left, right in detected_error_tuples2:
    cand_poss_gt = []
    for e in range(4):
        for cand, pre, cur in all_candidates[typo][e]:
            gt_p = get_final_Pr_correction(cand, typo, pre, cur, err_type[e], left, right)
            cand_poss_gt.append((cand, gt_p))
    gt_best_cand = max(cand_poss_gt, key=lambda x: x[1])[0] if cand_poss_gt else ''
    result[typo] = (truth, gt_best_cand)

# print(len(result))
# print(dict((k, v) for k, v in result.items() if 2 < len(k) < 5))
# print(dict((k, v) for k, v in result.items() if v[0] == v[1]))
# print(len(dict((k, v) for k, v in result.items() if v[0] == v[1])))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-40-98cdbf0bf9d0> in <module>
#       8     for e in range(4):
#       9         for cand, pre, cur in all_candidates[typo][e]:
# ---> 10             gt_p = get_final_Pr_correction(cand, typo, pre, cur, err_type[e], left, right)
#      11             cand_poss_gt.append((cand, gt_p))
#      12     gt_best_cand = max(cand_poss_gt, key=lambda x: x[1])[0] if cand_poss_gt else ''
#
# <ipython-input-40-98cdbf0bf9d0> in get_final_Pr_correction(cand, typo, pre, cur, error_type, left, right)
#       1 def get_final_Pr_correction(cand, typo, pre, cur, error_type, left, right):
# ----> 2     return get_Pr_c(cand) * get_Pr_tc(typo, cand, pre, cur, error_type)*get_Pr_context_correction(cand, left, right)
#       3
#       4 err_type = ['del', 'ins', 'sub', 'rev']
#       5 result = {}
#
# <ipython-input-34-0be13807c664> in get_Pr_context_correction(cand, left, right)
#      28     Nr1_right = bi_gram[bi_gram['freq']==r_right+1].shape[0]
#      29
# ---> 30     return((r_left+1)*(r_right+1)*Nr1_left*Nr1_right/(Nr_left*Nr_right))
#
# ZeroDivisionError: division by zero

# %%
def get_final_Pr_correction(cand, typo, pre, cur, error_type, left, right):
    return get_Pr_c(cand) * get_Pr_tc(typo, cand, pre, cur, error_type)*get_Pr_context_correction(cand, left, right)

def get_final_Pr_correction_ele(cand, typo, pre, cur, error_type, left, right):
    return get_Pr_c_ele(cand) * get_Pr_tc(typo, cand, pre, cur, error_type) * get_Pr_context_correction_ele(cand, left, right)

err_type = ['del', 'ins', 'sub', 'rev']
result = {}
for typo, truth, left, right in detected_error_tuples2:
    cand_poss_gt , cand_poss_ele= [], []
    for e in range(4):
        for cand, pre, cur in all_candidates[typo][e]:
            gt_p = get_final_Pr_correction(cand, typo, pre, cur, err_type[e], left, right)
            ele_p = get_final_Pr_correction_ele(cand, typo, pre, cur, err_type[e], left, right)
            cand_poss_gt.append((cand, gt_p))
            cand_poss_ele.append((cand, ele_p))
    gt_best_cand = max(cand_poss_gt, key=lambda x: x[1])[0] if cand_poss_gt else ''
    ele_best_cand = max(cand_poss_ele, key=lambda x: x[1])[0] if cand_poss_ele else ''
    result[typo] = (truth, gt_best_cand, ele_best_cand)

# print(len(result))
# print(dict((k, v) for k, v in result.items() if 2 < len(k) < 5))
# print(dict((k, v) for k, v in result.items() if v[0] == v[1]))
# print(len(dict((k, v) for k, v in result.items() if v[0] == v[1])))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-39-74185a020df2> in <module>
#      11     for e in range(4):
#      12         for cand, pre, cur in all_candidates[typo][e]:
# ---> 13             gt_p = get_final_Pr_correction(cand, typo, pre, cur, err_type[e], left, right)
#      14             ele_p = get_final_Pr_correction_ele(cand, typo, pre, cur, err_type[e], left, right)
#      15             cand_poss_gt.append((cand, gt_p))
#
# <ipython-input-39-74185a020df2> in get_final_Pr_correction(cand, typo, pre, cur, error_type, left, right)
#       1 def get_final_Pr_correction(cand, typo, pre, cur, error_type, left, right):
# ----> 2     return get_Pr_c(cand) * get_Pr_tc(typo, cand, pre, cur, error_type)*get_Pr_context_correction(cand, left, right)
#       3
#       4 def get_final_Pr_correction_ele(cand, typo, pre, cur, error_type, left, right):
#       5     return get_Pr_c_ele(cand) * get_Pr_tc(typo, cand, pre, cur, error_type) * get_Pr_context_correction_ele(cand, left, right)
#
# <ipython-input-34-0be13807c664> in get_Pr_context_correction(cand, left, right)
#      28     Nr1_right = bi_gram[bi_gram['freq']==r_right+1].shape[0]
#      29
# ---> 30     return((r_left+1)*(r_right+1)*Nr1_left*Nr1_right/(Nr_left*Nr_right))
#
# ZeroDivisionError: division by zero

# %%
#print(result)
# Out:
# {'provlde': ('provide', 'provide'), 'new': ('view', 'news'), 'the': ('ad', 'then'), 'lssues': ('issues', 'issues'), 'contlnue': ('continue', 'continue'), 'study': ('will', 'studys'), 'concernlng': ('concerning', 'concerning'), 'along': ('with', 'long'), 'actlve': ('active', 'active'), 'toxlcs': ('toxics', 'toxics'), 'but': ('then', 'bust'), 'actlvely': ('actively', 'actively'), 'and': ('mt', 'end'), 'of': ('a', 'off'), 'cm': ('cma', 'com'), 'air': ('and', 'aid'), 'related': ('sciences', 'relates'), 'chemlcals': ('chemicals', 'chemicals'), 'medla': ('media', 'medal'), 'budget': ('buoget', 'budgets'), 'as': ('of', 'ays'), 'been': ('one', 'bene'), 'about': ('four', ''), 'lssue': ('issue', 'issue'), 'our': ('and', 'ours'), 'for': ('the', 'four'), 'over': ('four', 'overt'), 'agree': ('agreed', 'agreed'), 'that': ('the', 'chat'), 'llttle': ('little', 'little'), 'an': ('age', 'ann'), 'from': ('this', 'form'), 'entlre': ('entire', 'entire'), 'obtalnlng': ('exemptions', ''), 'approved': ('freezing', 'approve'), 'rule': ('test', 'ruled'), 'market': ('markets', 'markets'), 'by': ('the', 'bly'), 'unplemented': ('implemented', ''), 'be': ('of', 'ble'), 'cost': ('would', 'coast'), 'annual': ('animal', 'annaul'), 'would': ('write', 'world'), 'submltted': ('submitted', 'submitted'), 'contlnulng': ('continuing', ''), 'sltes': ('sites', 'slates'), 'unposlng': ('imposing', ''), 'mu': ('mca', 'my'), 'conflmed': ('confirmed', ''), 'program': ('projects', 'porgram'), 'tax': ('code', 'tx'), 'were': ('told', 'where'), 'create': ('joint', 'created'), 'was': ('of', 'ways'), 'much': ('more', 'mich'), 'give': ('you', 'given'), 'do': ('so', 'doe'), 'on': ('the', 'one'), 'to': ('the', 'too'), 'wlthout': ('without', 'without'), 'dlfferent': ('different', 'different'), 'how': ('to', 'hoc'), 'prlmary': ('primary', 'primary'), 'retalnlng': ('retaining', ''), 'or': ('for', 'ore'), 'we': ('are', 'wey'), 'authorlzed': ('authorized', 'authorized'), 'lltlgatlon': ('litigation', ''), 'challenglng': ('challenging', 'challenging'), 'addltlon': ('addition', 'addlelon'), 'crlterla': ('criteria', ''), 'have': ('been', 'hava'), 'radlo': ('radio', 'radio'), 'also': ('has', 'asso'), 'dlstrlbutlng': ('distributing', ''), 'launchlng': ('launching', 'launching'), 'hazardous': ('materials', 'hazsrdous'), 'will': ('take', 'well'), 'lssued': ('issued', 'issued'), 'adoptlng': ('adopting', 'adopting'), 'determlne': ('determine', 'determine'), 'detemlne': ('determine', ''), 'proposed': ('federal', 'propose'), 'thls': ('this', 'thla'), 's': ('is', 'so'), 'proposal': ('focuses', 'proposals'), 'waste': ('water', 'wastes'), 'categorles': ('categories', 'categories'), 'has': ('been', 'hays'), 'show': ('very', 'shows'), 'years': ('yeers', 'yaars'), 'conduct': ('areawide', 'conduc'), 'small': ('part', 'shall'), 'certaln': ('certain', 'certain'), 'ordlnance': ('ordinance', 'ordinance'), 'addressed': ('adequately', 'addresses'), 'can': ('have', 'chan'), 'm': ('to', 'me'), 'developed': ('informal', ''), 'dlsposed': ('disposed', 'disposed'), 'address': ('problems', 'addrass'), 'meetlng': ('meeting', 'meeting'), 'ban': ('of', 'bean'), 'negotlatlon': ('negotiation', ''), 'materlals': ('materials', 'materials'), 'estlmated': ('estimated', 'estlmatad'), 'comments': ('conments', 'comment'), 'may': ('be', 'many'), 'negotlatlons': ('negotiations', ''), 'at': ('ct', 'art'), 'contalns': ('contains', 'contains'), 'communlty': ('community', 'community'), 'alr': ('air', 'ar'), 'emlsslons': ('emissions', ''), 'further': ('testing', 'furthar'), 'under': ('public', 'undar'), 'held': ('and', 'hold'), 'preoccupled': ('preoccupied', 'preoccupied'), 'mean': ('means', 'means'), 'addltlonal': ('additional', ''), 'sources': ('review', 'source'), 'emlsslon': ('emission', ''), 'conducted': ('advocacy', ''), 'more': ('than', 'moore'), 'chromlum': ('chromium', 'chromium'), 'conjunctlon': ('conjunction', 'conjunction'), 'llne': ('line', 'line'), 'partles': ('parties', 'parties'), 'tradlng': ('partners', 'trading'), 'a': ...

# %% [markdown]
# # performance measure

# %%
import os

# %%
# Create a list of words from tesseract text; regard repeatition and order of words
tr_word_list = []
tr_filenames = glob.glob("../data/tesseract/*.txt" )
for tr_f in tr_filenames:
    with open(tr_f) as file:
        raw = file.read()
        uncleaned_words = raw.split()
        tr_word_list += list(filter(lambda x: 1 < len(x) < 21, map(clean_word, uncleaned_words)))
N_tr = len(tr_word_list)
# print(N_tr, '\n', tr_word_list[:30])
print(N_tr)

# %%
# Word-wise recalls and precisions
num_corrections_found_GT = num_corrections_found_tesseract\
                            + len(dict((k, v) for k, v in result.items() if v[0] == v[1]))

num_corrections_found_ELE = num_corrections_found_tesseract\
                            + len(dict((k, v) for k, v in result.items() if v[0] == v[2]))

wordwise_precision_tesseract = num_corrections_found_tesseract / N
wordwise_precision_GT = num_corrections_found_GT / N
wordwise_precision_ELE = num_corrections_found_ELE / N
# print(wordwise_precision_tesseract, wordwise_precision_GT,wordwise_precision_ELE)

wordwise_recall_tesseract = num_corrections_found_tesseract / N_tr
wordwise_recall_GT = num_corrections_found_GT / N_tr
wordwise_recall_ELE = num_corrections_found_ELE / N_tr
print(wordwise_recall_tesseract, wordwise_recall_GT, wordwise_recall_ELE)

# %%
# Character-wise recalls and precisions
def get_100tage_per_word_pair(w1, w2):
    max_len, min_len = max(len(w1), len(w2)), min(len(w1), len(w2))
    score = 0
    for i in range(min_len):
        if w1[i] == w2[i]:
            score +=1
    return(score / max_len)
print(get_100tage_per_word_pair('cors', 'car'))
    
# len(result) is denominator
sum_tesseract, sum_GT, sum_ele = 0, 0, 0
for k, v in result.items():
    sum_tesseract += get_100tage_per_word_pair(v[0], k)
    sum_GT += get_100tage_per_word_pair(v[0], v[1])
    sum_ele += get_100tage_per_word_pair(v[0], v[2])


# Total numbers of letters in ground truth and in tesseract
sum_all_truth, sum_all_tesseract = 0, 0
for w in word_list:
    sum_all_truth += len(w)
for w in tr_word_list:
    sum_all_tesseract += len(w)

charwise_precision_tesseract = sum_letters[1] / sum_all_truth
charwise_precision_GT = (sum_letters[1] + sum_GT) / sum_all_truth
charwise_precision_ELE = (sum_letters[1] + sum_ele) / sum_all_truth
print(charwise_precision_tesseract, charwise_precision_GT, charwise_precision_ELE)

charwise_recall_tesseract = sum_letters[1] / sum_all_tesseract
charwise_recall_GT = (sum_letters[1] + sum_GT) / sum_all_tesseract
charwise_recall_ELE = (sum_letters[1] + sum_ele) / sum_all_tesseract
print(charwise_recall_tesseract, charwise_recall_GT, charwise_recall_ELE)

# %%
idxs = pd.Index(["Word-wise recall", "Word-wise precision", 
              "Character-wise recall ", "Character-wise precision"])
cols = pd.Index(["Tesseract", "Tesseract with Post-Processing (GT)",
                "Tesseract with Post-Processing (ELE)"])
df = pd.DataFrame(data=np.array([
     [wordwise_precision_tesseract, wordwise_precision_GT, wordwise_precision_ELE],\
     [wordwise_recall_tesseract, wordwise_recall_GT, wordwise_recall_ELE],\
     [charwise_precision_tesseract, charwise_precision_GT, charwise_precision_ELE],\
     [charwise_recall_tesseract, charwise_recall_GT, charwise_recall_ELE]]),\
     index=idxs, columns=cols)
display(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-229-021372fd4ee2> in <module>
#       4                 "Tesseract with Post-Processing (ELE)"])
#       5 df = pd.DataFrame(data=np.array([
# ----> 6      [wordwise_precision_tesseract, wordwise_precision_GT, wordwise_precision_ELE],\
#       7      [wordwise_recall_tesseract, wordwise_recall_GT, wordwise_recall_ELE],\
#       8      [charwise_precision_tesseract, charwise_precision_GT, charwise_precision_ELE],\
#
# NameError: name 'wordwise_precision_ELE' is not defined
